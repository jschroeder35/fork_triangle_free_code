# %%
from graph_algs_test_build import *

# %%
###Set up starting graph
v_0 = vert([1, 4, 5, 6], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1], [], 2)
v_3 = vert([4, 2], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 3, 7], [], 5)
v_6 = vert([0, 2], [7], 6)
v_7 = vert([5, 8], [0, 1, 2, 3, 4], 7)
v_8 = vert([7], [0, 1, 2, 3, 4], 8)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7, v_8])
test_graph.clean()
print(test_graph.update_graph(lem2_5_list))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2]
#     Non-edges: [7, 1, 3, 4, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8]
#     Non-edges: [0, 1, 2, 3, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   []
# ...

# %%
test_graph2=copy.deepcopy(test_graph)
new_vert=vert([8], [], len(test_graph2.vertex_list))
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph5([fork, triangle], verbose=True, add_vertices=False)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3]
#     Unknown:   [9]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   [9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 6, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2]
#     Non-edges: [7, 1, 3, 4, 5, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8]
#     Non-edges: [0, 1, 2, 3, 4, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [7, 9]
# ...
