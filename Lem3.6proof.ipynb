# %%
from graph_algs import *

# %%
###Set up starting graph
v_0 = vert([1, 4, 5], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1, 5], [], 2)
v_3 = vert([4, 2], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 2, 6], [], 5)
v_6 = vert([5], [0, 1, 2, 3, 4], 6)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6])
test_graph.clean()
print(test_graph.update_graph(lem3_5_list))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [6, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [6, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [6, 0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [6, 0, 1, 5]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [6, 1, 2, 5]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [5]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None

# %%
###See what we can get
test_graph2=copy.deepcopy(test_graph)
test_graph2.update_graph5(lem3_5_list, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='medium', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [6, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [6, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [6, 0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [6, 0, 1, 5]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [6, 1, 2, 5]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [5]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# There are 0 unknown edges in the graph to check
# Vertex 7 added adjacent to 1 that cannot be adjacent to [0, 2, 3, 4, 5]
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
# ...

# %%
###Testing if N^2(C) can be adjacent to N(v_4)
test_graph2=copy.deepcopy(test_graph)
new_vert=vert([3], [], 7)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([7], [0, 1, 2, 3, 4], 8)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph5(lem3_5_list, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='fast', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [6, 2, 3, 8]
#     Unknown:   [7]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [6, 3, 4, 5, 8]
#     Unknown:   [7]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [6, 0, 4, 8, 7]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 7]
#     Non-edges: [6, 0, 1, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [6, 1, 2, 5, 8, 7]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4]
#     Unknown:   [7, 8]
#     Color:   None
# Vertex 6:
#     Edges:     [5]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [7, 8]
#     Color:   None
# Vertex 7:
#     Edges:     [3, 8]
#     Non-edges: [2, 4]
#     Unknown:   [0, 1, 5, 6]
#     Color:   None
# Vertex 8:
#     Edges:     [7]
#     Non-edges: [0, 1, 2, 3, 4]
# ...

# %%
test_graph2=copy.deepcopy(test_graph)
new_vert=vert([6], [0, 1, 2, 3, 4], 7)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph5(lem3_5_list, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='slow', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [6, 2, 3, 7]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [6, 3, 4, 5, 7]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [6, 0, 4, 7]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [6, 0, 1, 5, 7]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [6, 1, 2, 5, 7]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4, 7]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [5, 7]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# There are 0 unknown edges in the graph to check
# ...

# %%
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[0].max_degree=3
test_graph2.vertex_list[2].max_degree=3
test_graph2.vertex_list[1].color=2
test_graph2.vertex_list[5].color=1
test_graph2.vertex_list[3].color=0
test_graph2.vertex_list[4].color=1
test_graph2.vertex_list[2].color_start=True
test_graph2.color_argument_iter(lem3_5_list, 2, 10, min_subgraph=C_5, carg_update_speed='slow')
# Out:
# Iteration: 1
# There are 7 vertices in the graph.
# Vertex 2 is colored None. Possible neighbors colored 0: [[3], [], [], [], [], [], []]. done_list: []
# Vertex 3 is colored 0. Possible neighbors colored 1: [[4], [], [], [7], [], [], []]. done_list: [(2, 0)]
# Vertex 3 is colored 0. Possible neighbors colored 2: [[], [], [], [7], [], [], []]. done_list: [(2, 0)]
# Vertex 2 is colored None. Possible neighbors colored 1: [[5], [], [], [], [], [], []]. done_list: []
# Vertex 5 is colored 1. Possible neighbors colored 0: [[0], [6], [], [9], [], [], []]. done_list: [(2, 1)]
# Vertex 5 is colored 1. Possible neighbors colored 2: [[], [6], [], [9], [7], [], []]. done_list: [(2, 1)]
# Vertex 2 is colored None. Possible neighbors colored 2: [[1], [], [], [], [], [], []]. done_list: []
# Vertex 1 is colored 2. Possible neighbors colored 0: [[0], [8], [], [9], [], [], []]. done_list: [(2, 2)]
# ...
