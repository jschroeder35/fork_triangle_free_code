# %%
from graph_algs import *

# %%
###Set up starting graph
v_0 = vert([1, 4, 5], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1, 5], [], 2)
v_3 = vert([4, 2], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 2], [], 5)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5])
test_graph.clean()
print(test_graph.update_graph(lem3_6_list))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [0, 1, 5]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [1, 2, 5]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2]
#     Non-edges: [1, 3, 4]
#     Unknown:   []
#     Color:   None

# %%
###Proves a_2 is not adjacent to b
test_graph2=copy.deepcopy(test_graph)
new_vert=vert([0, 3], [], 6) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([1, 6], [], 7) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([7], [0, 1, 2, 3, 4], 8) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([4], [], 9) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8, 9], [0, 1, 2, 3, 4], 10) 
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
#test_graph2.update_graph3(lem3_6_list, verbose=True, min_subgraph=C_5) 
test_graph2.update_graph5(lem3_6_list, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='slow', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [2, 3, 8, 10, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 7]
#     Non-edges: [3, 4, 5, 8, 10, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 8, 10, 6, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 8, 10, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 5, 8, 10, 6, 7]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2]
#     Non-edges: [1, 3, 4, 6, 8, 10, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 5, 8, 10]
#     Unknown:   [9]
#     Color:   None
# Vertex 7:
#     Edges:     [1, 6, 8]
#     Non-edges: [0, 2, 3, 4, 10, 5]
#     Unknown:   [9]
#     Color:   None
# Vertex 8:
#     Edges:     [7, 10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [4, 10]
#     Non-edges: [0, 3, 8]
#     Unknown:   [1, 2, 5, 6, 7]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7]
#     Unknown:   []
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Non-edge added from 1 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [2, 3, 8, 10, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 7]
#     Non-edges: [3, 4, 5, 8, 10, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 8, 10, 6, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 8, 10, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 5, 8, 10, 6, 7]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2]
#     Non-edges: [1, 3, 4, 6, 8, 10, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 5, 8, 10]
#     Unknown:   [9]
#     Color:   None
# Vertex 7:
#     Edges:     [1, 6, 8]
#     Non-edges: [0, 2, 3, 4, 10, 5]
#     Unknown:   [9]
#     Color:   None
# Vertex 8:
#     Edges:     [7, 10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [4, 10]
#     Non-edges: [0, 3, 8, 1, 2]
#     Unknown:   [5, 6, 7]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7]
#     Unknown:   []
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 5<->9. Completion:     0.00%
# Checking 6<->9. Completion:    33.33%
# Non-edge added from 6 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [2, 3, 8, 10, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 7]
#     Non-edges: [3, 4, 5, 8, 10, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 8, 10, 6, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 8, 10, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 5, 8, 10, 6, 7]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2]
#     Non-edges: [1, 3, 4, 6, 8, 10, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 5, 8, 10, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [1, 6, 8]
#     Non-edges: [0, 2, 3, 4, 10, 5, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [7, 10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [4, 10]
#     Non-edges: [0, 3, 8, 1, 2, 6, 7]
#     Unknown:   [5]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7]
#     Unknown:   []
#     Color:   None
# There are 1 unknown edges in the graph to check
# Checking 5<->9. Completion:     0.00%
# Checking if N(0) is contained in N(2) and N(3)
# N(0) is contained in N(2) and N(3). Attempting coloring...
# Iteration: 1
# There are 11 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[], [4, 6], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 1: [[], [1, 5], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 2: [[], [1, 4, 5, 6], [], [], [], [], []]. done_list: []
# Checking if N(1) is contained in N(3) and N(6)
# Checking if N(1) is contained in N(5) and N(6)
# N(1) is contained in N(5) and N(6). Attempting coloring...
# Iteration: 1
# There are 11 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [7], [], [], [], [], []]. done_list: []
# Vertex 7 is colored 0. Possible neighbors colored 1: [[6], [8], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 7 is colored 0. Possible neighbors colored 2: [[], [8], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 8 is colored 2. Possible neighbors colored 0: [[], [10], [], [11], [], [], []]. done_list: [(1, 0), (7, 2)]
# Vertex 8 is colored 2. Possible neighbors colored 1: [[], [10], [], [11], [], [], []]. done_list: [(1, 0), (7, 2)]
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[5], [3], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[], [3], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 3 is colored 2. Possible neighbors colored 0: [[], [4], [], [], [], [], []]. done_list: [(1, 1), (2, 2)]
# Vertex 4 is colored 0. Possible neighbors colored 1: [[], [9], [], [], [], [], []]. done_list: [(1, 1), (2, 2), (3, 0)]
# Vertex 9 is colored 1. Possible neighbors colored 0: [[10], [], [], [], [5], [], []]. done_list: [(1, 1), (2, 2), (3, 0), (4, 1)]
# Vertex 9 is colored 1. Possible neighbors colored 2: [[], [], [], [], [], [], []]. done_list: [(1, 1), (2, 2), (3, 0), (4, 1)]
# True

# %%
###Proves contradiction when a_2 is not adjacent to b (and by symmetry, a_5 is not adjacent to a_1)
test_graph2=copy.deepcopy(test_graph)
new_vert=vert([0, 3], [], 6) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([1], [6], 7) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([7], [0, 1, 2, 3, 4], 8) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([4], [5], 9) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8, 9], [0, 1, 2, 3, 4], 10) 
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph5(lem3_6_list, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='slow', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [2, 3, 8, 10, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 7]
#     Non-edges: [3, 4, 5, 8, 10, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 8, 10, 6, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 8, 10, 9]
#     Unknown:   [7]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 5, 8, 10, 6]
#     Unknown:   [7]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2]
#     Non-edges: [1, 3, 4, 9, 6, 8, 10]
#     Unknown:   [7]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 4, 5, 8, 10]
#     Unknown:   [9]
#     Color:   None
# Vertex 7:
#     Edges:     [1, 8]
#     Non-edges: [6, 0, 2, 10]
#     Unknown:   [3, 4, 5, 9]
#     Color:   None
# Vertex 8:
#     Edges:     [7, 10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [4, 10]
#     Non-edges: [5, 0, 3, 8]
#     Unknown:   [1, 2, 6, 7]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7]
#     Unknown:   []
#     Color:   None
# There are 7 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Non-edge added from 1 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [2, 3, 8, 10, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 7]
#     Non-edges: [3, 4, 5, 8, 10, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 8, 10, 6, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 8, 10, 9]
#     Unknown:   [7]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 5, 8, 10, 6]
#     Unknown:   [7]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2]
#     Non-edges: [1, 3, 4, 9, 6, 8, 10]
#     Unknown:   [7]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 4, 5, 8, 10]
#     Unknown:   [9]
#     Color:   None
# Vertex 7:
#     Edges:     [1, 8]
#     Non-edges: [6, 0, 2, 10]
#     Unknown:   [3, 4, 5, 9]
#     Color:   None
# Vertex 8:
#     Edges:     [7, 10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [4, 10]
#     Non-edges: [5, 0, 3, 8, 1, 2]
#     Unknown:   [6, 7]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7]
#     Unknown:   []
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 3<->7. Completion:     0.00%
# Non-edge added from 3 to 7; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [2, 3, 8, 10, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 7]
#     Non-edges: [3, 4, 5, 8, 10, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 8, 10, 6, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 8, 10, 9, 7]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 5, 8, 10, 6, 7]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2]
#     Non-edges: [1, 3, 4, 9, 6, 8, 10]
#     Unknown:   [7]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 4, 5, 8, 10]
#     Unknown:   [9]
#     Color:   None
# Vertex 7:
#     Edges:     [1, 8]
#     Non-edges: [6, 0, 2, 10, 3, 4]
#     Unknown:   [5, 9]
#     Color:   None
# Vertex 8:
#     Edges:     [7, 10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [4, 10]
#     Non-edges: [5, 0, 3, 8, 1, 2]
#     Unknown:   [6, 7]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7]
#     Unknown:   []
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 5<->7. Completion:     0.00%
# Checking 6<->9. Completion:    33.33%
# Checking 7<->9. Completion:    66.67%
# Checking if N(0) is contained in N(2) and N(3)
# Checking if N(1) is contained in N(5) and N(8)
# N(1) is contained in N(5) and N(8). Attempting coloring...
# Iteration: 1
# There are 11 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [], [], [11], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0, 7], [], [], [], [], []]. done_list: []
# Iteration: 2
# There are 12 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[11], [], [], [], [], [], []]. done_list: []
# Vertex 11 is colored 0. Possible neighbors colored 1: [[8], [], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 8 is colored 1. Possible neighbors colored 0: [[], [10], [], [], [], [], []]. done_list: [(1, 0), (11, 1)]
# Vertex 10 is colored 0. Possible neighbors colored 1: [[], [9], [], [12], [], [], []]. done_list: [(1, 0), (11, 1), (8, 0)]
# Vertex 10 is colored 0. Possible neighbors colored 2: [[], [9], [], [12], [], [], []]. done_list: [(1, 0), (11, 1), (8, 0)]
# Vertex 8 is colored 1. Possible neighbors colored 2: [[], [7], [], [], [], [], []]. done_list: [(1, 0), (11, 1)]
# Vertex 7 is colored 2. Possible neighbors colored 0: [[], [], [], [], [], [1], []]. done_list: [(1, 0), (11, 1), (8, 2)]
# Vertex 7 is colored 2. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: [(1, 0), (11, 1), (8, 2)]
# True

# %%
###Showing a_1 is not adjacent to a_4 or a_5
test_graph2=copy.deepcopy(test_graph)
new_vert=vert([3, 5], [], 6) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([6], [0, 1, 2, 3, 4], 7) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([4], [], 8) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([1], [], 10) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([10], [0, 1, 2, 3, 4], 11) 
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
#test_graph2.update_graph3(lem3_7_list0, verbose=True, min_subgraph=C_5) 
test_graph2.update_graph5(lem3_7_list0, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='slow', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6]
#     Unknown:   [8]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10]
#     Unknown:   [8]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4, 7, 9, 11]
#     Unknown:   [8, 10]
#     Color:   None
# Vertex 6:
#     Edges:     [3, 5, 7]
#     Non-edges: [0, 2, 4, 1]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [0, 3]
#     Unknown:   [1, 2, 5, 6, 7, 10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 11]
#     Non-edges: [0, 2]
#     Unknown:   [3, 4, 5, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 18 unknown edges in the graph to check
# Checking 1<->8. Completion:     0.00%
# Non-edge added from 1 to 8; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4, 7, 9, 11]
#     Unknown:   [8, 10]
#     Color:   None
# Vertex 6:
#     Edges:     [3, 5, 7]
#     Non-edges: [0, 2, 4, 1]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [0, 3, 1, 2]
#     Unknown:   [5, 6, 7, 10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 11]
#     Non-edges: [0, 2]
#     Unknown:   [3, 4, 5, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 16 unknown edges in the graph to check
# Checking 3<->10. Completion:     0.00%
# Non-edge added from 3 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4, 7, 9, 11]
#     Unknown:   [8, 10]
#     Color:   None
# Vertex 6:
#     Edges:     [3, 5, 7]
#     Non-edges: [0, 2, 4, 1]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [0, 3, 1, 2]
#     Unknown:   [5, 6, 7, 10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 11]
#     Non-edges: [0, 2, 3, 4]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 14 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Non-edge added from 5 to 8; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4, 7, 9, 11, 8]
#     Unknown:   [10]
#     Color:   None
# Vertex 6:
#     Edges:     [3, 5, 7]
#     Non-edges: [0, 2, 4, 1]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [0, 3, 1, 2, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 11]
#     Non-edges: [0, 2, 3, 4]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 13 unknown edges in the graph to check
# Checking 5<->10. Completion:     0.00%
# Non-edge added from 5 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4, 7, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 5, 7]
#     Non-edges: [0, 2, 4, 1]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [0, 3, 1, 2, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 11]
#     Non-edges: [0, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 12 unknown edges in the graph to check
# Checking 6<->8. Completion:     0.00%
# Checking 6<->9. Completion:     8.33%
# Checking 6<->10. Completion:    16.67%
# Non-edge added from 6 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4, 7, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 5, 7]
#     Non-edges: [0, 2, 4, 1, 10]
#     Unknown:   [8, 9, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [0, 3, 1, 2, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 11]
#     Non-edges: [0, 2, 3, 4, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 11 unknown edges in the graph to check
# Checking 6<->8. Completion:     0.00%
# Checking 6<->9. Completion:     9.09%
# Checking 6<->11. Completion:    18.18%
# Checking 7<->8. Completion:    27.27%
# Checking 7<->9. Completion:    36.36%
# Checking 7<->10. Completion:    45.45%
# Checking 7<->11. Completion:    54.55%
# Checking 8<->10. Completion:    63.64%
# Non-edge added from 8 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4, 7, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 5, 7]
#     Non-edges: [0, 2, 4, 1, 10]
#     Unknown:   [8, 9, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [0, 3, 1, 2, 5, 10]
#     Unknown:   [6, 7, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 11]
#     Non-edges: [0, 2, 3, 4, 5, 6, 8]
#     Unknown:   [7, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 10 unknown edges in the graph to check
# Checking 8<->11. Completion:     0.00%
# Checking 9<->10. Completion:    10.00%
# Checking 9<->11. Completion:    20.00%
# Checking 6<->8. Completion:    30.00%
# Checking 6<->9. Completion:    40.00%
# Checking 6<->11. Completion:    50.00%
# Checking 7<->8. Completion:    60.00%
# Checking 7<->9. Completion:    70.00%
# Checking 7<->10. Completion:    80.00%
# Checking 7<->11. Completion:    90.00%
# Checking if N(0) is contained in N(2) and N(3)
# Checking if N(0) is contained in N(2) and N(8)
# Checking if 0 is degree 3.
# 0 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 0.
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[1], [], [], [], [], [], []]. done_list: []
# Vertex 1 is colored 0. Possible neighbors colored 1: [[2], [10], [], [], [], [], []]. done_list: [(0, 0)]
# Vertex 1 is colored 0. Possible neighbors colored 2: [[], [10], [], [], [], [], []]. done_list: [(0, 0)]
# Vertex 10 is colored 2. Possible neighbors colored 0: [[], [11], [7, 9], [12], [], [], []]. done_list: [(0, 0), (1, 2)]
# Vertex 10 is colored 2. Possible neighbors colored 1: [[], [11], [7, 9], [12], [], [], []]. done_list: [(0, 0), (1, 2)]
# Vertex 0 is colored None. Possible neighbors colored 1: [[4], [], [], [], [], [], []]. done_list: []
# Vertex 4 is colored 1. Possible neighbors colored 0: [[], [3, 8], [], [12], [], [], []]. done_list: [(0, 1)]
# Vertex 4 is colored 1. Possible neighbors colored 2: [[], [3, 8], [], [12], [], [], []]. done_list: [(0, 1)]
# Vertex 0 is colored None. Possible neighbors colored 2: [[5], [], [], [], [], [], []]. done_list: []
# Vertex 5 is colored 2. Possible neighbors colored 0: [[], [6], [], [12], [], [], []]. done_list: [(0, 2)]
# Vertex 5 is colored 2. Possible neighbors colored 1: [[2], [6], [], [12], [], [], []]. done_list: [(0, 2)]
# Iteration: 2
# There are 12 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[1], [], [], [], [], [], []]. done_list: []
# Vertex 1 is colored 0. Possible neighbors colored 1: [[2], [], [], [], [], [], []]. done_list: [(0, 0)]
# Vertex 2 is colored 1. Possible neighbors colored 0: [[], [], [], [12], [], [], []]. done_list: [(0, 0), (1, 1)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[3, 5], [], [], [], [], [], []]. done_list: [(0, 0), (1, 1)]
# Vertex 1 is colored 0. Possible neighbors colored 2: [[10], [], [], [], [], [], []]. done_list: [(0, 0)]
# Vertex 10 is colored 2. Possible neighbors colored 0: [[12], [11], [7], [13], [], [], []]. done_list: [(0, 0), (1, 2)]
# Vertex 10 is colored 2. Possible neighbors colored 1: [[], [11], [], [], [], [], []]. done_list: [(0, 0), (1, 2)]
# Vertex 11 is colored 1. Possible neighbors colored 0: [[], [], [9], [13], [], [], []]. done_list: [(0, 0), (1, 2), (10, 1)]
# Vertex 11 is colored 1. Possible neighbors colored 2: [[], [], [9], [13], [], [], []]. done_list: [(0, 0), (1, 2), (10, 1)]
# Vertex 0 is colored None. Possible neighbors colored 1: [[4], [], [], [], [], [], []]. done_list: []
# Vertex 4 is colored 1. Possible neighbors colored 0: [[], [8], [], [13], [], [], []]. done_list: [(0, 1)]
# Vertex 4 is colored 1. Possible neighbors colored 2: [[3], [8], [], [13], [], [], []]. done_list: [(0, 1)]
# Vertex 0 is colored None. Possible neighbors colored 2: [[5], [], [], [], [], [], []]. done_list: []
# Vertex 5 is colored 2. Possible neighbors colored 0: [[], [6], [], [], [], [], []]. done_list: [(0, 2)]
# Vertex 6 is colored 0. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: [(0, 2), (5, 0)]
# 0 Must have degree at least 4; adding a new neighbor and updating...
# Vertex 0:
#     Edges:     [1, 4, 5, 12]
#     Non-edges: [2, 3, 7, 9, 11, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6, 8, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10, 8]
#     Unknown:   [12]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8, 10, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6, 10, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 6]
#     Non-edges: [1, 3, 4, 7, 9, 11, 8, 10, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 5, 7]
#     Non-edges: [0, 2, 4, 1, 10, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5, 12, 10]
#     Unknown:   [8, 9, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [0, 3, 1, 2, 5, 10]
#     Unknown:   [6, 7, 11, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 12, 6]
#     Unknown:   [7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 11, 12]
#     Non-edges: [0, 2, 3, 4, 5, 6, 8, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 12, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# Vertex 12:
#     Edges:     [0, 10]
#     Non-edges: [1, 4, 5, 11, 3, 7, 9, 6]
#     Unknown:   [2, 8]
#     Color:   None
# Checking if N(1) is contained in N(3) and N(12)
# N(1) is contained in N(3) and N(12). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [0, 10], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[3], [5], [], [13], [], [], []]. done_list: [(1, 1)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[], [5], [], [13], [], [], []]. done_list: [(1, 1)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [0, 10], [], [], [], [], []]. done_list: []
# Iteration: 2
# There are 13 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [0, 10], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[3], [5], [], [13], [], [], []]. done_list: [(1, 1)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[], [5], [], [13], [], [], []]. done_list: [(1, 1)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [0, 10], [], [], [], [], []]. done_list: []
# Checking if N(1) is contained in N(5) and N(11)
# N(1) is contained in N(5) and N(11). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [10], [], [], [], [], []]. done_list: []
# Vertex 10 is colored 0. Possible neighbors colored 1: [[11], [12], [9], [13], [], [], []]. done_list: [(1, 0)]
# Vertex 10 is colored 0. Possible neighbors colored 2: [[], [12], [9], [13], [], [], []]. done_list: [(1, 0)]
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0], [], [], [], [], []]. done_list: []
# Iteration: 2
# There are 13 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[10], [], [], [], [], [], []]. done_list: []
# Vertex 10 is colored 0. Possible neighbors colored 1: [[11], [12], [9], [13], [], [], []]. done_list: [(1, 0)]
# Vertex 10 is colored 0. Possible neighbors colored 2: [[], [12], [9], [13], [], [], []]. done_list: [(1, 0)]
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0], [], [], [], [], []]. done_list: []
# Checking if N(1) is contained in N(5) and N(12)
# N(1) is contained in N(5) and N(12). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [10], [], [], [], [], []]. done_list: []
# Vertex 10 is colored 0. Possible neighbors colored 1: [[12], [11], [9], [13], [], [], []]. done_list: [(1, 0)]
# Vertex 10 is colored 0. Possible neighbors colored 2: [[], [11], [9], [13], [], [], []]. done_list: [(1, 0)]
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[5], [3], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[], [3], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 3 is colored 2. Possible neighbors colored 0: [[], [4], [], [13], [], [], []]. done_list: [(1, 1), (2, 2)]
# Vertex 3 is colored 2. Possible neighbors colored 1: [[6], [4], [], [13], [], [], []]. done_list: [(1, 1), (2, 2)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 2. Possible neighbors colored 0: [[5], [4], [], [], [], [], []]. done_list: [(1, 2)]
# Vertex 0 is colored 2. Possible neighbors colored 1: [[12], [4], [], [], [], [], []]. done_list: [(1, 2)]
# Iteration: 2
# There are 13 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[10], [], [], [], [], [], []]. done_list: []
# Vertex 10 is colored 0. Possible neighbors colored 1: [[12], [11], [9], [13], [], [], []]. done_list: [(1, 0)]
# Vertex 10 is colored 0. Possible neighbors colored 2: [[], [11], [9], [13], [], [], []]. done_list: [(1, 0)]
# Vertex 1 is colored None. Possible neighbors colored 1: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[5], [], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 5 is colored 0. Possible neighbors colored 1: [[6], [], [], [], [], [], []]. done_list: [(1, 1), (2, 0)]
# Vertex 6 is colored 1. Possible neighbors colored 0: [[], [7], [8], [13], [], [], []]. done_list: [(1, 1), (2, 0), (5, 1)]
# Vertex 6 is colored 1. Possible neighbors colored 2: [[3], [7], [8], [13], [], [], []]. done_list: [(1, 1), (2, 0), (5, 1)]
# Vertex 5 is colored 0. Possible neighbors colored 2: [[0], [], [], [], [], [], []]. done_list: [(1, 1), (2, 0)]
# Vertex 0 is colored 2. Possible neighbors colored 0: [[], [4], [], [], [], [], []]. done_list: [(1, 1), (2, 0), (5, 2)]
# Vertex 4 is colored 0. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: [(1, 1), (2, 0), (5, 2), (0, 0)]
# True

# %%
###Showing that a_1 cannot be adjacent to a_2
test_graph2=copy.deepcopy(test_graph)
new_vert=vert([3], [5], 6) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([6], [0, 1, 2, 3, 4], 7) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([4], [5], 8) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([1, 5], [], 10) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([10], [0, 1, 2, 3, 4], 11) 
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph5(lem3_7_list0, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='slow', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 8, 10]
#     Unknown:   [6]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11]
#     Unknown:   [6, 8]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10]
#     Unknown:   [8]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 10]
#     Non-edges: [1, 3, 4, 6, 8, 7, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 7]
#     Non-edges: [5, 2, 4]
#     Unknown:   [0, 1, 8, 9, 10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [5, 0, 3]
#     Unknown:   [1, 2, 6, 7, 10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 5, 11]
#     Non-edges: [0, 2]
#     Unknown:   [3, 4, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 18 unknown edges in the graph to check
# Checking 0<->6. Completion:     0.00%
# Non-edge added from 0 to 6; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 8, 10, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6]
#     Unknown:   [8]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10]
#     Unknown:   [8]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 10]
#     Non-edges: [1, 3, 4, 6, 8, 7, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 7]
#     Non-edges: [5, 2, 4, 0, 1]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [5, 0, 3]
#     Unknown:   [1, 2, 6, 7, 10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 5, 11]
#     Non-edges: [0, 2]
#     Unknown:   [3, 4, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 16 unknown edges in the graph to check
# Checking 1<->8. Completion:     0.00%
# Non-edge added from 1 to 8; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 8, 10, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 10]
#     Non-edges: [1, 3, 4, 6, 8, 7, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 7]
#     Non-edges: [5, 2, 4, 0, 1]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [5, 0, 3, 1, 2]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 5, 11]
#     Non-edges: [0, 2]
#     Unknown:   [3, 4, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 14 unknown edges in the graph to check
# Checking 3<->10. Completion:     0.00%
# Non-edge added from 3 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 8, 10, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 10]
#     Non-edges: [1, 3, 4, 6, 8, 7, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 7]
#     Non-edges: [5, 2, 4, 0, 1]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [5, 0, 3, 1, 2]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 5, 11]
#     Non-edges: [0, 2, 3, 4]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# There are 12 unknown edges in the graph to check
# Checking 6<->8. Completion:     0.00%
# Checking 6<->9. Completion:     8.33%
# Checking 6<->10. Completion:    16.67%
# Checking 6<->11. Completion:    25.00%
# Checking 7<->8. Completion:    33.33%
# Checking 7<->9. Completion:    41.67%
# Checking 7<->10. Completion:    50.00%
# Checking 7<->11. Completion:    58.33%
# Checking 8<->10. Completion:    66.67%
# Checking 8<->11. Completion:    75.00%
# Checking 9<->10. Completion:    83.33%
# Checking 9<->11. Completion:    91.67%
# Vertex 12 added adjacent to 1 that cannot be in N(5)!
# Vertex 13 added adjacent to 5 that cannot be in N(1)!
# Setting up and and initial greedy updates...
# Contradiction obtained in initial updates.
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 7, 9, 11, 8, 10, 6, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10, 12]
#     Non-edges: [3, 4, 5, 7, 9, 11, 6, 8, 13]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [0, 4, 7, 9, 11, 6, 10, 8, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [0, 1, 5, 7, 9, 11, 8, 10]
#     Unknown:   [12, 13]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [1, 2, 5, 7, 9, 11, 6, 10]
#     Unknown:   [12, 13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 10, 13]
#     Non-edges: [1, 3, 4, 6, 8, 7, 9, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 7]
#     Non-edges: [5, 2, 4, 0, 1]
#     Unknown:   [8, 9, 10, 11, 12, 13]
#     Color:   None
# Vertex 7:
#     Edges:     [6]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [8, 9, 10, 11, 12, 13]
#     Color:   None
# Vertex 8:
#     Edges:     [4, 9]
#     Non-edges: [5, 0, 3, 1, 2]
#     Unknown:   [6, 7, 10, 11, 12, 13]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 10, 11, 12, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [1, 5, 11]
#     Non-edges: [0, 2, 3, 4, 12, 13]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [6, 7, 8, 9, 12, 13]
#     Color:   None
# Vertex 12:
#     Edges:     [1]
#     Non-edges: [5, 0, 2, 10]
#     Unknown:   [3, 4, 6, 7, 8, 9, 11, 13]
#     Color:   None
# Vertex 13:
#     Edges:     [5]
#     Non-edges: [1, 0, 2, 10]
#     Unknown:   [3, 4, 6, 7, 8, 9, 11, 12]
#     Color:   None
# True
