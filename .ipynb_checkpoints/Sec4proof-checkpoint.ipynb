# %%
from graph_algs import *

# %%
# Set up starting graph
v_0 = vert([1, 4], [], 0)  # v_1
v_1 = vert([2, 0], [], 1)  # v_2
v_2 = vert([3, 1], [], 2)  # v_3
v_3 = vert([4, 2], [], 3)  # v_4
v_4 = vert([0, 3], [], 4)  # v_5
v_5 = vert([0], [], 5)  # a_1
v_6 = vert([1], [], 6)  # a_2
v_7 = vert([2], [], 7)  # a_3
v_8 = vert([3], [], 8)  # a_4
v_9 = vert([4], [], 9)  # a_5
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7, v_8, v_9])
test_graph.update_graph3(lem3_7_list)
test_graph.show()
# Out:
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [2, 3, 6, 9, 7, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 6]
#     Non-edges: [3, 4, 5, 7, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 7]
#     Non-edges: [0, 4, 6, 8, 9, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 8]
#     Non-edges: [0, 1, 7, 9, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 5, 8, 7, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0]
#     Non-edges: [1, 4, 2, 3]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [1]
#     Non-edges: [0, 2, 3, 4]
#     Unknown:   [5, 7, 8, 9]
#     Color:   None
# Vertex 7:
#     Edges:     [2]
#     Non-edges: [1, 3, 0, 4]
#     Unknown:   [5, 6, 8, 9]
#     Color:   None
# Vertex 8:
#     Edges:     [3]
#     Non-edges: [2, 4, 0, 1]
# ...

# %% [markdown]
# CASE 2

# %%
# Completes case 2
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[3].max_degree=3
test_graph2.vertex_list[4].max_degree=3
new_vert=vert([0, 9], [], 10)  # b_1
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph4(lem3_7_list, verbose=True, min_subgraph=C_5) 
test_graph2.vertex_list[0].color=1
test_graph2.vertex_list[1].color=2
test_graph2.vertex_list[2].color=1
test_graph2.vertex_list[3].color=0
test_graph2.vertex_list[4].color_start=True
test_graph2.vertex_list[5].color=2
test_graph2.vertex_list[9].color=2
test_graph2.color_argument_iter(lem3_7_list, 4, 10, 
        min_subgraph=C_5, carg_update_speed='slow')
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 10]
#     Non-edges: [2, 3, 6, 9, 7, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 6]
#     Non-edges: [3, 4, 5, 7, 8, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 7]
#     Non-edges: [0, 4, 6, 8, 9, 5, 10]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 8]
#     Non-edges: [0, 1, 3, 5, 6, 7, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 4, 5, 6, 7, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0]
#     Non-edges: [1, 4, 2, 3, 10]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [1]
#     Non-edges: [0, 2, 3, 4]
#     Unknown:   [5, 7, 8, 9, 10]
#     Color:   None
# Vertex 7:
#     Edges:     [2]
#     Non-edges: [1, 3, 0, 4]
#     Unknown:   [5, 6, 8, 9, 10]
#     Color:   None
# ...

# %% [markdown]
# CASE 3

# %%
# Shows contradiction when a_3 is not adjacent to b_4
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[1].max_degree=3
test_graph2.vertex_list[4].max_degree=3
new_vert=vert([0, 9], [], 10)  # b_1
test_graph2.vertex_list.append(new_vert)
new_vert=vert([2, 6], [], 11)  # b_3
test_graph2.vertex_list.append(new_vert)
new_vert=vert([3, 9], [], 12)  # b_4
test_graph2.vertex_list.append(new_vert)
test_graph2.vertex_list[7].non_edges.append(12)
test_graph2.clean()
test_graph2.update_graph5(lem3_7_list, verbose=True, min_subgraph=C_5, 
        update_speed='medium', carg_update_speed='slow', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 10]
#     Non-edges: [2, 3, 6, 9, 7, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 6]
#     Non-edges: [1, 3, 4, 5, 7, 8, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 7, 11]
#     Non-edges: [0, 4, 6, 8, 9, 5, 12]
#     Unknown:   [10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 8, 12]
#     Non-edges: [0, 1, 7, 9, 5, 6, 11]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 4, 5, 6, 7, 8, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0]
#     Non-edges: [1, 4, 2, 3, 10]
#     Unknown:   [6, 7, 8, 9, 11, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [1, 11]
#     Non-edges: [0, 2, 3, 4, 12, 8]
#     Unknown:   [5, 7, 9, 10]
#     Color:   None
# Vertex 7:
#     Edges:     [2, 8]
# ...

# %%
# Shows contradiction when a_3 is adjacent to b_4
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[1].max_degree=3
test_graph2.vertex_list[4].max_degree=3
new_vert=vert([0, 9], [], 10)  # b_1
test_graph2.vertex_list.append(new_vert)
new_vert=vert([2, 6], [], 11)  # b_3
test_graph2.vertex_list.append(new_vert)
new_vert=vert([3, 9], [], 12)  # b_4
test_graph2.vertex_list.append(new_vert)
test_graph2.vertex_list[7].edges.append(12)
test_graph2.clean()
test_graph2.update_graph5(lem3_7_list, verbose=True, min_subgraph=C_5, 
        update_speed='medium', carg_update_speed='slow', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 10]
#     Non-edges: [2, 3, 6, 9, 7, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 6]
#     Non-edges: [1, 3, 4, 5, 7, 8, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 7, 11]
#     Non-edges: [0, 4, 6, 8, 9, 5, 12]
#     Unknown:   [10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 8, 12]
#     Non-edges: [0, 1, 7, 9, 5, 6, 11]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 4, 5, 6, 7, 8, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0]
#     Non-edges: [1, 4, 2, 3, 10]
#     Unknown:   [6, 7, 8, 9, 11, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [1, 11]
#     Non-edges: [0, 2, 3, 4, 8, 12]
#     Unknown:   [5, 7, 9, 10]
#     Color:   None
# Vertex 7:
#     Edges:     [2, 12]
# ...
