# %%
from graph_algs import *

# %%
# Set up starting graph
v_0 = vert([1, 4, 5, 6], [], 0)  # v_1
v_1 = vert([2, 0], [], 1)  # v_2
v_2 = vert([3, 1], [], 2)  # v_3
v_3 = vert([4, 2], [], 3)  # v_4
v_4 = vert([0, 3], [], 4)  # v_5
v_5 = vert([0, 7, 8], [], 5)  # a_1
v_6 = vert([0, 7, 8], [], 6)  # b_1
v_7 = vert([5, 6, 9], [0, 1, 2, 3, 4], 7)  # u_1
v_8 = vert([5, 6, 10], [0, 1, 2, 3, 4], 8)  # u_2
v_9 = vert([7], [8], 9)  # x_1
v_10 = vert([8], [7], 10)  # x_2
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7, v_8, v_9, v_10])
test_graph.update_graph(lem2_4_list)
test_graph.show()
# Out:
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4]
#     Unknown:   [5, 6, 9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1]
#     Unknown:   [5, 6, 9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 9, 10]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 5, 9, 10]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6]
#     Unknown:   [0, 1, 2, 3, 4, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6]
#     Unknown:   [0, 1, 2, 3, 4, 9]
#     Color:   None

# %%
# Update the starting graph as much as we can
test_graph.update_graph4(lem2_4_list, verbose=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4]
#     Unknown:   [5, 6, 9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1]
#     Unknown:   [5, 6, 9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 9, 10]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 5, 9, 10]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6]
#     Unknown:   [0, 1, 2, 3, 4, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6]
#     Unknown:   [0, 1, 2, 3, 4, 9]
#     Color:   None
# There are 15 unknown edges in the graph to check
# Checking 0<->9. Completion:     0.00%
# Non-edge added from 0 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4]
#     Unknown:   [5, 6, 9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1]
#     Unknown:   [5, 6, 9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 9, 10]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 5, 9, 10]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6]
#     Unknown:   [0, 1, 2, 3, 4, 9]
#     Color:   None
# There are 14 unknown edges in the graph to check
# Checking 0<->10. Completion:     0.00%
# Non-edge added from 0 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4]
#     Unknown:   [5, 6, 9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1]
#     Unknown:   [5, 6, 9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 9, 10]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 5, 9, 10]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9]
#     Color:   None
# There are 13 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Checking 1<->10. Completion:     7.69%
# Checking 2<->5. Completion:    15.38%
# Non-edge added from 2 to 5; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   [6, 9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1]
#     Unknown:   [5, 6, 9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 9, 10, 2]
#     Unknown:   [3]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 5, 9, 10]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9]
#     Color:   None
# There are 12 unknown edges in the graph to check
# Checking 2<->6. Completion:     0.00%
# Non-edge added from 2 to 6; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1]
#     Unknown:   [5, 6, 9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 9, 10, 2]
#     Unknown:   [3]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 5, 9, 10, 2]
#     Unknown:   [3]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9]
#     Color:   None
# There are 11 unknown edges in the graph to check
# Checking 2<->9. Completion:     0.00%
# Checking 2<->10. Completion:     9.09%
# Checking 3<->5. Completion:    18.18%
# Non-edge added from 3 to 5; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5]
#     Unknown:   [6, 9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 5, 9, 10, 2]
#     Unknown:   [3]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9]
#     Color:   None
# There are 10 unknown edges in the graph to check
# Checking 3<->6. Completion:     0.00%
# Non-edge added from 3 to 6; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9]
#     Color:   None
# There are 9 unknown edges in the graph to check
# Checking 3<->9. Completion:     0.00%
# Checking 3<->10. Completion:    11.11%
# Checking 4<->9. Completion:    22.22%
# Checking 4<->10. Completion:    33.33%
# Checking 9<->10. Completion:    44.44%
# Checking 1<->9. Completion:    55.56%
# Checking 1<->10. Completion:    66.67%
# Checking 2<->9. Completion:    77.78%
# Checking 2<->10. Completion:    88.89%
# Vertex 11 added adjacent to 5 that cannot be in N(6)!
# Vertex 12 added adjacent to 6 that cannot be in N(5)!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5]
#     Non-edges: [6, 0, 7, 8]
#     Unknown:   [1, 2, 3, 4, 9, 10, 12]
#     Color:   None
# Vertex 12:
#     Edges:     [6]
#     Non-edges: [5, 0, 7, 8]
#     Unknown:   [1, 2, 3, 4, 9, 10, 11]
#     Color:   None
# There are 22 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Checking 1<->10. Completion:     4.55%
# Checking 1<->11. Completion:     9.09%
# Checking 1<->12. Completion:    13.64%
# Checking 2<->9. Completion:    18.18%
# Checking 2<->10. Completion:    22.73%
# Checking 2<->11. Completion:    27.27%
# Non-edge added from 2 to 11; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11]
#     Unknown:   [9, 10, 12]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5]
#     Non-edges: [6, 0, 7, 8, 2]
#     Unknown:   [1, 3, 4, 9, 10, 12]
#     Color:   None
# Vertex 12:
#     Edges:     [6]
#     Non-edges: [5, 0, 7, 8]
#     Unknown:   [1, 2, 3, 4, 9, 10, 11]
#     Color:   None
# There are 21 unknown edges in the graph to check
# Checking 2<->9. Completion:     0.00%
# Checking 2<->10. Completion:     4.76%
# Checking 2<->12. Completion:     9.52%
# Non-edge added from 2 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5]
#     Non-edges: [6, 0, 7, 8, 2]
#     Unknown:   [1, 3, 4, 9, 10, 12]
#     Color:   None
# Vertex 12:
#     Edges:     [6]
#     Non-edges: [5, 0, 7, 8, 2]
#     Unknown:   [1, 3, 4, 9, 10, 11]
#     Color:   None
# There are 20 unknown edges in the graph to check
# Checking 2<->9. Completion:     0.00%
# Checking 2<->10. Completion:     5.00%
# Checking 3<->9. Completion:    10.00%
# Checking 3<->10. Completion:    15.00%
# Checking 3<->11. Completion:    20.00%
# Non-edge added from 3 to 11; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11]
#     Unknown:   [9, 10, 12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5]
#     Non-edges: [6, 0, 7, 8, 2, 3]
#     Unknown:   [1, 4, 9, 10, 12]
#     Color:   None
# Vertex 12:
#     Edges:     [6]
#     Non-edges: [5, 0, 7, 8, 2]
#     Unknown:   [1, 3, 4, 9, 10, 11]
#     Color:   None
# There are 19 unknown edges in the graph to check
# Checking 3<->9. Completion:     0.00%
# Checking 3<->10. Completion:     5.26%
# Checking 3<->12. Completion:    10.53%
# Non-edge added from 3 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5]
#     Non-edges: [6, 0, 7, 8, 2, 3]
#     Unknown:   [1, 4, 9, 10, 12]
#     Color:   None
# Vertex 12:
#     Edges:     [6]
#     Non-edges: [5, 0, 7, 8, 2, 3]
#     Unknown:   [1, 4, 9, 10, 11]
#     Color:   None
# There are 18 unknown edges in the graph to check
# Checking 3<->9. Completion:     0.00%
# Checking 3<->10. Completion:     5.56%
# Checking 4<->9. Completion:    11.11%
# Checking 4<->10. Completion:    16.67%
# Checking 4<->11. Completion:    22.22%
# Checking 4<->12. Completion:    27.78%
# Checking 9<->10. Completion:    33.33%
# Checking 9<->11. Completion:    38.89%
# Checking 9<->12. Completion:    44.44%
# Checking 10<->11. Completion:    50.00%
# Checking 10<->12. Completion:    55.56%
# Checking 11<->12. Completion:    61.11%
# Non-edge added from 11 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10, 11, 12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12]
#     Unknown:   [1, 4, 9, 10]
#     Color:   None
# Vertex 12:
#     Edges:     [6]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11]
#     Unknown:   [1, 4, 9, 10]
#     Color:   None
# There are 17 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Checking 1<->10. Completion:     5.88%
# Checking 1<->11. Completion:    11.76%
# Checking 1<->12. Completion:    17.65%
# Checking 2<->9. Completion:    23.53%
# Checking 2<->10. Completion:    29.41%
# Checking 3<->9. Completion:    35.29%
# Checking 3<->10. Completion:    41.18%
# Checking 4<->9. Completion:    47.06%
# Checking 4<->10. Completion:    52.94%
# Checking 4<->11. Completion:    58.82%
# Checking 4<->12. Completion:    64.71%
# Checking 9<->10. Completion:    70.59%
# Checking 9<->11. Completion:    76.47%
# Checking 9<->12. Completion:    82.35%
# Checking 10<->11. Completion:    88.24%
# Checking 10<->12. Completion:    94.12%
# False

# %%
# Suppose that c1 is adjacent to both v1 and v4 and update
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[11].edges.append(1)
test_graph2.vertex_list[11].edges.append(4)
test_graph2.clean()
test_graph2.update_graph5(lem2_4_2_list, verbose=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 11]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10, 12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10, 12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7, 10]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 1, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 12:
#     Edges:     [6]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11]
#     Unknown:   [1, 4, 9, 10]
#     Color:   None
# There are 14 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Non-edge added from 1 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 11, 12]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10, 12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7, 10]
#     Non-edges: [8, 5, 6, 0, 1]
#     Unknown:   [2, 3, 4, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 1, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 12:
#     Edges:     [6, 1]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11]
#     Unknown:   [4, 9, 10]
#     Color:   None
# There are 12 unknown edges in the graph to check
# Checking 1<->10. Completion:     0.00%
# Non-edge added from 1 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 11, 12]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10, 12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7, 10]
#     Non-edges: [8, 5, 6, 0, 1]
#     Unknown:   [2, 3, 4, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [7, 5, 6, 0, 1]
#     Unknown:   [2, 3, 4, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 1, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 12:
#     Edges:     [6, 1]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11]
#     Unknown:   [4, 9, 10]
#     Color:   None
# There are 11 unknown edges in the graph to check
# Checking 2<->9. Completion:     0.00%
# Checking 2<->10. Completion:     9.09%
# Checking 3<->9. Completion:    18.18%
# Checking 3<->10. Completion:    27.27%
# Checking 4<->9. Completion:    36.36%
# Non-edge added from 4 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 11, 12]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11, 12]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7, 10]
#     Non-edges: [8, 5, 6, 0, 1, 4]
#     Unknown:   [2, 3, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [7, 5, 6, 0, 1]
#     Unknown:   [2, 3, 4, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 1, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 12:
#     Edges:     [6, 1, 4]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11]
#     Unknown:   [9, 10]
#     Color:   None
# There are 9 unknown edges in the graph to check
# Checking 4<->10. Completion:     0.00%
# Non-edge added from 4 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 11, 12]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11, 12]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7, 10]
#     Non-edges: [8, 5, 6, 0, 1, 4]
#     Unknown:   [2, 3, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [7, 5, 6, 0, 1, 4]
#     Unknown:   [2, 3, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 1, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 12:
#     Edges:     [6, 1, 4]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11]
#     Unknown:   [9, 10]
#     Color:   None
# There are 8 unknown edges in the graph to check
# Checking 9<->11. Completion:     0.00%
# Non-edge added from 9 to 11; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 11, 12]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11, 12]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7, 10]
#     Non-edges: [8, 5, 6, 0, 1, 4, 11]
#     Unknown:   [2, 3, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [7, 5, 6, 0, 1, 4, 11]
#     Unknown:   [2, 3, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 1, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [6, 1, 4]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11]
#     Unknown:   [9, 10]
#     Color:   None
# There are 6 unknown edges in the graph to check
# Checking 9<->12. Completion:     0.00%
# Non-edge added from 9 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 11, 12]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11, 12]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7, 10]
#     Non-edges: [8, 5, 6, 0, 1, 4, 11, 12]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [7, 5, 6, 0, 1, 4, 11, 12]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 1, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [6, 1, 4]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11, 9, 10]
#     Unknown:   []
#     Color:   None
# There are 4 unknown edges in the graph to check
# Checking 2<->9. Completion:     0.00%
# Checking 2<->10. Completion:    25.00%
# Checking 3<->9. Completion:    50.00%
# Checking 3<->10. Completion:    75.00%
# Vertex 13 added adjacent to 11 that cannot be in N(0)!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 11, 12]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10, 13]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10, 13]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11, 12]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11, 13]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9, 13]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10, 13]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7, 10]
#     Non-edges: [8, 5, 6, 0, 1, 4, 11, 12, 13]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [7, 5, 6, 0, 1, 4, 11, 12, 13]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 1, 4, 13]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [6, 1, 4, 13]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [11, 7, 8, 12]
#     Non-edges: [0, 1, 4, 5, 6, 9, 10]
#     Unknown:   [2, 3]
#     Color:   None
# There are 6 unknown edges in the graph to check
# Checking 2<->9. Completion:     0.00%
# Checking 2<->10. Completion:    16.67%
# Checking 2<->13. Completion:    33.33%
# Non-edge added from 2 to 13; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 11, 12]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12, 13]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12, 13]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11, 12]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11, 13]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9, 13]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10, 13]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7, 10]
#     Non-edges: [8, 5, 6, 0, 1, 4, 11, 12, 13]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [7, 5, 6, 0, 1, 4, 11, 12, 13]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 1, 4, 13]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [6, 1, 4, 13]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [11, 7, 8, 12]
#     Non-edges: [0, 1, 4, 5, 6, 9, 10, 2, 3]
#     Unknown:   []
#     Color:   None
# There are 4 unknown edges in the graph to check
# Checking 2<->9. Completion:     0.00%
# Checking 2<->10. Completion:    25.00%
# Checking 3<->9. Completion:    50.00%
# Checking 3<->10. Completion:    75.00%
# Checking if N(0) is contained in N(7) and N(11)
# N(0) is contained in N(7) and N(11). Attempting coloring...
# Iteration: 1
# There are 14 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[], [1, 4], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: []
# True

# %%
# Checking the case in which c1 \sim v4 and c2 \sim v1
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[11].edges.append(4)
test_graph2.vertex_list[11].non_edges.append(1)
test_graph2.vertex_list[12].edges.append(1)
test_graph2.vertex_list[12].non_edges.append(4)
test_graph2.clean()
test_graph2.update_graph5(lem2_4_2_list, verbose=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 12]
#     Non-edges: [7, 8, 3, 4, 5, 6, 11, 10, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11]
#     Non-edges: [7, 8, 1, 2, 5, 6, 12, 10, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7, 11, 12]
#     Non-edges: [8, 5, 6, 0, 1, 4, 10]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 11, 12]
#     Non-edges: [7, 5, 6, 0, 1, 4, 9]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 4, 10, 9]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12, 1]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [6, 1, 10, 9]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11, 4]
#     Unknown:   []
#     Color:   None
# There are 4 unknown edges in the graph to check
# Checking 2<->9. Completion:     0.00%
# Checking 2<->10. Completion:    25.00%
# Checking 3<->9. Completion:    50.00%
# Checking 3<->10. Completion:    75.00%
# Checking if N(0) is contained in N(11) and N(12)
# N(0) is contained in N(11) and N(12). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[], [1, 6], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 1: [[], [4, 5], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 2: [[], [1, 4, 5, 6], [], [], [], [], []]. done_list: []
# Checking if N(1) is contained in N(3) and N(6)
# N(1) is contained in N(3) and N(6). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [0, 12], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[3], [], [9, 10], [13], [], [], []]. done_list: [(1, 1)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[], [], [9, 10], [13], [], [], []]. done_list: [(1, 1)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [0, 12], [], [13], [], [], []]. done_list: []
# Iteration: 2
# There are 13 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [0, 12], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[3], [], [9, 10], [13], [], [], []]. done_list: [(1, 1)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[], [], [9, 10], [13], [], [], []]. done_list: [(1, 1)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [0, 12], [], [13], [], [], []]. done_list: []
# Checking if N(2) is contained in N(4) and N(12)
# Checking if N(3) is contained in N(1) and N(11)
# Checking if N(4) is contained in N(2) and N(5)
# N(4) is contained in N(2) and N(5). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 4 is colored None. Possible neighbors colored 0: [[], [0, 11], [], [], [], [], []]. done_list: []
# Vertex 4 is colored None. Possible neighbors colored 1: [[], [3], [], [], [], [], []]. done_list: []
# Vertex 3 is colored 1. Possible neighbors colored 0: [[2], [], [9, 10], [13], [], [], []]. done_list: [(4, 1)]
# Vertex 3 is colored 1. Possible neighbors colored 2: [[], [], [9, 10], [13], [], [], []]. done_list: [(4, 1)]
# Vertex 4 is colored None. Possible neighbors colored 2: [[], [0, 11], [], [13], [], [], []]. done_list: []
# Iteration: 2
# There are 13 vertices in the graph.
# Vertex 4 is colored None. Possible neighbors colored 0: [[], [0, 11], [], [], [], [], []]. done_list: []
# Vertex 4 is colored None. Possible neighbors colored 1: [[3], [], [], [], [], [], []]. done_list: []
# Vertex 3 is colored 1. Possible neighbors colored 0: [[2], [], [9, 10], [13], [], [], []]. done_list: [(4, 1)]
# Vertex 3 is colored 1. Possible neighbors colored 2: [[], [], [9, 10], [13], [], [], []]. done_list: [(4, 1)]
# Vertex 4 is colored None. Possible neighbors colored 2: [[], [0, 11], [], [13], [], [], []]. done_list: []
# Checking if N(5) is contained in N(4) and N(6)
# N(5) is contained in N(4) and N(6). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [7, 8], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [11], [], [], [], [], []]. done_list: []
# Vertex 11 is colored 1. Possible neighbors colored 0: [[4], [10, 9], [], [13], [], [], []]. done_list: [(5, 1)]
# Vertex 11 is colored 1. Possible neighbors colored 2: [[], [10, 9], [], [13], [], [], []]. done_list: [(5, 1)]
# Vertex 5 is colored None. Possible neighbors colored 2: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 2. Possible neighbors colored 0: [[4], [], [], [], [], [], []]. done_list: [(5, 2)]
# Vertex 4 is colored 0. Possible neighbors colored 1: [[11], [3], [], [], [], [], []]. done_list: [(5, 2), (0, 0)]
# Vertex 4 is colored 0. Possible neighbors colored 2: [[], [3], [], [], [], [], []]. done_list: [(5, 2), (0, 0)]
# Vertex 3 is colored 2. Possible neighbors colored 0: [[2], [], [], [13], [], [], []]. done_list: [(5, 2), (0, 0), (4, 2)]
# Vertex 3 is colored 2. Possible neighbors colored 1: [[], [], [], [13], [], [], []]. done_list: [(5, 2), (0, 0), (4, 2)]
# Vertex 0 is colored 2. Possible neighbors colored 1: [[1, 6], [], [], [], [], [], []]. done_list: [(5, 2)]
# Iteration: 2
# There are 14 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[7, 8], [], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[11], [], [], [], [], [], []]. done_list: []
# Vertex 11 is colored 1. Possible neighbors colored 0: [[4], [], [], [], [], [], []]. done_list: [(5, 1)]
# Vertex 4 is colored 0. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: [(5, 1), (11, 0)]
# True

# %%
# Checking the case in which c1 \sim v4 and c2 \sim v4
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[11].edges.append(4)
test_graph2.vertex_list[11].non_edges.append(1)
test_graph2.vertex_list[12].edges.append(4)
test_graph2.vertex_list[12].non_edges.append(1)
test_graph2.clean()
test_graph2.update_graph5(lem2_4_2_list, verbose=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11, 12]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 10, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12, 1]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 12:
#     Edges:     [6, 4]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11, 1]
#     Unknown:   [9, 10]
#     Color:   None
# There are 13 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Checking 1<->10. Completion:     7.69%
# Checking 2<->9. Completion:    15.38%
# Checking 2<->10. Completion:    23.08%
# Checking 3<->9. Completion:    30.77%
# Checking 3<->10. Completion:    38.46%
# Checking 4<->9. Completion:    46.15%
# Non-edge added from 4 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11, 12]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0, 4]
#     Unknown:   [1, 2, 3, 10, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0]
#     Unknown:   [1, 2, 3, 4, 9, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12, 1]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 12:
#     Edges:     [6, 4]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11, 1]
#     Unknown:   [9, 10]
#     Color:   None
# There are 12 unknown edges in the graph to check
# Checking 4<->10. Completion:     0.00%
# Non-edge added from 4 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11, 12]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0, 4]
#     Unknown:   [1, 2, 3, 10, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0, 4]
#     Unknown:   [1, 2, 3, 9, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12, 1]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 12:
#     Edges:     [6, 4]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11, 1]
#     Unknown:   [9, 10]
#     Color:   None
# There are 11 unknown edges in the graph to check
# Checking 9<->10. Completion:     0.00%
# Non-edge added from 9 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 8, 0, 4, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 8, 0, 1, 5, 6, 11, 12]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 11, 12]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 11]
#     Non-edges: [1, 4, 6, 9, 10, 2, 3, 12]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 5, 9, 10, 2, 3, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 9, 7, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [8, 5, 6, 0, 4, 10]
#     Unknown:   [1, 2, 3, 11, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8]
#     Non-edges: [7, 5, 6, 0, 4, 9]
#     Unknown:   [1, 2, 3, 11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [5, 4]
#     Non-edges: [6, 0, 7, 8, 2, 3, 12, 1]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 12:
#     Edges:     [6, 4]
#     Non-edges: [5, 0, 7, 8, 2, 3, 11, 1]
#     Unknown:   [9, 10]
#     Color:   None
# There are 10 unknown edges in the graph to check
# Checking 9<->11. Completion:     0.00%
# Checking 9<->12. Completion:    10.00%
# Checking 10<->11. Completion:    20.00%
# Checking 10<->12. Completion:    30.00%
# Checking 1<->9. Completion:    40.00%
# Checking 1<->10. Completion:    50.00%
# Checking 2<->9. Completion:    60.00%
# Checking 2<->10. Completion:    70.00%
# Checking 3<->9. Completion:    80.00%
# Checking 3<->10. Completion:    90.00%
# Checking if N(3) is contained in N(1) and N(11)
# N(3) is contained in N(1) and N(11). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 3 is colored None. Possible neighbors colored 0: [[], [4], [9, 10], [13], [], [], []]. done_list: []
# Vertex 3 is colored None. Possible neighbors colored 1: [[], [2], [9, 10], [13], [], [], []]. done_list: []
# Vertex 3 is colored None. Possible neighbors colored 2: [[], [4, 2], [9, 10], [13], [], [], []]. done_list: []
# Checking if N(3) is contained in N(1) and N(12)
# N(3) is contained in N(1) and N(12). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 3 is colored None. Possible neighbors colored 0: [[], [4], [9, 10], [13], [], [], []]. done_list: []
# Vertex 3 is colored None. Possible neighbors colored 1: [[], [2], [9, 10], [13], [], [], []]. done_list: []
# Vertex 3 is colored None. Possible neighbors colored 2: [[], [4, 2], [9, 10], [13], [], [], []]. done_list: []
# Checking if N(5) is contained in N(4) and N(6)
# N(5) is contained in N(4) and N(6). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [7, 8], [], [13], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [11], [], [], [], [], []]. done_list: []
# Vertex 11 is colored 1. Possible neighbors colored 0: [[4], [], [9, 10], [13], [], [], []]. done_list: [(5, 1)]
# Vertex 11 is colored 1. Possible neighbors colored 2: [[], [], [], [], [], [], []]. done_list: [(5, 1)]
# True
