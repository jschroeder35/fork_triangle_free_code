# %%
from graph_algs import *

# %%
for tgraph in lem3_5_list:
    tgraph.show()
# Out:
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [5, 7, 0, 1, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 2, 7]
#     Non-edges: [3, 1, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [5, 7, 0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [5, 7, 0, 1, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [2, 3, 1, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [6, 7, 0, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5, 6]
#     Non-edges: [7, 0, 1]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 3, 7]
#     Non-edges: [2, 1, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [6, 7, 0, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [6, 7, 0, 1]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 7]
#     Non-edges: [2, 3, 1, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [7, 2, 3, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 5, 6]
#     Non-edges: [7, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 0, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5, 6]
#     Non-edges: [7, 0, 1]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [5, 7, 1, 2, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [1, 3, 7]
#     Non-edges: [4, 0, 2, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [1, 3, 7]
#     Non-edges: [0, 2, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [7, 2, 3, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 5, 6]
#     Non-edges: [7, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 0, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 6]
#     Non-edges: [5, 7, 0, 1]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [5, 7, 1, 2, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [1, 7]
#     Non-edges: [3, 4, 0, 2, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [1, 3, 7]
#     Non-edges: [0, 2, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [7, 2, 3, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 5, 6]
#     Non-edges: [7, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 0, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [6, 7, 0, 1, 5]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 5, 6]
#     Non-edges: [7, 1, 2]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [1, 4, 7]
#     Non-edges: [0, 2, 3, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [1, 4, 7]
#     Non-edges: [3, 0, 2, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [7, 2, 3, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 5, 6]
#     Non-edges: [7, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 0, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [6, 7, 0, 1, 5]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 5]
#     Non-edges: [6, 7, 1, 2]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [1, 4, 7]
#     Non-edges: [0, 2, 3, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [1, 7]
#     Non-edges: [3, 4, 0, 2, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [5, 7, 2, 3, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 5, 6]
#     Non-edges: [7, 1, 2]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [2, 4, 7]
#     Non-edges: [0, 1, 3, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [2, 4, 7]
#     Non-edges: [0, 1, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [5, 7, 2, 3, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 6]
#     Non-edges: [5, 7, 1, 2]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [2, 7]
#     Non-edges: [4, 0, 1, 3, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [2, 4, 7]
#     Non-edges: [0, 1, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [6, 7, 1, 2, 5]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [2, 0, 7]
#     Non-edges: [1, 3, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [2, 0, 7]
#     Non-edges: [4, 1, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4, 5]
#     Non-edges: [6, 7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [6, 7, 1, 2, 5]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [2, 0, 7]
#     Non-edges: [1, 3, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [2, 7]
#     Non-edges: [4, 0, 1, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [5, 7, 3, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 0, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5, 6]
#     Non-edges: [7, 0, 1]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [3, 0, 7]
#     Non-edges: [1, 2, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 0, 7]
#     Non-edges: [1, 2, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4, 6]
#     Non-edges: [5, 7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [5, 7, 3, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 0, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5, 6]
#     Non-edges: [7, 0, 1]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [3, 7]
#     Non-edges: [0, 1, 2, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 0, 7]
#     Non-edges: [1, 2, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [6, 7, 2, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 5, 6]
#     Non-edges: [7, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 0, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5, 6]
#     Non-edges: [7, 0, 1]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [3, 1, 7]
#     Non-edges: [0, 2, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 1, 7]
#     Non-edges: [0, 2, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [6, 7, 2, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 5]
#     Non-edges: [6, 7, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [7, 0, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5, 6]
#     Non-edges: [7, 0, 1]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [3, 1, 7]
#     Non-edges: [0, 2, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [3, 7]
#     Non-edges: [0, 1, 2, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [7, 2, 3, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 5, 6]
#     Non-edges: [7, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [5, 7, 0, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 5, 6]
#     Non-edges: [7, 1, 2]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [4, 1, 7]
#     Non-edges: [2, 0, 3, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [4, 1, 7]
#     Non-edges: [0, 2, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [7, 2, 3, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 6]
#     Non-edges: [5, 7, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1]
#     Non-edges: [5, 7, 0, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 5, 6]
#     Non-edges: [7, 1, 2]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [4, 7]
#     Non-edges: [1, 2, 0, 3, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [4, 1, 7]
#     Non-edges: [0, 2, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [7, 2, 3, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [6, 7, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 5, 6]
#     Non-edges: [7, 1, 2]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [4, 2, 7]
#     Non-edges: [0, 1, 3, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [4, 2, 7]
#     Non-edges: [1, 0, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# Vertex 0:
#     Edges:     [1, 4]
#     Non-edges: [7, 2, 3, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [6, 7, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 5]
#     Non-edges: [6, 7, 0, 4]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 5, 6]
#     Non-edges: [7, 1, 2]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [4, 2, 7]
#     Non-edges: [0, 1, 3, 6]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [4, 7]
#     Non-edges: [1, 2, 0, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None

# %%
###Set up starting graph
v_0 = vert([1, 4, 5, 6], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1], [], 2)
v_3 = vert([4, 2], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 7], [], 5)
v_6 = vert([0, 2, 7], [], 6)
v_7 = vert([5, 6], [0, 1, 2, 3, 4], 7)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7])
test_graph.clean()
print(test_graph.update_graph(lem3_4_list))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6]
#     Unknown:   [5]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None

# %%
###Shows contradiction if c_5=c_2
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].non_edges.append(3)
test_graph2.clean()
test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='medium', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3]
#     Unknown:   [2]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# There are 1 unknown edges in the graph to check
# Checking 2<->5. Completion:     0.00%
# Vertex 8 added adjacent to 1 that cannot be adjacent to [0, 2, 3, 4, 6]
# Vertex 9 added adjacent to 7 that cannot be in N(0)!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8]
#     Unknown:   [5, 9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3, 9]
#     Unknown:   [2]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 5]
#     Non-edges: [0, 2, 3, 4, 6, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [0, 5, 6]
#     Unknown:   [1, 2, 3, 4, 8]
#     Color:   None
# There are 6 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Non-edge added from 1 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8]
#     Unknown:   [5, 9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3, 9]
#     Unknown:   [2]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 5]
#     Non-edges: [0, 2, 3, 4, 6, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [0, 5, 6, 1]
#     Unknown:   [2, 3, 4, 8]
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 2<->5. Completion:     0.00%
# Checking 2<->9. Completion:    20.00%
# Checking 3<->9. Completion:    40.00%
# Checking 4<->9. Completion:    60.00%
# Checking 8<->9. Completion:    80.00%
# Checking if N(1) is contained in N(3) and N(5)
# Checking if N(1) is contained in N(5) and N(6)
# Checking if 1 is degree 3.
# 1 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 1.
# Iteration: 1
# There are 10 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 0. Possible neighbors colored 1: [[], [3], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 3 is colored 1. Possible neighbors colored 0: [[], [4], [9], [10], [], [], []]. done_list: [(1, 0), (2, 1)]
# Vertex 3 is colored 1. Possible neighbors colored 2: [[], [4], [9], [10], [], [], []]. done_list: [(1, 0), (2, 1)]
# Vertex 2 is colored 0. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 6 is colored 2. Possible neighbors colored 0: [[], [], [], [10], [], [], []]. done_list: [(1, 0), (2, 2)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[0, 7], [], [], [11], [], [], []]. done_list: [(1, 0), (2, 2)]
# Vertex 1 is colored None. Possible neighbors colored 1: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 1. Possible neighbors colored 0: [[5], [4], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 0 is colored 1. Possible neighbors colored 2: [[6], [4], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[8], [], [], [], [], [], []]. done_list: []
# Vertex 8 is colored 2. Possible neighbors colored 0: [[5], [], [9], [11], [], [], []]. done_list: [(1, 2)]
# Vertex 8 is colored 2. Possible neighbors colored 1: [[], [], [], [11], [], [], []]. done_list: [(1, 2)]
# Iteration: 2
# There are 12 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 0. Possible neighbors colored 1: [[3], [], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 3 is colored 1. Possible neighbors colored 0: [[], [4], [9], [12], [10], [], []]. done_list: [(1, 0), (2, 1)]
# Vertex 3 is colored 1. Possible neighbors colored 2: [[], [4], [9], [12], [], [], []]. done_list: [(1, 0), (2, 1)]
# Vertex 2 is colored 0. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 6 is colored 2. Possible neighbors colored 0: [[10], [], [], [], [], [], []]. done_list: [(1, 0), (2, 2)]
# Vertex 10 is colored 0. Possible neighbors colored 1: [[], [], [], [], [3], [], []]. done_list: [(1, 0), (2, 2), (6, 0)]
# Vertex 3 is colored 1. Possible neighbors colored 0: [[4], [], [], [12], [], [], []]. done_list: [(1, 0), (2, 2), (6, 0), (10, 1)]
# Vertex 3 is colored 1. Possible neighbors colored 2: [[], [], [], [12], [], [2], []]. done_list: [(1, 0), (2, 2), (6, 0), (10, 1)]
# Vertex 10 is colored 0. Possible neighbors colored 2: [[9], [], [], [], [], [], []]. done_list: [(1, 0), (2, 2), (6, 0)]
# Vertex 9 is colored 2. Possible neighbors colored 0: [[4], [], [], [12], [], [], []]. done_list: [(1, 0), (2, 2), (6, 0), (10, 2)]
# Vertex 9 is colored 2. Possible neighbors colored 1: [[7], [], [], [12], [], [], []]. done_list: [(1, 0), (2, 2), (6, 0), (10, 2)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[0, 7], [], [], [], [], [], []]. done_list: [(1, 0), (2, 2)]
# Vertex 1 is colored None. Possible neighbors colored 1: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 1. Possible neighbors colored 0: [[4, 5], [], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 0 is colored 1. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 6 is colored 2. Possible neighbors colored 0: [[2, 10], [], [], [], [], [], []]. done_list: [(1, 1), (0, 2)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[7], [], [], [], [], [], []]. done_list: [(1, 1), (0, 2)]
# Vertex 7 is colored 1. Possible neighbors colored 0: [[5], [], [], [], [], [], []]. done_list: [(1, 1), (0, 2), (6, 1)]
# Vertex 5 is colored 0. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: [(1, 1), (0, 2), (6, 1), (7, 0)]
# 1 Must have degree at least 4; adding a new neighbor and updating...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 10]
#     Non-edges: [7, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8, 10]
#     Unknown:   [5, 9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3, 9]
#     Unknown:   [2, 10]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 5]
#     Non-edges: [0, 2, 3, 4, 6, 7, 10]
#     Unknown:   [9]
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [0, 5, 6, 1]
#     Unknown:   [2, 3, 4, 8, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [1]
#     Non-edges: [0, 2, 8, 7]
#     Unknown:   [3, 4, 5, 6, 9]
#     Color:   None
# Checking if N(5) is contained in N(1) and N(6)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/g1/fwv1fw7x3_d5xr_5fk_dfdph0000gn/T/ipykernel_8325/429555061.py in <module>
#       3 test_graph2.vertex_list[5].non_edges.append(3)
#       4 test_graph2.clean()
# ----> 5 test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='medium', check_deg_three=True)
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in update_graph5(self, subgraph_list, add_vertices, update_speed, max_distance, verbose, min_subgraph, check_deg_three, carg_update_speed)
#     989                             print('Checking if N({}) is contained in N({}) and N({})'.format(v1.index, v2.index, v3.index))
#     990                         ###If the update returns a contradiction, proceed, otherwise break
# --> 991                         if not temp_graph.update_graph_flexible(subgraph_list, update_speed, verbose=False, with_colors=False, min_subgraph=min_subgraph):
#     992                             continue
#     993
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in update_graph_flexible(self, subgraph_list, update_speed, verbose, min_subgraph, with_colors, max_depth)
#     932                 return True
#     933         elif update_speed=='medium':
# --> 934             if self.update_graph3(subgraph_list, verbose=verbose, with_colors=with_colors, min_subgraph=min_subgraph, max_depth=max_depth):
#     935                 return True
#     936         elif update_speed=='slow':
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in update_graph3(self, subgraph_list, verbose, with_colors, min_subgraph, max_depth)
#     813
#     814                             ##### Check both cases. If there is a contradiction in either case, return True #####
# --> 815                             bool1 = temp_graph.update_graph2_2(subgraph_list, max_depth, verbose=False, with_colors=with_colors, min_subgraph=min_subgraph)
#     816                             bool2 = temp_graph2.update_graph2_2(subgraph_list, max_depth, verbose=False, with_colors=with_colors, min_subgraph=min_subgraph)
#     817                             if (bool1 and bool2):
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in update_graph2_2(self, subgraph_list, max_depth, verbose, with_colors, min_subgraph)
#     658         while True:
#     659             ###First run update_graph2
# --> 660             if self.update_graph2(subgraph_list, max_depth, start_vert=None, current_depth=0, verbose=verbose, with_colors=with_colors):
#     661                 return True
#     662             ###at this point, there is no specificed min C_5, we are done.
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in update_graph2(self, subgraph_list, max_depth, start_vert, current_depth, verbose, with_colors)
#     601                     temp_graph.vertex_list[edge[0]].edges.append(edge[1])
#     602                     temp_graph.clean()
# --> 603                     if temp_graph.update_graph(subgraph_list, start_vert, with_colors):
#     604                         continue
#     605                     #####Recurse if less than max_depth
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in update_graph(self, subgraph_list, start_vert, with_colors)
#     564                     return True
#     565             else:
# --> 566                 if self.check_for_subgraphs_iter(subgraph_list):
#     567                     return True
#     568             updated =False
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in check_for_subgraphs_iter(self, subgraph_list, depth_cutoff)
#     397             while True:
#     398                 old_graph = copy.deepcopy(self)
# --> 399                 bool1=self.check_for_subgraphs(subgraph_list, i)
#     400                 if bool1:
#     401                     return True
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in check_for_subgraphs(self, subgraph_list, depth_cutoff)
#     378                             ##### Check both cases. If there is a contradiction in either case, return True #####
#     379                             bool1 = temp_graph.check_for_subgraphs(subgraph_list, depth_cutoff)
# --> 380                             bool2 = temp_graph2.check_for_subgraphs(subgraph_list, depth_cutoff)
#     381                             if (bool1 and bool2):
#     382                                 return True
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in check_for_subgraphs(self, subgraph_list, depth_cutoff)
#     356         #####In practice, little is gained by a depth cutoff of more than one#####
#     357         #####Method returns True if a fork/triangle is forced, False otherwise #####
# --> 358         if self.contains_subgraphs(subgraph_list):
#     359             return True
#     360
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in contains_subgraphs(self, subgraph_list)
#     177             tpast_vertex_list=copy.copy(past_vertex_list)
#     178             ###need to convert vertex indices to match the indices of the subgraph, and filter down to only those corresponding to vertices already added to our partial list
# --> 179             temp_edges=[i for i, vert in enumerate(past_vertex_list) if vert in vertex.edges]
#     180             temp_non_edges=[i for i, vert in enumerate(past_vertex_list) if vert in vertex.non_edges]
#     181             key1=(frozenset(temp_edges), frozenset(temp_non_edges))
#
# KeyboardInterrupt:

# %%
###Shows contradiction if c_5=c_2
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].edges.append(3)
new_vert=vert([1, 4], [], 8)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph4(lem3_4_list, verbose=True, min_subgraph=C_5)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 7]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    50.00%
# Vertex 10 added adjacent to 1 that cannot be adjacent to [0, 2, 3, 4, 6]
# Vertex 11 added adjacent to 0 that cannot be adjacent to [1, 2, 3, 4, 8]
# Vertex 12 added adjacent to 4 that cannot be adjacent to [0, 1, 2, 3, 5]
# True

# %%
### Shows a contradiction to conclude Claim 1
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].edges.append(3)
new_vert=vert([1], [4], 8)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([4], [0, 1, 2, 3, 5, 6], 10)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph4(lem3_4_list, verbose=True, min_subgraph=C_5)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10]
#     Unknown:   [8]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [8, 9, 10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2]
#     Unknown:   [3, 5, 6, 7, 10]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 10 unknown edges in the graph to check
# Checking 3<->8. Completion:     0.00%
# Non-edge added from 3 to 8; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [8, 9, 10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3]
#     Unknown:   [5, 6, 7, 10]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 9 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 5<->9. Completion:    11.11%
# Non-edge added from 5 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7]
#     Unknown:   [5, 6, 10]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    20.00%
# Checking 7<->10. Completion:    40.00%
# Non-edge added from 7 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8]
#     Unknown:   [9]
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 9<->10. Completion:     0.00%
# Non-edge added from 9 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9]
#     Unknown:   []
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    50.00%
# Vertex 11 added adjacent to 4 that cannot be adjacent to [2, 3, 5, 6, 7]
# Vertex 12 added adjacent to 10 that cannot be in N(0)!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   [12]
#     Color:   None
# Vertex 12:
#     Edges:     [10]
#     Non-edges: [0, 4]
#     Unknown:   [1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Color:   None
# There are 11 unknown edges in the graph to check
# Checking 1<->12. Completion:     0.00%
# Non-edge added from 1 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1]
#     Unknown:   [2, 3, 5, 6, 7, 8, 9]
#     Color:   None
# There are 9 unknown edges in the graph to check
# Checking 2<->12. Completion:     0.00%
# Non-edge added from 2 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2]
#     Unknown:   [3, 5, 6, 7, 8, 9]
#     Color:   None
# There are 8 unknown edges in the graph to check
# Checking 3<->12. Completion:     0.00%
# Non-edge added from 3 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# There are 7 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 5<->12. Completion:    14.29%
# Non-edge added from 5 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    20.00%
# Checking 7<->12. Completion:    40.00%
# Non-edge added from 7 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11, 12]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3, 5, 6, 7, 8]
#     Unknown:   [9]
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 9<->12. Completion:     0.00%
# Checking 5<->8. Completion:    33.33%
# Checking 6<->8. Completion:    66.67%
# Vertex 13 added adjacent to 10 that cannot be in N(11)!
# Vertex 14 added adjacent to 11 that cannot be in N(10)!
# Setting up and and initial greedy updates...
# Contradiction obtained in initial updates.
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11, 12]
#     Unknown:   [8, 13, 14]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11, 12]
#     Unknown:   [8, 13, 14]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11, 12]
#     Unknown:   [5, 6, 13, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12, 13, 14]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12, 13]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12, 14]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9, 13]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3, 5, 6, 7, 8, 13, 14]
#     Unknown:   [9]
#     Color:   None
# Vertex 13:
#     Edges:     [10]
#     Non-edges: [11, 4, 12]
#     Unknown:   [0, 1, 2, 3, 5, 6, 7, 8, 9, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [11]
#     Non-edges: [10, 4, 12]
#     Unknown:   [0, 1, 2, 3, 5, 6, 7, 8, 9, 13]
#     Color:   None
# True

# %%
###Proves that v2 must have degree >3 
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].non_edges.append(3)
test_graph2.clean()
test_graph2.update_graph4(lem3_5_list0, verbose=True, min_subgraph=C_5) 
test_graph2.vertex_list[1].max_degree=3
test_graph2.fill_in_colors(1)
test_graph2.color_argument_iter(lem3_5_list0, 1, 10, min_subgraph=C_5, carg_update_speed='fast')
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3]
#     Unknown:   [2]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# There are 1 unknown edges in the graph to check
# Checking 2<->5. Completion:     0.00%
# Vertex 8 added adjacent to 1 that cannot be adjacent to [0, 2, 3, 4, 6]
# Vertex 9 added adjacent to 7 that cannot be in N(0)!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8]
#     Unknown:   [5, 9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3, 9]
#     Unknown:   [2]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 5]
#     Non-edges: [0, 2, 3, 4, 6, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [0, 5, 6]
#     Unknown:   [1, 2, 3, 4, 8]
#     Color:   None
# There are 6 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Non-edge added from 1 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8]
#     Unknown:   [5, 9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3, 9]
#     Unknown:   [2]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 5]
#     Non-edges: [0, 2, 3, 4, 6, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 9:
#     Edges:     [7]
#     Non-edges: [0, 5, 6, 1]
#     Unknown:   [2, 3, 4, 8]
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 2<->5. Completion:     0.00%
# Checking 2<->9. Completion:    20.00%
# Checking 3<->9. Completion:    40.00%
# Checking 4<->9. Completion:    60.00%
# Checking 8<->9. Completion:    80.00%
# Iteration: 1
# There are 10 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 0. Possible neighbors colored 1: [[], [3], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 3 is colored 1. Possible neighbors colored 0: [[], [4], [9], [10], [], [], []]. done_list: [(1, 0), (2, 1)]
# Vertex 3 is colored 1. Possible neighbors colored 2: [[], [4], [9], [10], [], [], []]. done_list: [(1, 0), (2, 1)]
# Vertex 2 is colored 0. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 6 is colored 2. Possible neighbors colored 0: [[], [], [], [10], [], [], []]. done_list: [(1, 0), (2, 2)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[0, 7], [], [], [11], [], [], []]. done_list: [(1, 0), (2, 2)]
# Vertex 1 is colored None. Possible neighbors colored 1: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 1. Possible neighbors colored 0: [[5], [4], [], [11], [], [], []]. done_list: [(1, 1)]
# Vertex 0 is colored 1. Possible neighbors colored 2: [[6], [4], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[8], [], [], [], [], [], []]. done_list: []
# Vertex 8 is colored 2. Possible neighbors colored 0: [[5], [], [9], [11], [], [], []]. done_list: [(1, 2)]
# Vertex 8 is colored 2. Possible neighbors colored 1: [[], [], [], [11], [], [], []]. done_list: [(1, 2)]
# Iteration: 2
# There are 12 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 0. Possible neighbors colored 1: [[3], [], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 3 is colored 1. Possible neighbors colored 0: [[], [4], [9], [12], [10], [], []]. done_list: [(1, 0), (2, 1)]
# Vertex 3 is colored 1. Possible neighbors colored 2: [[], [4], [9], [12], [], [], []]. done_list: [(1, 0), (2, 1)]
# Vertex 2 is colored 0. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 6 is colored 2. Possible neighbors colored 0: [[10], [], [], [], [], [], []]. done_list: [(1, 0), (2, 2)]
# Vertex 10 is colored 0. Possible neighbors colored 1: [[], [], [], [12], [3], [], []]. done_list: [(1, 0), (2, 2), (6, 0)]
# Vertex 10 is colored 0. Possible neighbors colored 2: [[9], [], [], [12], [], [], []]. done_list: [(1, 0), (2, 2), (6, 0)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[0, 7], [], [], [], [], [], []]. done_list: [(1, 0), (2, 2)]
# Vertex 1 is colored None. Possible neighbors colored 1: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 1. Possible neighbors colored 0: [[5], [4], [], [12], [], [], []]. done_list: [(1, 1)]
# Vertex 0 is colored 1. Possible neighbors colored 2: [[6], [4], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[8], [], [], [], [], [], []]. done_list: []
# Vertex 8 is colored 2. Possible neighbors colored 0: [[5], [], [], [12], [], [], []]. done_list: [(1, 2)]
# Vertex 8 is colored 2. Possible neighbors colored 1: [[11], [], [], [], [], [], []]. done_list: [(1, 2)]
# Vertex 11 is colored 1. Possible neighbors colored 0: [[], [], [], [12], [], [], []]. done_list: [(1, 2), (8, 1)]
# Vertex 11 is colored 1. Possible neighbors colored 2: [[], [], [], [13], [], [], []]. done_list: [(1, 2), (8, 1)]
# Iteration: 3
# There are 14 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 0. Possible neighbors colored 1: [[3], [], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 3 is colored 1. Possible neighbors colored 0: [[10], [4], [], [14], [], [], []]. done_list: [(1, 0), (2, 1)]
# Vertex 3 is colored 1. Possible neighbors colored 2: [[], [4], [], [14], [], [], []]. done_list: [(1, 0), (2, 1)]
# Vertex 2 is colored 0. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: [(1, 0)]
# Vertex 6 is colored 2. Possible neighbors colored 0: [[10], [], [], [], [], [], []]. done_list: [(1, 0), (2, 2)]
# Vertex 10 is colored 0. Possible neighbors colored 1: [[3], [], [], [14], [], [], []]. done_list: [(1, 0), (2, 2), (6, 0)]
# Vertex 10 is colored 0. Possible neighbors colored 2: [[9], [], [], [14], [], [], []]. done_list: [(1, 0), (2, 2), (6, 0)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[0, 7], [], [], [], [], [], []]. done_list: [(1, 0), (2, 2)]
# Vertex 1 is colored None. Possible neighbors colored 1: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 1. Possible neighbors colored 0: [[5], [4], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 0 is colored 1. Possible neighbors colored 2: [[6], [4], [], [], [], [], []]. done_list: [(1, 1)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[8], [], [], [], [], [], []]. done_list: []
# Vertex 8 is colored 2. Possible neighbors colored 0: [[5], [], [], [], [], [], []]. done_list: [(1, 2)]
# Vertex 5 is colored 0. Possible neighbors colored 1: [[0, 7], [], [], [14], [], [], []]. done_list: [(1, 2), (8, 0)]
# Vertex 5 is colored 0. Possible neighbors colored 2: [[], [], [], [], [], [], []]. done_list: [(1, 2), (8, 0)]
# True

# %%
###This proves that b_2 must be adjacent to {v_4, v_5}
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].non_edges.append(3)
new_vert=vert([1], [0, 2, 3, 4, 6], 8) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([1], [3, 4], 9) 
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='medium', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8, 9]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3]
#     Unknown:   [2, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 5]
#     Non-edges: [0, 2, 3, 4, 6, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1]
#     Non-edges: [3, 4, 0, 2, 8, 7]
#     Unknown:   [5, 6]
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 2<->5. Completion:     0.00%
# Checking 5<->9. Completion:    33.33%
# Checking 6<->9. Completion:    66.67%
# Edge added from 6 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8, 9]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3]
#     Unknown:   [2, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 9]
#     Non-edges: [1, 3, 4, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 5]
#     Non-edges: [0, 2, 3, 4, 6, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 6]
#     Non-edges: [3, 4, 0, 2, 8, 7]
#     Unknown:   [5]
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 2<->5. Completion:     0.00%
# Checking 5<->9. Completion:    50.00%
# Vertex 10 added adjacent to 7 that cannot be in N(0)!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [7, 3, 4, 5, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8, 9]
#     Unknown:   [5, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3, 10]
#     Unknown:   [2, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 9]
#     Non-edges: [1, 3, 4, 5, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 5]
#     Non-edges: [0, 2, 3, 4, 6, 7, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 9:
#     Edges:     [1, 6]
#     Non-edges: [3, 4, 0, 2, 8, 7]
#     Unknown:   [5, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [7]
#     Non-edges: [0, 5, 6, 1]
#     Unknown:   [2, 3, 4, 8, 9]
#     Color:   None
# There are 7 unknown edges in the graph to check
# Checking 2<->5. Completion:     0.00%
# Checking 2<->10. Completion:    14.29%
# Checking 3<->10. Completion:    28.57%
# Checking 4<->10. Completion:    42.86%
# Checking 5<->9. Completion:    57.14%
# Checking 8<->10. Completion:    71.43%
# Edge added from 8 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [7, 3, 4, 5, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8, 9]
#     Unknown:   [5, 10]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3, 10]
#     Unknown:   [2, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 9]
#     Non-edges: [1, 3, 4, 5, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 5, 10]
#     Non-edges: [0, 2, 3, 4, 6, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 6]
#     Non-edges: [3, 4, 0, 2, 8, 7]
#     Unknown:   [5, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [7, 8]
#     Non-edges: [0, 5, 6, 1]
#     Unknown:   [2, 3, 4, 9]
#     Color:   None
# There are 6 unknown edges in the graph to check
# Checking 9<->10. Completion:     0.00%
# Checking 2<->5. Completion:    16.67%
# Checking 2<->10. Completion:    33.33%
# Checking 3<->10. Completion:    50.00%
# Checking 4<->10. Completion:    66.67%
# Checking 5<->9. Completion:    83.33%
# Checking if N(1) is contained in N(5) and N(6)
# Checking if N(1) is contained in N(6) and N(10)
# Checking if N(5) is contained in N(1) and N(6)
# Checking if N(5) is contained in N(1) and N(10)
# Checking if N(5) is contained in N(6) and N(10)
# Checking if N(6) is contained in N(1) and N(5)
# Checking if N(6) is contained in N(1) and N(10)
# Checking if N(7) is contained in N(0) and N(8)
# N(7) is contained in N(0) and N(8). Attempting coloring...
# Iteration: 1
# There are 11 vertices in the graph.
# Vertex 7 is colored None. Possible neighbors colored 0: [[], [10], [], [11], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: []
# True

# %%
###Show that u_1' has a neighbor w
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].non_edges.append(3)
new_vert=vert([1], [0, 2, 3, 4, 6], 8) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([1], [], 9) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8, 9], [0, 1, 2, 3, 4], 10) 
test_graph2.vertex_list.append(new_vert)
new_vert=vert([7], [0, 1, 2, 3, 4, 5, 6, 8, 9], 11) 
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5, update_speed='medium', carg_update_speed='medium', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 10, 11, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [7, 3, 4, 5, 6, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8, 10, 11, 9, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8, 10, 11]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8, 10, 11]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3, 11, 10, 2]
#     Unknown:   [9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 11, 10, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 10, 5]
#     Non-edges: [0, 2, 3, 4, 6, 11, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 10]
#     Non-edges: [11, 0, 2, 8, 6, 7]
#     Unknown:   [3, 4, 5]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 11]
#     Color:   None
# Vertex 11:
#     Edges:     [7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 9]
#     Unknown:   [10]
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 3<->9. Completion:     0.00%
# Checking 4<->9. Completion:    20.00%
# Checking 5<->9. Completion:    40.00%
# Non-edge added from 5 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 10, 11, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [7, 3, 4, 5, 6, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8, 10, 11, 9, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8, 10, 11]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8, 10, 11]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3, 11, 10, 2, 9]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 11, 10, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 10, 5]
#     Non-edges: [0, 2, 3, 4, 6, 11, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 10]
#     Non-edges: [11, 0, 2, 8, 6, 7, 5]
#     Unknown:   [3, 4]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 11]
#     Color:   None
# Vertex 11:
#     Edges:     [7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 9]
#     Unknown:   [10]
#     Color:   None
# There are 4 unknown edges in the graph to check
# Checking 7<->10. Completion:     0.00%
# Non-edge added from 7 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 10, 11, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [7, 3, 4, 5, 6, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8, 10, 11, 9, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8, 10, 11]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 8, 10, 11]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8]
#     Non-edges: [1, 4, 6, 3, 11, 10, 2, 9]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 11, 10, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 10, 5]
#     Non-edges: [0, 2, 3, 4, 6, 11, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 10]
#     Non-edges: [11, 0, 2, 8, 6, 7, 5]
#     Unknown:   [3, 4]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7]
#     Unknown:   [11]
#     Color:   None
# Vertex 11:
#     Edges:     [7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 9]
#     Unknown:   [10]
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 10<->11. Completion:     0.00%
# Checking 3<->9. Completion:    33.33%
# Checking 4<->9. Completion:    66.67%
# Checking if N(1) is contained in N(6) and N(10)
# N(1) is contained in N(6) and N(10). Attempting coloring...
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [8, 9], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0, 8, 9], [], [], [], [], []]. done_list: []
# Checking if N(2) is contained in N(0) and N(4)
# Checking if 2 is degree 3.
# 2 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 2.
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 2 is colored None. Possible neighbors colored 0: [[3], [], [], [], [], [], []]. done_list: []
# Vertex 3 is colored 0. Possible neighbors colored 1: [[], [4], [], [12], [], [], []]. done_list: [(2, 0)]
# Vertex 3 is colored 0. Possible neighbors colored 2: [[], [4], [9], [12], [], [], []]. done_list: [(2, 0)]
# Vertex 2 is colored None. Possible neighbors colored 1: [[1], [], [], [], [], [], []]. done_list: []
# Vertex 1 is colored 1. Possible neighbors colored 0: [[0], [8, 9], [], [], [], [], []]. done_list: [(2, 1)]
# Vertex 1 is colored 1. Possible neighbors colored 2: [[], [8, 9], [], [], [], [], []]. done_list: [(2, 1)]
# Vertex 2 is colored None. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: []
# Vertex 6 is colored 2. Possible neighbors colored 0: [[0], [7], [], [12], [], [], []]. done_list: [(2, 2)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[], [7], [], [12], [], [], []]. done_list: [(2, 2)]
# Checking if N(3) is contained in N(0) and N(1)
# Checking if N(4) is contained in N(1) and N(2)
# Checking if N(5) is contained in N(1) and N(6)
# Checking if N(5) is contained in N(1) and N(11)
# Checking if N(5) is contained in N(6) and N(10)
# Checking if 5 is degree 3.
# 5 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 5.
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 0. Possible neighbors colored 1: [[1], [4], [], [], [], [], []]. done_list: [(5, 0)]
# Vertex 0 is colored 0. Possible neighbors colored 2: [[6], [4], [], [], [], [], []]. done_list: [(5, 0)]
# Vertex 5 is colored None. Possible neighbors colored 1: [[7], [], [], [], [], [], []]. done_list: []
# Vertex 7 is colored 1. Possible neighbors colored 0: [[], [11], [], [], [], [], []]. done_list: [(5, 1)]
# Vertex 11 is colored 0. Possible neighbors colored 1: [[], [], [10], [12], [], [], []]. done_list: [(5, 1), (7, 0)]
# Vertex 11 is colored 0. Possible neighbors colored 2: [[], [], [], [12], [], [], []]. done_list: [(5, 1), (7, 0)]
# Vertex 7 is colored 1. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: [(5, 1)]
# Vertex 6 is colored 2. Possible neighbors colored 0: [[0, 2], [], [], [], [], [], []]. done_list: [(5, 1), (7, 2)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: [(5, 1), (7, 2)]
# 5 Must have degree at least 4; adding a new neighbor and updating...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 10, 11, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [7, 3, 4, 5, 6, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8, 10, 11, 9, 5, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8, 10, 11, 12]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 12]
#     Non-edges: [7, 1, 2, 5, 6, 8, 10, 11]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 6, 3, 11, 10, 2, 9]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9, 10, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 10, 5]
#     Non-edges: [0, 2, 3, 4, 6, 11, 7, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 10]
#     Non-edges: [11, 0, 2, 8, 6, 7, 5]
#     Unknown:   [3, 4, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7]
#     Unknown:   [11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 9]
#     Unknown:   [10, 12]
#     Color:   None
# Vertex 12:
#     Edges:     [5, 4]
#     Non-edges: [0, 7, 8, 1, 2, 3, 6]
#     Unknown:   [9, 10, 11]
#     Color:   None
# Checking if N(6) is contained in N(1) and N(5)
# Checking if N(6) is contained in N(1) and N(11)
# N(6) is contained in N(1) and N(11). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[], [7], [], [13], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 1: [[], [0, 2], [], [], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 2: [[], [0, 2, 7], [], [13], [], [], []]. done_list: []
# Checking if N(6) is contained in N(3) and N(5)
# Checking if 6 is degree 3.
# 6 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 6.
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 0. Possible neighbors colored 1: [[5], [4], [], [], [], [], []]. done_list: [(6, 0)]
# Vertex 0 is colored 0. Possible neighbors colored 2: [[1], [4], [], [], [], [], []]. done_list: [(6, 0)]
# Vertex 6 is colored None. Possible neighbors colored 1: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[], [3], [], [], [], [], []]. done_list: [(6, 1)]
# Vertex 3 is colored 0. Possible neighbors colored 1: [[], [4], [], [13], [], [], []]. done_list: [(6, 1), (2, 0)]
# Vertex 3 is colored 0. Possible neighbors colored 2: [[], [4], [], [13], [], [], []]. done_list: [(6, 1), (2, 0)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[1], [], [], [], [], [], []]. done_list: [(6, 1)]
# Vertex 1 is colored 2. Possible neighbors colored 0: [[0, 8], [9], [], [], [], [], []]. done_list: [(6, 1), (2, 2)]
# Vertex 1 is colored 2. Possible neighbors colored 1: [[], [9], [], [], [], [], []]. done_list: [(6, 1), (2, 2)]
# Vertex 9 is colored 1. Possible neighbors colored 0: [[], [], [], [], [], [], []]. done_list: [(6, 1), (2, 2), (1, 1)]
# 6 Must have degree at least 4; adding a new neighbor and updating...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 10, 11, 9, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [3, 4, 5, 6, 7, 10, 11, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8, 10, 11, 9, 5, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8, 10, 11, 12]
#     Unknown:   [9, 13]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 12]
#     Non-edges: [7, 1, 2, 5, 6, 8, 10, 11]
#     Unknown:   [9, 13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 6, 3, 11, 10, 2, 9, 13]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 13]
#     Non-edges: [1, 3, 4, 5, 8, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9, 10, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 10, 5]
#     Non-edges: [0, 2, 3, 4, 6, 11, 7, 9, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 10]
#     Non-edges: [11, 0, 2, 8, 6, 7, 5]
#     Unknown:   [3, 4, 12, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7, 13]
#     Unknown:   [11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [7, 13]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 9]
#     Unknown:   [10, 12]
#     Color:   None
# Vertex 12:
#     Edges:     [5, 4]
#     Non-edges: [0, 7, 8, 1, 2, 3, 6]
#     Unknown:   [9, 10, 11, 13]
#     Color:   None
# Vertex 13:
#     Edges:     [6, 11]
#     Non-edges: [0, 2, 7, 1, 5, 8, 10]
#     Unknown:   [3, 4, 9, 12]
#     Color:   None
# Checking if N(7) is contained in N(0) and N(13)
# Checking if N(7) is contained in N(8) and N(13)
# N(7) is contained in N(8) and N(13). Attempting coloring...
# Iteration: 1
# There are 14 vertices in the graph.
# Vertex 7 is colored None. Possible neighbors colored 0: [[], [6, 11], [], [], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 1: [[], [5], [], [14], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 2: [[], [5, 6, 11], [], [14], [], [], []]. done_list: []
# Checking if N(7) is contained in N(12) and N(13)
# Checking if 7 is degree 3.
# 7 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 7.
# Iteration: 1
# There are 14 vertices in the graph.
# Vertex 7 is colored None. Possible neighbors colored 0: [[5], [], [], [], [], [], []]. done_list: []
# Vertex 5 is colored 0. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: [(7, 0)]
# 7 Must have degree at least 4; adding a new neighbor and updating...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 10, 11, 9, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [3, 4, 5, 6, 7, 10, 11, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 14]
#     Non-edges: [7, 0, 4, 8, 10, 11, 9, 5, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 8, 10, 11, 12, 14]
#     Unknown:   [9, 13]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 12]
#     Non-edges: [7, 1, 2, 5, 6, 8, 10, 11, 14]
#     Unknown:   [9, 13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 4, 6, 3, 11, 10, 2, 9, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 13]
#     Non-edges: [1, 3, 4, 5, 8, 9, 10, 11, 12, 14]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11, 14]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9, 10, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 10, 5, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 9, 11, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 10]
#     Non-edges: [11, 0, 2, 8, 6, 7, 5, 14]
#     Unknown:   [3, 4, 12, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7, 13, 14]
#     Unknown:   [11, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [7, 13]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 9, 14]
#     Unknown:   [10, 12]
#     Color:   None
# Vertex 12:
#     Edges:     [5, 4]
#     Non-edges: [0, 7, 8, 1, 2, 3, 6, 14]
#     Unknown:   [9, 10, 11, 13]
#     Color:   None
# Vertex 13:
#     Edges:     [6, 11]
#     Non-edges: [0, 1, 2, 5, 7, 8, 10, 14]
#     Unknown:   [3, 4, 9, 12]
#     Color:   None
# Vertex 14:
#     Edges:     [7, 8, 2]
#     Non-edges: [5, 6, 11, 1, 0, 10, 3, 4, 13, 9, 12]
#     Unknown:   []
#     Color:   None
# Checking if N(8) is contained in N(7) and N(9)
# N(8) is contained in N(7) and N(9). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 8 is colored None. Possible neighbors colored 0: [[], [1, 10], [], [], [], [], []]. done_list: []
# Vertex 8 is colored None. Possible neighbors colored 1: [[], [5, 14], [], [], [], [], []]. done_list: []
# Vertex 8 is colored None. Possible neighbors colored 2: [[], [1, 10, 5, 14], [], [], [], [], []]. done_list: []
# Checking if N(14) is contained in N(1) and N(5)
# Checking if N(14) is contained in N(1) and N(6)
# Checking if N(14) is contained in N(1) and N(11)
# Checking if N(14) is contained in N(3) and N(5)
# N(14) is contained in N(3) and N(5). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 14 is colored None. Possible neighbors colored 0: [[], [7, 8], [], [], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 1: [[], [2], [], [15], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 2: [[], [7, 8, 2], [], [15], [], [], []]. done_list: []
# Checking if N(14) is contained in N(5) and N(6)
# Checking if N(14) is contained in N(6) and N(10)
# Checking if 14 is degree 3.
# 14 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 14.
# 14 Must have degree at least 4; adding a new neighbor and updating...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 10, 11, 9, 12, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [3, 4, 5, 6, 7, 10, 11, 12, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 14]
#     Non-edges: [7, 0, 4, 8, 10, 11, 9, 5, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 15]
#     Non-edges: [0, 1, 5, 6, 7, 8, 10, 11, 12, 14]
#     Unknown:   [9, 13]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 12]
#     Non-edges: [7, 1, 2, 5, 6, 8, 10, 11, 14, 15]
#     Unknown:   [9, 13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 2, 3, 4, 6, 9, 10, 11, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 13]
#     Non-edges: [1, 3, 4, 5, 8, 9, 10, 11, 12, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11, 14]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9, 10, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 10, 5, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 9, 11, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 10]
#     Non-edges: [0, 2, 5, 6, 7, 8, 11, 14]
#     Unknown:   [3, 4, 12, 13, 15]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7, 13, 14]
#     Unknown:   [11, 12, 15]
#     Color:   None
# Vertex 11:
#     Edges:     [7, 13]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 9, 14]
#     Unknown:   [10, 12, 15]
#     Color:   None
# Vertex 12:
#     Edges:     [5, 4]
#     Non-edges: [0, 7, 8, 1, 2, 3, 6, 14]
#     Unknown:   [9, 10, 11, 13, 15]
#     Color:   None
# Vertex 13:
#     Edges:     [6, 11]
#     Non-edges: [0, 1, 2, 5, 7, 8, 10, 14]
#     Unknown:   [3, 4, 9, 12, 15]
#     Color:   None
# Vertex 14:
#     Edges:     [7, 8, 2, 15]
#     Non-edges: [5, 6, 11, 1, 0, 10, 3, 4, 13, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 15:
#     Edges:     [14, 3]
#     Non-edges: [2, 7, 8, 0, 1, 4, 5, 6]
#     Unknown:   [9, 10, 11, 12, 13]
#     Color:   None
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 8, 10, 11, 9, 12, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [3, 4, 5, 6, 7, 10, 11, 12, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 14]
#     Non-edges: [7, 0, 4, 8, 10, 11, 9, 5, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 15]
#     Non-edges: [0, 1, 5, 6, 7, 8, 10, 11, 12, 14]
#     Unknown:   [9, 13]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 12]
#     Non-edges: [7, 1, 2, 5, 6, 8, 10, 11, 14, 15]
#     Unknown:   [9, 13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 2, 3, 4, 6, 9, 10, 11, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 13]
#     Non-edges: [1, 3, 4, 5, 8, 9, 10, 11, 12, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11, 14]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9, 10, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 10, 5, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 9, 11, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 10]
#     Non-edges: [0, 2, 5, 6, 7, 8, 11, 14]
#     Unknown:   [3, 4, 12, 13, 15]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7, 13, 14]
#     Unknown:   [11, 12, 15]
#     Color:   None
# Vertex 11:
#     Edges:     [7, 13]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 9, 14]
#     Unknown:   [10, 12, 15]
#     Color:   None
# Vertex 12:
#     Edges:     [5, 4]
#     Non-edges: [0, 7, 8, 1, 2, 3, 6, 14]
#     Unknown:   [9, 10, 11, 13, 15]
#     Color:   None
# Vertex 13:
#     Edges:     [6, 11]
#     Non-edges: [0, 1, 2, 5, 7, 8, 10, 14]
#     Unknown:   [3, 4, 9, 12, 15]
#     Color:   None
# Vertex 14:
#     Edges:     [7, 8, 2, 15]
#     Non-edges: [5, 6, 11, 1, 0, 10, 3, 4, 13, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 15:
#     Edges:     [14, 3]
#     Non-edges: [2, 7, 8, 0, 1, 4, 5, 6]
#     Unknown:   [9, 10, 11, 12, 13]
#     Color:   None
# There are 15 unknown edges in the graph to check
# Checking 3<->9. Completion:     0.00%
# Checking 3<->13. Completion:     6.67%
# Checking 4<->9. Completion:    13.33%
# Checking 4<->13. Completion:    20.00%
# Checking 9<->12. Completion:    26.67%
# Checking 9<->13. Completion:    33.33%
# Checking 9<->15. Completion:    40.00%
# Checking 10<->11. Completion:    46.67%
# Checking 10<->12. Completion:    53.33%
# Checking 10<->15. Completion:    60.00%
# Checking 11<->12. Completion:    66.67%
# Checking 11<->15. Completion:    73.33%
# Checking 12<->13. Completion:    80.00%
# Checking 12<->15. Completion:    86.67%
# Checking 13<->15. Completion:    93.33%
# Checking if N(0) is contained in N(2) and N(12)
# N(0) is contained in N(2) and N(12). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[], [4, 5], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 1: [[], [1, 6], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 2: [[], [1, 4, 5, 6], [], [], [], [], []]. done_list: []
# Checking if N(1) is contained in N(6) and N(10)
# N(1) is contained in N(6) and N(10). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [8, 9], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0, 8, 9], [], [], [], [], []]. done_list: []
# Checking if N(2) is contained in N(0) and N(15)
# N(2) is contained in N(0) and N(15). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 2 is colored None. Possible neighbors colored 0: [[], [3, 14], [], [], [], [], []]. done_list: []
# Vertex 2 is colored None. Possible neighbors colored 1: [[], [1, 6], [], [], [], [], []]. done_list: []
# Vertex 2 is colored None. Possible neighbors colored 2: [[], [3, 1, 6, 14], [], [], [], [], []]. done_list: []
# Checking if N(5) is contained in N(4) and N(14)
# N(5) is contained in N(4) and N(14). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [7, 8], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [0, 12], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 2: [[], [0, 7, 8, 12], [], [], [], [], []]. done_list: []
# Checking if N(6) is contained in N(1) and N(11)
# N(6) is contained in N(1) and N(11). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[], [7, 13], [], [], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 1: [[], [0, 2], [], [], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 2: [[], [0, 2, 7, 13], [], [], [], [], []]. done_list: []
# Checking if N(7) is contained in N(8) and N(13)
# N(7) is contained in N(8) and N(13). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 7 is colored None. Possible neighbors colored 0: [[], [6, 11], [], [], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 1: [[], [5, 14], [], [], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 2: [[], [5, 6, 11, 14], [], [], [], [], []]. done_list: []
# Checking if N(8) is contained in N(7) and N(9)
# N(8) is contained in N(7) and N(9). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 8 is colored None. Possible neighbors colored 0: [[], [1, 10], [], [], [], [], []]. done_list: []
# Vertex 8 is colored None. Possible neighbors colored 1: [[], [5, 14], [], [], [], [], []]. done_list: []
# Vertex 8 is colored None. Possible neighbors colored 2: [[], [1, 10, 5, 14], [], [], [], [], []]. done_list: []
# Checking if N(14) is contained in N(3) and N(5)
# N(14) is contained in N(3) and N(5). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 14 is colored None. Possible neighbors colored 0: [[], [7, 8], [], [], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 1: [[], [2, 15], [], [], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 2: [[], [7, 8, 2, 15], [], [], [], [], []]. done_list: []
# False

# %%
###Show that w must be adjacent to C
test_graph3=copy.deepcopy(test_graph2)
test_graph3.vertex_list[13].non_edges.append(3)
test_graph3.vertex_list[13].non_edges.append(4)
test_graph3.clean()
test_graph3.update_graph4(lem3_5_list0, verbose=True, min_subgraph=C_5)
# Out:
# Setting up and and initial greedy updates...
# Contradiction obtained in initial updates.
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [2, 3, 7, 8, 9, 10, 11, 12, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 9]
#     Non-edges: [3, 4, 5, 6, 7, 10, 11, 12, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 14]
#     Non-edges: [0, 4, 5, 7, 8, 9, 10, 11, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 15]
#     Non-edges: [0, 1, 5, 6, 7, 8, 10, 11, 12, 14, 13]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 12]
#     Non-edges: [1, 2, 5, 6, 7, 8, 10, 11, 14, 15, 13]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 8, 12]
#     Non-edges: [1, 2, 3, 4, 6, 9, 10, 11, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 13]
#     Non-edges: [1, 3, 4, 5, 8, 9, 10, 11, 12, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11, 14]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9, 10, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 10, 5, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 9, 11, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [1, 10]
#     Non-edges: [0, 2, 5, 6, 7, 8, 11, 14]
#     Unknown:   [3, 4, 12, 13, 15]
#     Color:   None
# Vertex 10:
#     Edges:     [8, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7, 13, 14]
#     Unknown:   [11, 12, 15]
#     Color:   None
# Vertex 11:
#     Edges:     [7, 13]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 9, 14]
#     Unknown:   [10, 12, 15]
#     Color:   None
# Vertex 12:
#     Edges:     [5, 4]
#     Non-edges: [0, 1, 2, 3, 6, 7, 8, 14]
#     Unknown:   [9, 10, 11, 13, 15]
#     Color:   None
# Vertex 13:
#     Edges:     [6, 11]
#     Non-edges: [0, 1, 2, 5, 7, 8, 10, 14, 3, 4]
#     Unknown:   [9, 12, 15]
#     Color:   None
# Vertex 14:
#     Edges:     [7, 8, 2, 15]
#     Non-edges: [0, 1, 3, 4, 5, 6, 9, 10, 11, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 15:
#     Edges:     [14, 3]
#     Non-edges: [0, 1, 2, 4, 5, 6, 7, 8]
#     Unknown:   [9, 10, 11, 12, 13]
#     Color:   None
# True
