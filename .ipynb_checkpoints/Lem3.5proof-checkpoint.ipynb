# %%
from graph_algs import *

# %%
###Set up starting graph
v_0 = vert([1, 4, 5, 6], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1], [], 2)
v_3 = vert([4, 2], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 7], [], 5)
v_6 = vert([0, 2, 7], [], 6)
v_7 = vert([5, 6], [0, 1, 2, 3, 4], 7)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7])
test_graph.clean()
print(test_graph.update_graph(lem3_4_list))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6]
#     Unknown:   [5]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None

# %%
###Shows contradiction if c_5=c_2
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].edges.append(3)
new_vert=vert([1, 4], [], 8)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph4(lem3_4_list, verbose=True, min_subgraph=C_5)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 7]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    50.00%
# Vertex 10 added to the graph that cannot be adjacent to [0, 2, 3, 4, 6]
# Vertex 11 added to the graph that cannot be adjacent to [1, 2, 3, 4, 8]
# Vertex 12 added to the graph that cannot be adjacent to [0, 1, 2, 3, 5]
# True

# %%
### Shows a contradiction to conclude Claim 1
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].edges.append(3)
new_vert=vert([1], [4], 8)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([4], [0, 1, 2, 3, 5, 6], 10)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph4(lem3_4_list, verbose=True, min_subgraph=C_5)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10]
#     Unknown:   [8]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [8, 9, 10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2]
#     Unknown:   [3, 5, 6, 7, 10]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 10 unknown edges in the graph to check
# Checking 3<->8. Completion:     0.00%
# Non-edge added from 3 to 8; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [8, 9, 10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3]
#     Unknown:   [5, 6, 7, 10]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 9 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 5<->9. Completion:    11.11%
# Non-edge added from 5 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7]
#     Unknown:   [5, 6, 10]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    20.00%
# Checking 7<->10. Completion:    40.00%
# Non-edge added from 7 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8]
#     Unknown:   [9]
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 9<->10. Completion:     0.00%
# Non-edge added from 9 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9]
#     Unknown:   []
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    50.00%
# Vertex 11 added to the graph that cannot be adjacent to [2, 3, 5, 6, 7]
# Vertex 12 added!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   [12]
#     Color:   None
# Vertex 12:
#     Edges:     [10]
#     Non-edges: [0, 4]
#     Unknown:   [1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Color:   None
# There are 11 unknown edges in the graph to check
# Checking 1<->12. Completion:     0.00%
# Non-edge added from 1 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1]
#     Unknown:   [2, 3, 5, 6, 7, 8, 9]
#     Color:   None
# There are 9 unknown edges in the graph to check
# Checking 2<->12. Completion:     0.00%
# Non-edge added from 2 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2]
#     Unknown:   [3, 5, 6, 7, 8, 9]
#     Color:   None
# There are 8 unknown edges in the graph to check
# Checking 3<->12. Completion:     0.00%
# Non-edge added from 3 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# There are 7 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 5<->12. Completion:    14.29%
# Non-edge added from 5 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    20.00%
# Checking 7<->12. Completion:    40.00%
# Non-edge added from 7 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11, 12]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3, 5, 6, 7, 8]
#     Unknown:   [9]
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 9<->12. Completion:     0.00%
# Checking 5<->8. Completion:    33.33%
# Checking 6<->8. Completion:    66.67%
# Vertex 13 added!
# Vertex 14 added!
# Setting up and and initial greedy updates...
# Contradiction obtained (if this is not the first line of output, there is an algorithmic error)
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11, 12]
#     Unknown:   [8, 13, 14]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11, 12]
#     Unknown:   [8, 13, 14]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11, 12]
#     Unknown:   [5, 6, 13, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12, 13, 14]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12, 13]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12, 14]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9, 13]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3, 5, 6, 7, 8, 13, 14]
#     Unknown:   [9]
#     Color:   None
# Vertex 13:
#     Edges:     [10]
#     Non-edges: [11, 4, 12]
#     Unknown:   [0, 1, 2, 3, 5, 6, 7, 8, 9, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [11]
#     Non-edges: [10, 4, 12]
#     Unknown:   [0, 1, 2, 3, 5, 6, 7, 8, 9, 13]
#     Color:   None
# True

# %%
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].non_edges.append(3)
new_vert=vert([1, 3], [5, 6], len(test_graph2.vertex_list))
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], len(test_graph2.vertex_list))
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5, update_speed='fast')
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 8]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 8]
#     Non-edges: [7, 0, 1, 6, 5, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 9]
#     Unknown:   [2]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 3, 9]
#     Non-edges: [5, 6, 0, 2, 4, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7]
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 2<->5. Completion:     0.00%
# Checking 7<->9. Completion:    50.00%
# Vertex 10 added to the graph that cannot be adjacent to [0, 1, 3, 4, 8]
# Vertex 11 added to the graph that cannot be adjacent to [0, 2, 3, 4, 6]
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 8, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 11]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 10]
#     Non-edges: [7, 0, 4, 9, 8, 11]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 8]
#     Non-edges: [7, 0, 1, 6, 5, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 9, 8, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 11]
#     Non-edges: [1, 4, 6, 3, 8, 9, 10]
#     Unknown:   [2]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 8, 11]
#     Unknown:   [9]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 3, 9]
#     Non-edges: [5, 6, 0, 2, 4, 7, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8, 11]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10]
#     Unknown:   [7]
#     Color:   None
# Vertex 10:
#     Edges:     [2, 7, 11]
#     Non-edges: [0, 1, 3, 4, 8, 6, 9, 5]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [1, 5, 9, 10]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8]
#     Unknown:   []
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 2<->5. Completion:     0.00%
# Checking 7<->9. Completion:    50.00%
# Checking if N(1) is contained in N(3) and N(5)
# Checking if N(1) is contained in N(6) and N(9)
# N(1) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [8, 11], [], [12], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0, 8, 11], [], [12], [], [], []]. done_list: []
# Checking if N(2) is contained in N(7) and N(8)
# N(2) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 2 is colored None. Possible neighbors colored 0: [[], [3, 1], [], [], [], [], []]. done_list: []
# Vertex 2 is colored None. Possible neighbors colored 1: [[], [6, 10], [5], [12], [], [], []]. done_list: []
# Vertex 2 is colored None. Possible neighbors colored 2: [[], [3, 1, 6, 10], [5], [12], [], [], []]. done_list: []
# Checking if N(3) is contained in N(0) and N(1)
# Checking if 3 is degree 3.
# 3 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 3.
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 3 is colored None. Possible neighbors colored 0: [[4], [], [], [], [], [], []]. done_list: []
# Vertex 4 is colored 0. Possible neighbors colored 1: [[], [0], [], [12], [], [], []]. done_list: [(3, 0)]
# Vertex 4 is colored 0. Possible neighbors colored 2: [[], [0], [], [12], [], [], []]. done_list: [(3, 0)]
# Vertex 3 is colored None. Possible neighbors colored 1: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[1], [6, 10], [5], [12], [], [], []]. done_list: [(3, 1)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[], [6, 10], [5], [12], [], [], []]. done_list: [(3, 1)]
# Vertex 3 is colored None. Possible neighbors colored 2: [[8], [], [], [], [], [], []]. done_list: []
# Vertex 8 is colored 2. Possible neighbors colored 0: [[1], [9], [], [12], [], [], []]. done_list: [(3, 2)]
# Vertex 8 is colored 2. Possible neighbors colored 1: [[], [9], [], [12], [], [], []]. done_list: [(3, 2)]
# Checking if N(4) is contained in N(1) and N(2)
# Checking if N(4) is contained in N(1) and N(8)
# Checking if N(4) is contained in N(2) and N(5)
# Checking if N(4) is contained in N(2) and N(6)
# Checking if N(4) is contained in N(5) and N(8)
# Checking if N(4) is contained in N(6) and N(8)
# Checking if N(5) is contained in N(1) and N(6)
# Checking if N(5) is contained in N(1) and N(10)
# Checking if N(5) is contained in N(4) and N(10)
# N(5) is contained in N(4) and N(10). Attempting coloring...
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [7, 11], [2], [12], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [0], [], [12], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 2: [[], [0, 7, 11], [2], [12], [], [], []]. done_list: []
# Checking if N(5) is contained in N(6) and N(9)
# Checking if N(5) is contained in N(6) and N(10)
# Checking if N(6) is contained in N(1) and N(5)
# Checking if N(6) is contained in N(1) and N(10)
# Checking if N(6) is contained in N(3) and N(5)
# Checking if N(6) is contained in N(4) and N(10)
# N(6) is contained in N(4) and N(10). Attempting coloring...
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[], [2, 7], [], [12], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 1: [[], [0], [], [12], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 2: [[], [0, 2, 7], [], [12], [], [], []]. done_list: []
# Checking if N(6) is contained in N(5) and N(10)
# Checking if 6 is degree 3.
# 6 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 6.
# 6 Must have degree at least 4; adding a new neighbor and updating...
# Checking if N(7) is contained in N(0) and N(11)
# Checking if N(7) is contained in N(2) and N(11)
# Checking if N(7) is contained in N(11) and N(12)
# N(7) is contained in N(11) and N(12). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 7 is colored None. Possible neighbors colored 0: [[], [6], [], [13], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 1: [[], [5, 10], [], [13], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 2: [[], [5, 6, 10], [9], [13], [], [], []]. done_list: []
# Checking if N(9) is contained in N(1) and N(5)
# Checking if N(9) is contained in N(1) and N(6)
# Checking if N(9) is contained in N(1) and N(10)
# Checking if N(9) is contained in N(3) and N(5)
# Checking if N(9) is contained in N(3) and N(10)
# Checking if N(10) is contained in N(1) and N(5)
# Checking if N(10) is contained in N(1) and N(6)
# Checking if N(10) is contained in N(3) and N(5)
# Checking if N(10) is contained in N(5) and N(6)
# Checking if N(10) is contained in N(6) and N(9)
# N(10) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 10 is colored None. Possible neighbors colored 0: [[], [11], [], [13], [], [], []]. done_list: []
# Vertex 10 is colored None. Possible neighbors colored 1: [[], [2, 7], [], [], [], [], []]. done_list: []
# Vertex 10 is colored None. Possible neighbors colored 2: [[], [2, 7, 11], [12], [13], [], [], []]. done_list: []
# Checking if N(11) is contained in N(7) and N(8)
# N(11) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 11 is colored None. Possible neighbors colored 0: [[], [1, 9], [], [], [], [], []]. done_list: []
# Vertex 11 is colored None. Possible neighbors colored 1: [[], [5, 10], [], [13], [], [], []]. done_list: []
# Vertex 11 is colored None. Possible neighbors colored 2: [[], [1, 5, 9, 10], [], [13], [], [], []]. done_list: []
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 8, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 11]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   [12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 10]
#     Non-edges: [7, 0, 4, 9, 8, 11, 12]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 8]
#     Non-edges: [7, 0, 1, 6, 5, 9, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [1, 2, 5, 6, 7, 8, 9, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 11]
#     Non-edges: [1, 4, 6, 3, 8, 9, 10]
#     Unknown:   [2, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 12]
#     Non-edges: [1, 3, 4, 5, 8, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 8, 11, 12]
#     Unknown:   [9]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 3, 9]
#     Non-edges: [0, 2, 4, 5, 6, 7, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 11]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10]
#     Unknown:   [7, 12]
#     Color:   None
# Vertex 10:
#     Edges:     [2, 7, 11]
#     Non-edges: [0, 1, 3, 4, 5, 6, 8, 9]
#     Unknown:   [12]
#     Color:   None
# Vertex 11:
#     Edges:     [1, 5, 9, 10]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 12]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [6]
#     Non-edges: [0, 2, 11, 7]
#     Unknown:   [1, 3, 4, 5, 8, 9, 10]
#     Color:   None
# There are 9 unknown edges in the graph to check
# Checking 1<->12. Completion:     0.00%
# Checking 2<->5. Completion:    11.11%
# Checking 3<->12. Completion:    22.22%
# Checking 4<->12. Completion:    33.33%
# Checking 5<->12. Completion:    44.44%
# Checking 7<->9. Completion:    55.56%
# Checking 8<->12. Completion:    66.67%
# Checking 9<->12. Completion:    77.78%
# Checking 10<->12. Completion:    88.89%
# Checking if N(1) is contained in N(3) and N(5)
# Checking if N(1) is contained in N(6) and N(9)
# N(1) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [8, 11], [], [13], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0, 8, 11], [12], [13], [], [], []]. done_list: []
# Checking if N(2) is contained in N(7) and N(8)
# N(2) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 2 is colored None. Possible neighbors colored 0: [[], [3, 1], [], [], [], [], []]. done_list: []
# Vertex 2 is colored None. Possible neighbors colored 1: [[], [6, 10], [5], [13], [], [], []]. done_list: []
# Vertex 2 is colored None. Possible neighbors colored 2: [[], [3, 1, 6, 10], [5], [13], [], [], []]. done_list: []
# Checking if N(4) is contained in N(1) and N(8)
# Checking if N(4) is contained in N(2) and N(6)
# Checking if N(4) is contained in N(5) and N(8)
# Checking if N(4) is contained in N(6) and N(8)
# Checking if N(5) is contained in N(1) and N(6)
# Checking if N(5) is contained in N(1) and N(10)
# Checking if N(5) is contained in N(4) and N(10)
# N(5) is contained in N(4) and N(10). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [7, 11], [2, 12], [13], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [0], [12], [13], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 2: [[], [0, 7, 11], [2, 12], [13], [], [], []]. done_list: []
# Checking if N(5) is contained in N(6) and N(9)
# Checking if N(5) is contained in N(6) and N(10)
# Checking if N(6) is contained in N(1) and N(5)
# Checking if N(6) is contained in N(1) and N(10)
# Checking if N(6) is contained in N(3) and N(5)
# Checking if N(6) is contained in N(4) and N(10)
# N(6) is contained in N(4) and N(10). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[], [2, 7, 12], [], [13], [], [], []]. done_list: []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/g1/fwv1fw7x3_d5xr_5fk_dfdph0000gn/T/ipykernel_22763/3583090726.py in <module>
#       6 test_graph2.vertex_list.append(new_vert)
#       7 test_graph2.clean()
# ----> 8 test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5, update_speed='fast')
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in update_graph5(self, subgraph_list, add_vertices, update_speed, max_distance, verbose, min_subgraph, check_deg_three)
#     987                                 print('Contradiction obtained filling in colors.')
#     988                             return True
# --> 989                         if self.color_argument_iter(subgraph_list, v1.index, max_distance, verbose=verbose, add_vertices=add_vertices, min_subgraph=min_subgraph):
#     990                             return True
#     991
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in color_argument_iter(self, subgraph_list, start_vert, max_distance, verbose, add_vertices, min_subgraph)
#    1313             old_graph = copy.deepcopy(self)
#    1314             #####With the changes to the code, there is not much meaningful difference between the distance and depth. I can probably remove the second variable in the next update but I wanted to get this update out sooner. #####
# -> 1315             if self.color_argument(subgraph_list, start_vert, [], 0, max_distance, max_distance, verbose, add_vertices, min_subgraph):
#    1316                 return True
#    1317             if self.update_graph2_2(subgraph_list, 1, min_subgraph=min_subgraph):
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in color_argument(self, subgraph_list, start_vert, done_list, current_distance, max_distance, max_depth, verbose, add_vertices, min_subgraph)
#    1154                     temp_graph.clean()
#    1155                     #####Assuming no contradiction, recurse on temp_vert #####
# -> 1156                     if not temp_graph.update_graph2_2(subgraph_list, 1, min_subgraph=min_subgraph):
#    1157                         list3.append(temp_vert.index)
#    1158                         graph_list.append(temp_graph)
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in update_graph2_2(self, subgraph_list, max_depth, verbose, with_colors, min_subgraph)
#     647         while True:
#     648             ###First run update_graph2
# --> 649             if self.update_graph2(subgraph_list, max_depth, start_vert=None, current_depth=0, verbose=verbose, with_colors=with_colors):
#     650                 return True
#     651             ###at this point, there is no specificed min C_5, we are done.
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in update_graph2(self, subgraph_list, max_depth, start_vert, current_depth, verbose, with_colors)
#     590                     temp_graph.vertex_list[edge[0]].edges.append(edge[1])
#     591                     temp_graph.clean()
# --> 592                     if temp_graph.update_graph(subgraph_list, start_vert, with_colors):
#     593                         continue
#     594                     #####Recurse if less than max_depth
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in update_graph(self, subgraph_list, start_vert, with_colors)
#     550                     return True
#     551             elif with_colors:
# --> 552                 if self.fill_in_colors(start_vert) or self.check_for_subgraphs_iter(subgraph_list):
#     553                     return True
#     554             else:
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in check_for_subgraphs_iter(self, subgraph_list, depth_cutoff)
#     386             while True:
#     387                 old_graph = copy.deepcopy(self)
# --> 388                 bool1=self.check_for_subgraphs(subgraph_list, i)
#     389                 if bool1:
#     390                     return True
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in check_for_subgraphs(self, subgraph_list, depth_cutoff)
#     366
#     367                             ##### Check both cases. If there is a contradiction in either case, return True #####
# --> 368                             bool1 = temp_graph.check_for_subgraphs(subgraph_list, depth_cutoff)
#     369                             bool2 = temp_graph2.check_for_subgraphs(subgraph_list, depth_cutoff)
#     370                             if (bool1 and bool2):
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in check_for_subgraphs(self, subgraph_list, depth_cutoff)
#     345         #####In practice, little is gained by a depth cutoff of more than one#####
#     346         #####Method returns True if a fork/triangle is forced, False otherwise #####
# --> 347         if self.contains_subgraphs(subgraph_list):
#     348             return True
#     349
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in contains_subgraphs(self, subgraph_list)
#     169             ###need to convert vertex indices to match the indices of the subgraph, and filter down to only those corresponding to vertices already added to our partial list
#     170             temp_edges=[i for i, vert in enumerate(past_vertex_list) if vert in vertex.edges]
# --> 171             temp_non_edges=[i for i, vert in enumerate(past_vertex_list) if vert in vertex.non_edges]
#     172             key1=(frozenset(temp_edges), frozenset(temp_non_edges))
#     173             key2=(frozenset(temp_edges), frozenset(temp_non_edges), vertex.index)
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs.py in <listcomp>(.0)
#     169             ###need to convert vertex indices to match the indices of the subgraph, and filter down to only those corresponding to vertices already added to our partial list
#     170             temp_edges=[i for i, vert in enumerate(past_vertex_list) if vert in vertex.edges]
# --> 171             temp_non_edges=[i for i, vert in enumerate(past_vertex_list) if vert in vertex.non_edges]
#     172             key1=(frozenset(temp_edges), frozenset(temp_non_edges))
#     173             key2=(frozenset(temp_edges), frozenset(temp_non_edges), vertex.index)
#
# KeyboardInterrupt:

# %%
test_graph3=copy.deepcopy(test_graph)
test_graph3.vertex_list[5].non_edges.append(3)
test_graph3.clean()
test_graph3.vertex_list[5].color=0
test_graph3.vertex_list[6].color=1
test_graph3.fill_in_colors(1)
test_graph3.color_argument_iter(lem3_5_list0, 1, 10)
# Out:
# Iteration: 1
# There are 8 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [2], [], [8], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [], [], [8], [], [], []]. done_list: []
# Vertex 8 is colored 1. Possible neighbors colored 0: [[], [], [3, 4], [9], [5], [], []]. done_list: [(1, 1)]
# Vertex 8 is colored 1. Possible neighbors colored 2: [[], [], [3], [9], [7], [], []]. done_list: [(1, 1)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[0], [2], [], [9], [], [], []]. done_list: []
# Iteration: 2
# There are 9 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [2], [], [9], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[8], [], [], [9], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[0], [2], [], [9], [], [], []]. done_list: []
# False

# %%
test_graph3.show()
# Out:
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [8, 2, 3, 7]
#     Unknown:   []
#     Color:   2
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5]
#     Unknown:   [8]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   [8]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 3, 4, 6]
#     Unknown:   [2, 8]
#     Color:   0
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8]
#     Unknown:   []
#     Color:   1
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [8]
#     Color:   2
# Vertex 8:
#     Edges:     [1]
#     Non-edges: [0, 2, 6]
#     Unknown:   [3, 4, 5, 7]
#     Color:   1
