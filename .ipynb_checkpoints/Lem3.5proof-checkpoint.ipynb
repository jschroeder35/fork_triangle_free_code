# %%
from graph_algs import *

# %%
###Set up starting graph
v_0 = vert([1, 4, 5, 6], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1], [], 2)
v_3 = vert([4, 2], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 7], [], 5)
v_6 = vert([0, 2, 7], [], 6)
v_7 = vert([5, 6], [0, 1, 2, 3, 4], 7)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7])
test_graph.clean()
print(test_graph.update_graph(lem3_4_list))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6]
#     Unknown:   [5]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None

# %%
###Shows contradiction if c_5=c_2
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].edges.append(3)
new_vert=vert([1, 4], [], 8)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph4(lem3_4_list, verbose=True, min_subgraph=C_5)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 7]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    50.00%
# Vertex 10 added adjacent to 1 that cannot be adjacent to [0, 2, 3, 4, 6]
# Vertex 11 added adjacent to 0 that cannot be adjacent to [1, 2, 3, 4, 8]
# Vertex 12 added adjacent to 4 that cannot be adjacent to [0, 1, 2, 3, 5]
# True

# %%
### Shows a contradiction to conclude Claim 1
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].edges.append(3)
new_vert=vert([1], [4], 8)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([4], [0, 1, 2, 3, 5, 6], 10)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph4(lem3_4_list, verbose=True, min_subgraph=C_5)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10]
#     Unknown:   [8]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [8, 9, 10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2]
#     Unknown:   [3, 5, 6, 7, 10]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 10 unknown edges in the graph to check
# Checking 3<->8. Completion:     0.00%
# Non-edge added from 3 to 8; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [8, 9, 10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3]
#     Unknown:   [5, 6, 7, 10]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 9 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 5<->9. Completion:    11.11%
# Non-edge added from 5 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [10]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7]
#     Unknown:   [5, 6, 10]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    20.00%
# Checking 7<->10. Completion:    40.00%
# Non-edge added from 7 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [10]
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8]
#     Unknown:   [9]
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 9<->10. Completion:     0.00%
# Non-edge added from 9 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 10:
#     Edges:     [4]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9]
#     Unknown:   []
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    50.00%
# Vertex 11 added adjacent to 4 that cannot be adjacent to [2, 3, 5, 6, 7]
# Vertex 12 added adjacent to 10 that cannot be in N(0)!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   [12]
#     Color:   None
# Vertex 12:
#     Edges:     [10]
#     Non-edges: [0, 4]
#     Unknown:   [1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Color:   None
# There are 11 unknown edges in the graph to check
# Checking 1<->12. Completion:     0.00%
# Non-edge added from 1 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1]
#     Unknown:   [2, 3, 5, 6, 7, 8, 9]
#     Color:   None
# There are 9 unknown edges in the graph to check
# Checking 2<->12. Completion:     0.00%
# Non-edge added from 2 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2]
#     Unknown:   [3, 5, 6, 7, 8, 9]
#     Color:   None
# There are 8 unknown edges in the graph to check
# Checking 3<->12. Completion:     0.00%
# Non-edge added from 3 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# There are 7 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 5<->12. Completion:    14.29%
# Non-edge added from 5 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11]
#     Unknown:   [5, 6, 12]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 5<->8. Completion:     0.00%
# Checking 6<->8. Completion:    20.00%
# Checking 7<->12. Completion:    40.00%
# Non-edge added from 7 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11, 12]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11, 12]
#     Unknown:   [5, 6]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3, 5, 6, 7, 8]
#     Unknown:   [9]
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 9<->12. Completion:     0.00%
# Checking 5<->8. Completion:    33.33%
# Checking 6<->8. Completion:    66.67%
# Vertex 13 added adjacent to 10 that cannot be in N(11)!
# Vertex 14 added adjacent to 11 that cannot be in N(10)!
# Setting up and and initial greedy updates...
# Contradiction obtained in initial updates.
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10, 8, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10, 11]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2, 9, 11, 12]
#     Unknown:   [8, 13, 14]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10, 9, 11, 12]
#     Unknown:   [8, 13, 14]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8, 10, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 9]
#     Non-edges: [4, 0, 2, 3, 7, 10, 11, 12]
#     Unknown:   [5, 6, 13, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 10, 11]
#     Unknown:   [12, 13, 14]
#     Color:   None
# Vertex 10:
#     Edges:     [4, 12, 13]
#     Non-edges: [0, 1, 2, 3, 5, 6, 7, 8, 9, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [4, 12, 14]
#     Non-edges: [2, 3, 5, 6, 7, 0, 10, 1, 8, 9, 13]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [10, 11]
#     Non-edges: [0, 4, 1, 2, 3, 5, 6, 7, 8, 13, 14]
#     Unknown:   [9]
#     Color:   None
# Vertex 13:
#     Edges:     [10]
#     Non-edges: [11, 4, 12]
#     Unknown:   [0, 1, 2, 3, 5, 6, 7, 8, 9, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [11]
#     Non-edges: [10, 4, 12]
#     Unknown:   [0, 1, 2, 3, 5, 6, 7, 8, 9, 13]
#     Color:   None
# True

# %%
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].non_edges.append(3)
new_vert=vert([1, 4], [5, 6], 8)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([3], [], 10)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([10], [0, 1, 2, 3, 4], 11)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
#test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5)
test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5, update_speed='fast', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8]
#     Unknown:   [10]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11]
#     Unknown:   [10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [7, 0, 1, 6, 5, 9, 11, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 9]
#     Unknown:   [2, 10, 11]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 0, 2, 3, 7]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4]
#     Unknown:   [0, 1, 5, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# There are 14 unknown edges in the graph to check
# Checking 0<->10. Completion:     0.00%
# Non-edge added from 0 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11]
#     Unknown:   [10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [7, 0, 1, 6, 5, 9, 11, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 9]
#     Unknown:   [2, 10, 11]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 0, 2, 3, 7]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0]
#     Unknown:   [1, 5, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# There are 13 unknown edges in the graph to check
# Checking 1<->10. Completion:     0.00%
# Non-edge added from 1 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [7, 0, 1, 6, 5, 9, 11, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 9]
#     Unknown:   [2, 10, 11]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 0, 2, 3, 7]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# There are 12 unknown edges in the graph to check
# Checking 2<->5. Completion:     0.00%
# Non-edge added from 2 to 5; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [7, 0, 1, 6, 5, 9, 11, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 9, 2]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 0, 2, 3, 7]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# There are 11 unknown edges in the graph to check
# Checking 5<->10. Completion:     0.00%
# Non-edge added from 5 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [7, 0, 1, 6, 5, 9, 11, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 9, 2, 10]
#     Unknown:   [11]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 0, 2, 3, 7]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 8, 9]
#     Color:   None
# There are 10 unknown edges in the graph to check
# Checking 5<->11. Completion:     0.00%
# Non-edge added from 5 to 11; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [7, 0, 1, 6, 5, 9, 11, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 9, 2, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11]
#     Unknown:   [10]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 0, 2, 3, 7]
#     Unknown:   [10, 11]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 8, 9]
#     Color:   None
# There are 8 unknown edges in the graph to check
# Checking 6<->10. Completion:     0.00%
# Checking 7<->9. Completion:    12.50%
# Checking 7<->10. Completion:    25.00%
# Checking 7<->11. Completion:    37.50%
# Checking 8<->10. Completion:    50.00%
# Checking 8<->11. Completion:    62.50%
# Non-edge added from 8 to 11; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [7, 0, 1, 6, 5, 9, 11, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 9, 2, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11]
#     Unknown:   [10]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 0, 2, 3, 7, 11]
#     Unknown:   [10]
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8]
#     Unknown:   [7, 9]
#     Color:   None
# There are 7 unknown edges in the graph to check
# Checking 8<->10. Completion:     0.00%
# Checking 9<->10. Completion:    14.29%
# Checking 9<->11. Completion:    28.57%
# Checking 6<->10. Completion:    42.86%
# Checking 7<->9. Completion:    57.14%
# Checking 7<->10. Completion:    71.43%
# Checking 7<->11. Completion:    85.71%
# Vertex 12 added adjacent to 1 that cannot be adjacent to [0, 2, 3, 4, 6]
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [7, 0, 1, 6, 5, 9, 11, 8, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12]
#     Non-edges: [1, 4, 6, 3, 8, 9, 2, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12]
#     Unknown:   [10]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12]
#     Unknown:   [9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 0, 2, 3, 7, 11, 12]
#     Unknown:   [10]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5]
#     Unknown:   [6, 7, 8, 9, 12]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11]
#     Unknown:   [10]
#     Color:   None
# There are 8 unknown edges in the graph to check
# Checking 6<->10. Completion:     0.00%
# Checking 7<->9. Completion:    12.50%
# Checking 7<->10. Completion:    25.00%
# Checking 7<->11. Completion:    37.50%
# Checking 8<->10. Completion:    50.00%
# Checking 9<->10. Completion:    62.50%
# Checking 9<->11. Completion:    75.00%
# Checking 10<->12. Completion:    87.50%
# Non-edge added from 10 to 12; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [7, 0, 1, 6, 5, 9, 11, 8, 12]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12]
#     Non-edges: [1, 4, 6, 3, 8, 9, 2, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12]
#     Unknown:   [10]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12]
#     Unknown:   [9, 10, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 0, 2, 3, 7, 11, 12]
#     Unknown:   [10]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 10, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12]
#     Unknown:   [6, 7, 8, 9]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10]
#     Unknown:   []
#     Color:   None
# There are 7 unknown edges in the graph to check
# Checking 6<->10. Completion:     0.00%
# Checking 7<->9. Completion:    14.29%
# Checking 7<->10. Completion:    28.57%
# Checking 7<->11. Completion:    42.86%
# Checking 8<->10. Completion:    57.14%
# Checking 9<->10. Completion:    71.43%
# Checking 9<->11. Completion:    85.71%
# Checking if N(0) is contained in N(7) and N(8)
# N(0) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[], [1, 4], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 1: [[], [5, 6], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 2: [[], [1, 4, 5, 6], [], [13], [], [], []]. done_list: []
# Checking if N(1) is contained in N(6) and N(9)
# N(1) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [8, 12], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0, 8, 12], [], [13], [], [], []]. done_list: []
# Checking if N(2) is contained in N(0) and N(4)
# Checking if N(2) is contained in N(0) and N(10)
# Checking if 2 is degree 3.
# 2 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 2.
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 2 is colored None. Possible neighbors colored 0: [[3], [], [], [], [], [], []]. done_list: []
# Vertex 3 is colored 0. Possible neighbors colored 1: [[], [4, 10], [], [13], [], [], []]. done_list: [(2, 0)]
# Vertex 3 is colored 0. Possible neighbors colored 2: [[], [4, 10], [], [13], [], [], []]. done_list: [(2, 0)]
# Vertex 2 is colored None. Possible neighbors colored 1: [[1], [], [], [], [], [], []]. done_list: []
# Vertex 1 is colored 1. Possible neighbors colored 0: [[0], [8, 12], [], [13], [], [], []]. done_list: [(2, 1)]
# Vertex 1 is colored 1. Possible neighbors colored 2: [[], [8, 12], [], [], [], [], []]. done_list: [(2, 1)]
# Vertex 2 is colored None. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: []
# Vertex 6 is colored 2. Possible neighbors colored 0: [[0], [7], [], [13], [], [], []]. done_list: [(2, 2)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[], [7], [10], [13], [], [], []]. done_list: [(2, 2)]
# Checking if N(3) is contained in N(6) and N(8)
# Checking if 3 is degree 3.
# 3 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 3.
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 3 is colored None. Possible neighbors colored 0: [[4], [], [], [], [], [], []]. done_list: []
# Vertex 4 is colored 0. Possible neighbors colored 1: [[], [0, 8], [], [13], [], [], []]. done_list: [(3, 0)]
# Vertex 4 is colored 0. Possible neighbors colored 2: [[], [0, 8], [], [13], [], [], []]. done_list: [(3, 0)]
# Vertex 3 is colored None. Possible neighbors colored 1: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[], [1, 6], [], [13], [], [], []]. done_list: [(3, 1)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[], [1, 6], [], [13], [], [], []]. done_list: [(3, 1)]
# Vertex 3 is colored None. Possible neighbors colored 2: [[10], [], [], [], [], [], []]. done_list: []
# Vertex 10 is colored 2. Possible neighbors colored 0: [[], [11], [6, 7, 9], [13], [], [], []]. done_list: [(3, 2)]
# Vertex 10 is colored 2. Possible neighbors colored 1: [[], [11], [7, 8, 9], [13], [], [], []]. done_list: [(3, 2)]
# Checking if N(4) is contained in N(1) and N(2)
# Checking if N(4) is contained in N(1) and N(10)
# Checking if 4 is degree 3.
# 4 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 4.
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 4 is colored None. Possible neighbors colored 0: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 0. Possible neighbors colored 1: [[1], [5, 6], [], [13], [], [], []]. done_list: [(4, 0)]
# Vertex 0 is colored 0. Possible neighbors colored 2: [[], [5, 6], [], [], [], [], []]. done_list: [(4, 0)]
# Vertex 4 is colored None. Possible neighbors colored 1: [[3], [], [], [], [], [], []]. done_list: []
# Vertex 3 is colored 1. Possible neighbors colored 0: [[], [2, 10], [], [13], [], [], []]. done_list: [(4, 1)]
# Vertex 3 is colored 1. Possible neighbors colored 2: [[], [2, 10], [], [13], [], [], []]. done_list: [(4, 1)]
# Vertex 4 is colored None. Possible neighbors colored 2: [[8], [], [], [], [], [], []]. done_list: []
# Vertex 8 is colored 2. Possible neighbors colored 0: [[], [9], [10], [13], [], [], []]. done_list: [(4, 2)]
# Vertex 8 is colored 2. Possible neighbors colored 1: [[1], [9], [], [13], [], [], []]. done_list: [(4, 2)]
# Checking if N(5) is contained in N(1) and N(6)
# Checking if N(5) is contained in N(6) and N(9)
# N(5) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [12], [], [13], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [0, 7], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 2: [[], [0, 7, 12], [], [13], [], [], []]. done_list: []
# Checking if 5 is degree 3.
# 5 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 5.
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 0. Possible neighbors colored 1: [[1], [4], [], [], [], [], []]. done_list: [(5, 0)]
# Vertex 0 is colored 0. Possible neighbors colored 2: [[6], [4], [], [], [], [], []]. done_list: [(5, 0)]
# Vertex 5 is colored None. Possible neighbors colored 1: [[7], [], [], [], [], [], []]. done_list: []
# Vertex 7 is colored 1. Possible neighbors colored 0: [[], [], [9, 10, 11], [13], [], [], []]. done_list: [(5, 1)]
# Vertex 7 is colored 1. Possible neighbors colored 2: [[6], [], [10, 11], [13], [], [], []]. done_list: [(5, 1)]
# Vertex 5 is colored None. Possible neighbors colored 2: [[12], [], [], [], [], [], []]. done_list: []
# Vertex 12 is colored 2. Possible neighbors colored 0: [[], [9], [], [], [], [], []]. done_list: [(5, 2)]
# Vertex 9 is colored 0. Possible neighbors colored 1: [[], [], [10, 11], [13], [7], [], []]. done_list: [(5, 2), (12, 0)]
# Vertex 9 is colored 0. Possible neighbors colored 2: [[8], [], [11], [13], [], [], []]. done_list: [(5, 2), (12, 0)]
# Vertex 12 is colored 2. Possible neighbors colored 1: [[1], [], [], [], [], [], []]. done_list: [(5, 2)]
# Vertex 1 is colored 1. Possible neighbors colored 0: [[2, 0], [], [], [], [], [], []]. done_list: [(5, 2), (12, 1)]
# Vertex 1 is colored 1. Possible neighbors colored 2: [[8], [], [], [], [], [], []]. done_list: [(5, 2), (12, 1)]
# Vertex 8 is colored 2. Possible neighbors colored 0: [[9], [], [], [], [], [], []]. done_list: [(5, 2), (12, 1), (1, 2)]
# Vertex 9 is colored 0. Possible neighbors colored 1: [[], [], [10, 11], [13], [7], [12], []]. done_list: [(5, 2), (12, 1), (1, 2), (8, 0)]
# Vertex 9 is colored 0. Possible neighbors colored 2: [[], [], [11], [13], [], [], []]. done_list: [(5, 2), (12, 1), (1, 2), (8, 0)]
# Vertex 8 is colored 2. Possible neighbors colored 1: [[4], [], [], [13], [], [], []]. done_list: [(5, 2), (12, 1), (1, 2)]
# Iteration: 2
# There are 13 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 0. Possible neighbors colored 1: [[1, 4], [], [], [], [], [], []]. done_list: [(5, 0)]
# Vertex 0 is colored 0. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: [(5, 0)]
# Vertex 6 is colored 2. Possible neighbors colored 0: [[2], [], [], [], [], [], []]. done_list: [(5, 0), (0, 2)]
# Vertex 2 is colored 0. Possible neighbors colored 1: [[1], [], [], [], [], [], []]. done_list: [(5, 0), (0, 2), (6, 0)]
# Vertex 1 is colored 1. Possible neighbors colored 0: [[], [], [], [], [], [], []]. done_list: [(5, 0), (0, 2), (6, 0), (2, 1)]
# 5 Must have degree at least 4; adding a new neighbor and updating...
# Checking if N(6) is contained in N(3) and N(5)
# N(6) is contained in N(3) and N(5). Attempting coloring...
# Iteration: 1
# There are 14 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[], [0, 7], [13], [14], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 1: [[], [2], [10], [14], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 2: [[], [0, 2, 7], [10, 13], [14], [], [], []]. done_list: []
# Checking if N(11) is contained in N(6) and N(8)
# Checking if N(12) is contained in N(0) and N(8)
# Checking if N(12) is contained in N(7) and N(8)
# N(12) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 14 vertices in the graph.
# Vertex 12 is colored None. Possible neighbors colored 0: [[], [1, 9], [], [], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 1: [[], [5], [], [14], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 2: [[], [1, 5, 9], [], [14], [], [], []]. done_list: []
# Checking if N(12) is contained in N(8) and N(13)
# Checking if 12 is degree 3.
# 12 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 12.
# Iteration: 1
# There are 14 vertices in the graph.
# Vertex 12 is colored None. Possible neighbors colored 0: [[1], [], [], [], [], [], []]. done_list: []
# Vertex 1 is colored 0. Possible neighbors colored 1: [[8], [], [], [], [], [], []]. done_list: [(12, 0)]
# Vertex 8 is colored 1. Possible neighbors colored 0: [[4], [], [], [], [], [], []]. done_list: [(12, 0), (1, 1)]
# Vertex 4 is colored 0. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: [(12, 0), (1, 1), (8, 0)]
# 12 Must have degree at least 4; adding a new neighbor and updating...
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12]
#     Unknown:   [10, 13, 14]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13]
#     Unknown:   [9, 10, 11, 14]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12]
#     Unknown:   [10, 13, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14]
#     Unknown:   [7, 10, 11, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12]
#     Unknown:   [6, 7, 8, 9, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9, 13, 14]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5]
#     Non-edges: [0, 7, 12]
#     Unknown:   [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12]
#     Non-edges: [1, 5, 9]
#     Unknown:   [0, 2, 3, 4, 6, 7, 8, 10, 11, 13]
#     Color:   None
# There are 26 unknown edges in the graph to check
# Checking 0<->14. Completion:     0.00%
# Checking 1<->13. Completion:     3.85%
# Checking 2<->13. Completion:     7.69%
# Non-edge added from 2 to 13; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12]
#     Unknown:   [10, 13, 14]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13]
#     Unknown:   [9, 10, 11, 14]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12]
#     Unknown:   [10, 13, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14]
#     Unknown:   [7, 10, 11, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12]
#     Unknown:   [6, 7, 8, 9, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9, 13, 14]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5]
#     Non-edges: [0, 7, 12, 2]
#     Unknown:   [1, 3, 4, 6, 8, 9, 10, 11, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12]
#     Non-edges: [1, 5, 9]
#     Unknown:   [0, 2, 3, 4, 6, 7, 8, 10, 11, 13]
#     Color:   None
# There are 25 unknown edges in the graph to check
# Checking 2<->14. Completion:     0.00%
# Checking 3<->13. Completion:     4.00%
# Non-edge added from 3 to 13; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12]
#     Unknown:   [10, 13, 14]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13]
#     Unknown:   [9, 10, 11, 14]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12, 13]
#     Unknown:   [10, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14]
#     Unknown:   [7, 10, 11, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12]
#     Unknown:   [6, 7, 8, 9, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9, 13, 14]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5]
#     Non-edges: [0, 7, 12, 2, 3, 8]
#     Unknown:   [1, 4, 6, 9, 10, 11, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12]
#     Non-edges: [1, 5, 9]
#     Unknown:   [0, 2, 3, 4, 6, 7, 8, 10, 11, 13]
#     Color:   None
# There are 23 unknown edges in the graph to check
# Checking 3<->14. Completion:     0.00%
# Non-edge added from 3 to 14; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12]
#     Unknown:   [13, 14]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12, 14]
#     Unknown:   [10, 13]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13]
#     Unknown:   [9, 10, 11, 14]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12, 13]
#     Unknown:   [10, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14]
#     Unknown:   [7, 10, 11, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12]
#     Unknown:   [6, 7, 8, 9, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9, 13, 14]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5]
#     Non-edges: [0, 7, 12, 2, 3, 8]
#     Unknown:   [1, 4, 6, 9, 10, 11, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12]
#     Non-edges: [1, 5, 9, 3, 6]
#     Unknown:   [0, 2, 4, 7, 8, 10, 11, 13]
#     Color:   None
# There are 21 unknown edges in the graph to check
# Checking 4<->13. Completion:     0.00%
# Checking 4<->14. Completion:     4.76%
# Non-edge added from 4 to 14; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12, 14]
#     Unknown:   [10, 13]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13]
#     Unknown:   [9, 10, 11, 14]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12, 13]
#     Unknown:   [10, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14]
#     Unknown:   [7, 10, 11, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12]
#     Unknown:   [6, 7, 8, 9, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9, 13, 14]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5]
#     Non-edges: [0, 7, 12, 2, 3, 8]
#     Unknown:   [1, 4, 6, 9, 10, 11, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12]
#     Non-edges: [1, 5, 9, 3, 6, 4]
#     Unknown:   [0, 2, 7, 8, 10, 11, 13]
#     Color:   None
# There are 20 unknown edges in the graph to check
# Checking 4<->13. Completion:     0.00%
# Checking 6<->10. Completion:     5.00%
# Checking 6<->13. Completion:    10.00%
# Checking 7<->9. Completion:    15.00%
# Checking 7<->10. Completion:    20.00%
# Non-edge added from 7 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12, 14]
#     Unknown:   [10, 13]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13, 10]
#     Unknown:   [9, 11, 14]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12, 13]
#     Unknown:   [10, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14]
#     Unknown:   [7, 10, 11, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12, 7]
#     Unknown:   [6, 8, 9, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9, 13, 14]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5]
#     Non-edges: [0, 7, 12, 2, 3, 8]
#     Unknown:   [1, 4, 6, 9, 10, 11, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12]
#     Non-edges: [1, 5, 9, 3, 6, 4]
#     Unknown:   [0, 2, 7, 8, 10, 11, 13]
#     Color:   None
# There are 19 unknown edges in the graph to check
# Checking 7<->9. Completion:     0.00%
# Checking 7<->11. Completion:     5.26%
# Checking 7<->14. Completion:    10.53%
# Edge added from 7 to 14; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12, 14]
#     Unknown:   [10, 13]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 14]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13, 10]
#     Unknown:   [9, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12, 13]
#     Unknown:   [10, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14]
#     Unknown:   [7, 10, 11, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12, 7]
#     Unknown:   [6, 8, 9, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9, 13, 14]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5]
#     Non-edges: [0, 7, 12, 2, 3, 8]
#     Unknown:   [1, 4, 6, 9, 10, 11, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12, 7]
#     Non-edges: [1, 5, 9, 3, 6, 4]
#     Unknown:   [0, 2, 8, 10, 11, 13]
#     Color:   None
# There are 18 unknown edges in the graph to check
# Checking 7<->9. Completion:     0.00%
# Checking 7<->11. Completion:     5.56%
# Checking 8<->10. Completion:    11.11%
# Checking 8<->14. Completion:    16.67%
# Checking 9<->10. Completion:    22.22%
# Non-edge added from 9 to 10; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12, 14]
#     Unknown:   [10, 13]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 14]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13, 10]
#     Unknown:   [9, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12, 13]
#     Unknown:   [10, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14, 10]
#     Unknown:   [7, 11, 13]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12, 7, 9]
#     Unknown:   [6, 8, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9, 13, 14]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5]
#     Non-edges: [0, 7, 12, 2, 3, 8]
#     Unknown:   [1, 4, 6, 9, 10, 11, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12, 7]
#     Non-edges: [1, 5, 9, 3, 6, 4]
#     Unknown:   [0, 2, 8, 10, 11, 13]
#     Color:   None
# There are 17 unknown edges in the graph to check
# Checking 9<->11. Completion:     0.00%
# Checking 9<->13. Completion:     5.88%
# Edge added from 9 to 13; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12, 14]
#     Unknown:   [10, 13]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 14]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13, 10]
#     Unknown:   [9, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12, 13]
#     Unknown:   [10, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12, 13]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14, 10]
#     Unknown:   [7, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12, 7, 9]
#     Unknown:   [6, 8, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12]
#     Unknown:   [7, 9, 13, 14]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5, 9]
#     Non-edges: [0, 7, 12, 2, 3, 8]
#     Unknown:   [1, 4, 6, 10, 11, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12, 7]
#     Non-edges: [1, 5, 9, 3, 6, 4]
#     Unknown:   [0, 2, 8, 10, 11, 13]
#     Color:   None
# There are 16 unknown edges in the graph to check
# Checking 9<->11. Completion:     0.00%
# Checking 10<->13. Completion:     6.25%
# Checking 10<->14. Completion:    12.50%
# Checking 11<->13. Completion:    18.75%
# Non-edge added from 11 to 13; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12, 14]
#     Unknown:   [10, 13]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 14]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13, 10]
#     Unknown:   [9, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12, 13]
#     Unknown:   [10, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12, 13]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14, 10]
#     Unknown:   [7, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12, 7, 9]
#     Unknown:   [6, 8, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12, 13]
#     Unknown:   [7, 9, 14]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5, 9]
#     Non-edges: [0, 7, 12, 2, 3, 8, 11]
#     Unknown:   [1, 4, 6, 10, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12, 7]
#     Non-edges: [1, 5, 9, 3, 6, 4]
#     Unknown:   [0, 2, 8, 10, 11, 13]
#     Color:   None
# There are 15 unknown edges in the graph to check
# Checking 11<->14. Completion:     0.00%
# Non-edge added from 11 to 14; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 11, 8, 10, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 12]
#     Non-edges: [7, 3, 4, 5, 6, 9, 11, 10, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 11, 8, 10, 5, 12, 13]
#     Unknown:   [14]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 10]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 11, 12, 13, 14]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 11, 10, 12, 14]
#     Unknown:   [13]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 12, 13]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 11, 14]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9, 11, 12, 14]
#     Unknown:   [10, 13]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 14]
#     Non-edges: [0, 1, 2, 3, 4, 8, 12, 13, 10]
#     Unknown:   [9, 11]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 11, 12, 13]
#     Unknown:   [10, 14]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 12, 13]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 14, 10]
#     Unknown:   [7, 11]
#     Color:   None
# Vertex 10:
#     Edges:     [3, 11]
#     Non-edges: [2, 4, 0, 1, 5, 12, 7, 9]
#     Unknown:   [6, 8, 13, 14]
#     Color:   None
# Vertex 11:
#     Edges:     [10]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 12, 13, 14]
#     Unknown:   [7, 9]
#     Color:   None
# Vertex 12:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 11, 10, 13]
#     Unknown:   []
#     Color:   None
# Vertex 13:
#     Edges:     [5, 9]
#     Non-edges: [0, 7, 12, 2, 3, 8, 11]
#     Unknown:   [1, 4, 6, 10, 14]
#     Color:   None
# Vertex 14:
#     Edges:     [12, 7]
#     Non-edges: [1, 5, 9, 3, 6, 4, 11]
#     Unknown:   [0, 2, 8, 10, 13]
#     Color:   None
# There are 14 unknown edges in the graph to check
# Checking 13<->14. Completion:     0.00%
# Checking 0<->14. Completion:     7.14%
# Checking 1<->13. Completion:    14.29%
# Checking 2<->14. Completion:    21.43%
# Checking 4<->13. Completion:    28.57%
# Checking 6<->10. Completion:    35.71%
# Checking 6<->13. Completion:    42.86%
# Checking 7<->9. Completion:    50.00%
# Checking 7<->11. Completion:    57.14%
# Checking 8<->10. Completion:    64.29%
# Checking 8<->14. Completion:    71.43%
# Checking 9<->11. Completion:    78.57%
# Checking 10<->13. Completion:    85.71%
# Checking 10<->14. Completion:    92.86%
# Checking if N(0) is contained in N(7) and N(8)
# N(0) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[], [1, 4], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 1: [[], [5, 6], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 2: [[], [1, 4, 5, 6], [14], [15], [], [], []]. done_list: []
# Checking if N(1) is contained in N(6) and N(9)
# N(1) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [8, 12], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0, 8, 12], [13], [15], [], [], []]. done_list: []
# Checking if N(2) is contained in N(0) and N(10)
# Checking if N(3) is contained in N(6) and N(8)
# Checking if 3 is degree 3.
# 3 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 3.
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 3 is colored None. Possible neighbors colored 0: [[4], [], [], [], [], [], []]. done_list: []
# Vertex 4 is colored 0. Possible neighbors colored 1: [[], [0, 8], [13], [15], [], [], []]. done_list: [(3, 0)]
# Vertex 4 is colored 0. Possible neighbors colored 2: [[], [0, 8], [13], [15], [], [], []]. done_list: [(3, 0)]
# Vertex 3 is colored None. Possible neighbors colored 1: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[], [1, 6], [14], [15], [], [], []]. done_list: [(3, 1)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[], [1, 6], [14], [15], [], [], []]. done_list: [(3, 1)]
# Vertex 3 is colored None. Possible neighbors colored 2: [[10], [], [], [], [], [], []]. done_list: []
# Vertex 10 is colored 2. Possible neighbors colored 0: [[], [11], [6, 14], [15], [], [], []]. done_list: [(3, 2)]
# Vertex 10 is colored 2. Possible neighbors colored 1: [[], [11], [8, 13], [15], [], [], []]. done_list: [(3, 2)]
# Checking if N(4) is contained in N(1) and N(10)
# Checking if N(5) is contained in N(1) and N(6)
# N(5) is contained in N(1) and N(6). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [7, 13], [], [15], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [12, 13], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 2: [[0], [7, 12, 13], [], [15], [], [], []]. done_list: []
# Checking if N(5) is contained in N(1) and N(14)
# Checking if N(5) is contained in N(4) and N(14)
# Checking if N(5) is contained in N(6) and N(9)
# N(5) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [12, 13], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [0, 7], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 2: [[], [0, 7, 12, 13], [], [15], [], [], []]. done_list: []
# Checking if N(5) is contained in N(6) and N(14)
# N(5) is contained in N(6) and N(14). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [12, 13], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [0, 13], [], [15], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 2: [[7], [0, 12, 13], [], [15], [], [], []]. done_list: []
# Checking if N(6) is contained in N(3) and N(5)
# N(6) is contained in N(3) and N(5). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[], [0, 7], [13], [15], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 1: [[], [2], [10], [15], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 2: [[], [0, 2, 7], [10, 13], [15], [], [], []]. done_list: []
# Checking if N(7) is contained in N(10) and N(13)
# Checking if N(8) is contained in N(3) and N(12)
# N(8) is contained in N(3) and N(12). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 8 is colored None. Possible neighbors colored 0: [[], [1, 9], [14], [15], [], [], []]. done_list: []
# Vertex 8 is colored None. Possible neighbors colored 1: [[], [4], [10], [15], [], [], []]. done_list: []
# Vertex 8 is colored None. Possible neighbors colored 2: [[], [1, 4, 9], [10, 14], [15], [], [], []]. done_list: []
# Checking if N(9) is contained in N(10) and N(14)
# Checking if N(11) is contained in N(6) and N(8)
# Checking if N(11) is contained in N(6) and N(13)
# Checking if N(11) is contained in N(8) and N(14)
# Checking if N(11) is contained in N(13) and N(14)
# Checking if N(12) is contained in N(0) and N(8)
# N(12) is contained in N(0) and N(8). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 12 is colored None. Possible neighbors colored 0: [[], [9, 14], [], [15], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 1: [[], [5, 14], [], [], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 2: [[1], [5, 9, 14], [], [15], [], [], []]. done_list: []
# Checking if N(12) is contained in N(0) and N(13)
# Checking if N(12) is contained in N(2) and N(13)
# Checking if N(12) is contained in N(7) and N(8)
# N(12) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 12 is colored None. Possible neighbors colored 0: [[], [1, 9], [], [], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 1: [[], [5, 14], [], [], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 2: [[], [1, 5, 9, 14], [], [15], [], [], []]. done_list: []
# Checking if N(12) is contained in N(8) and N(13)
# N(12) is contained in N(8) and N(13). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 12 is colored None. Possible neighbors colored 0: [[], [5, 14], [], [], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 1: [[], [1, 14], [], [15], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 2: [[9], [1, 5, 14], [], [15], [], [], []]. done_list: []
# False

# %%
test_graph2.get_edgelists(lem3_5_list0)
# Out:
# [frozenset({frozenset({2, 14}), frozenset({0, 14}), frozenset({8, 14})}),
#  frozenset({frozenset({6, 13}), frozenset({1, 13}), frozenset({4, 13})})]

# %%
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].non_edges.append(3)
new_vert=vert([1, 4], [5, 6], 8)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([7], [0, 1, 2, 3, 4, 5, 6, 8], 10)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
#test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5)
test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5, update_speed='fast', check_deg_three=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 8, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 10, 2, 9]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 10, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 10, 0, 2, 3, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6]
#     Unknown:   [7, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8]
#     Unknown:   [9]
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 7<->9. Completion:     0.00%
# Non-edge added from 7 to 9; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 8, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 10, 2, 9]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 10, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 10, 0, 2, 3, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7]
#     Unknown:   [10]
#     Color:   None
# Vertex 10:
#     Edges:     [7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8]
#     Unknown:   [9]
#     Color:   None
# There are 1 unknown edges in the graph to check
# Checking 9<->10. Completion:     0.00%
# Vertex 11 added adjacent to 1 that cannot be adjacent to [0, 2, 3, 4, 6]
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 11]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 8, 5, 11]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5, 9, 10, 8, 11]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 11]
#     Non-edges: [1, 4, 6, 3, 8, 10, 2, 9]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 10, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 10]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [5, 6, 10, 0, 2, 3, 7, 11]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8, 11]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7]
#     Unknown:   [10]
#     Color:   None
# Vertex 10:
#     Edges:     [7]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 11]
#     Unknown:   [9]
#     Color:   None
# Vertex 11:
#     Edges:     [1, 5, 9]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 10]
#     Unknown:   []
#     Color:   None
# There are 1 unknown edges in the graph to check
# Checking 9<->10. Completion:     0.00%
# Checking if N(0) is contained in N(7) and N(8)
# N(0) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[], [1, 4], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 1: [[], [5, 6], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 2: [[], [1, 4, 5, 6], [], [], [], [], []]. done_list: []
# Checking if N(1) is contained in N(6) and N(9)
# N(1) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [8, 11], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0, 8, 11], [], [], [], [], []]. done_list: []
# Checking if N(2) is contained in N(0) and N(4)
# Checking if 2 is degree 3.
# 2 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 2.
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 2 is colored None. Possible neighbors colored 0: [[3], [], [], [], [], [], []]. done_list: []
# Vertex 3 is colored 0. Possible neighbors colored 1: [[], [4], [], [12], [], [], []]. done_list: [(2, 0)]
# Vertex 3 is colored 0. Possible neighbors colored 2: [[], [4], [], [12], [], [], []]. done_list: [(2, 0)]
# Vertex 2 is colored None. Possible neighbors colored 1: [[1], [], [], [], [], [], []]. done_list: []
# Vertex 1 is colored 1. Possible neighbors colored 0: [[0], [8, 11], [], [], [], [], []]. done_list: [(2, 1)]
# Vertex 1 is colored 1. Possible neighbors colored 2: [[], [8, 11], [], [], [], [], []]. done_list: [(2, 1)]
# Vertex 2 is colored None. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: []
# Vertex 6 is colored 2. Possible neighbors colored 0: [[0], [7], [], [], [], [], []]. done_list: [(2, 2)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[], [7], [], [12], [], [], []]. done_list: [(2, 2)]
# Checking if N(3) is contained in N(0) and N(1)
# Checking if N(3) is contained in N(0) and N(6)
# Checking if N(3) is contained in N(1) and N(8)
# Checking if N(3) is contained in N(6) and N(8)
# Checking if N(4) is contained in N(1) and N(2)
# Checking if 4 is degree 3.
# 4 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 4.
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 4 is colored None. Possible neighbors colored 0: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 0. Possible neighbors colored 1: [[1], [5, 6], [], [], [], [], []]. done_list: [(4, 0)]
# Vertex 0 is colored 0. Possible neighbors colored 2: [[], [5, 6], [], [], [], [], []]. done_list: [(4, 0)]
# Vertex 4 is colored None. Possible neighbors colored 1: [[3], [], [], [], [], [], []]. done_list: []
# Vertex 3 is colored 1. Possible neighbors colored 0: [[], [2], [], [12], [], [], []]. done_list: [(4, 1)]
# Vertex 3 is colored 1. Possible neighbors colored 2: [[], [2], [], [12], [], [], []]. done_list: [(4, 1)]
# Vertex 4 is colored None. Possible neighbors colored 2: [[8], [], [], [], [], [], []]. done_list: []
# Vertex 8 is colored 2. Possible neighbors colored 0: [[], [9], [], [12], [], [], []]. done_list: [(4, 2)]
# Vertex 8 is colored 2. Possible neighbors colored 1: [[1], [9], [], [], [], [], []]. done_list: [(4, 2)]
# Checking if N(5) is contained in N(1) and N(6)
# Checking if N(5) is contained in N(1) and N(10)
# Checking if N(5) is contained in N(6) and N(9)
# N(5) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [11], [], [12], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [0, 7], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 2: [[], [0, 7, 11], [], [12], [], [], []]. done_list: []
# Checking if 5 is degree 3.
# 5 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 5.
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 0. Possible neighbors colored 1: [[1], [4], [], [], [], [], []]. done_list: [(5, 0)]
# Vertex 0 is colored 0. Possible neighbors colored 2: [[6], [4], [], [], [], [], []]. done_list: [(5, 0)]
# Vertex 5 is colored None. Possible neighbors colored 1: [[7], [], [], [], [], [], []]. done_list: []
# Vertex 7 is colored 1. Possible neighbors colored 0: [[], [10], [], [], [], [], []]. done_list: [(5, 1)]
# Vertex 10 is colored 0. Possible neighbors colored 1: [[], [], [9], [12], [], [], []]. done_list: [(5, 1), (7, 0)]
# Vertex 10 is colored 0. Possible neighbors colored 2: [[], [], [], [12], [], [], []]. done_list: [(5, 1), (7, 0)]
# Vertex 12 is colored 2. Possible neighbors colored 0: [[], [], [9], [13], [], [], []]. done_list: [(5, 1), (7, 0), (10, 2)]
# Vertex 12 is colored 2. Possible neighbors colored 1: [[], [], [3, 9], [13], [], [], []]. done_list: [(5, 1), (7, 0), (10, 2)]
# Vertex 7 is colored 1. Possible neighbors colored 2: [[6], [], [], [], [], [], []]. done_list: [(5, 1)]
# Vertex 6 is colored 2. Possible neighbors colored 0: [[0, 2], [], [], [], [], [], []]. done_list: [(5, 1), (7, 2)]
# Vertex 6 is colored 2. Possible neighbors colored 1: [[], [], [], [13], [], [], []]. done_list: [(5, 1), (7, 2)]
# Vertex 13 is colored 1. Possible neighbors colored 0: [[10], [], [], [], [], [], []]. done_list: [(5, 1), (7, 2), (6, 1)]
# Vertex 10 is colored 0. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: [(5, 1), (7, 2), (6, 1), (13, 0)]
# 5 Must have degree at least 4; adding a new neighbor and updating...
# Checking if N(6) is contained in N(1) and N(5)
# Checking if N(6) is contained in N(1) and N(10)
# N(6) is contained in N(1) and N(10). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[], [7], [], [13], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 1: [[], [0, 2], [], [], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 2: [[], [0, 2, 7], [], [13], [], [], []]. done_list: []
# Checking if N(6) is contained in N(3) and N(5)
# N(6) is contained in N(3) and N(5). Attempting coloring...
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[], [0, 7], [], [], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 1: [[], [2], [], [13], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 2: [[], [0, 2, 7], [], [13], [], [], []]. done_list: []
# Checking if 6 is degree 3.
# 6 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 6.
# Iteration: 1
# There are 13 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[0], [], [], [], [], [], []]. done_list: []
# Vertex 0 is colored 0. Possible neighbors colored 1: [[5], [4], [], [], [], [], []]. done_list: [(6, 0)]
# Vertex 0 is colored 0. Possible neighbors colored 2: [[1], [4], [], [], [], [], []]. done_list: [(6, 0)]
# Vertex 6 is colored None. Possible neighbors colored 1: [[2], [], [], [], [], [], []]. done_list: []
# Vertex 2 is colored 1. Possible neighbors colored 0: [[], [3], [], [], [], [], []]. done_list: [(6, 1)]
# Vertex 3 is colored 0. Possible neighbors colored 1: [[], [4], [], [13], [], [], []]. done_list: [(6, 1), (2, 0)]
# Vertex 3 is colored 0. Possible neighbors colored 2: [[], [4], [], [13], [], [], []]. done_list: [(6, 1), (2, 0)]
# Vertex 2 is colored 1. Possible neighbors colored 2: [[1], [], [], [], [], [], []]. done_list: [(6, 1)]
# Vertex 1 is colored 2. Possible neighbors colored 0: [[0, 11], [8], [], [], [], [], []]. done_list: [(6, 1), (2, 2)]
# Vertex 1 is colored 2. Possible neighbors colored 1: [[], [8], [], [], [], [], []]. done_list: [(6, 1), (2, 2)]
# Vertex 8 is colored 1. Possible neighbors colored 0: [[], [], [], [], [], [], []]. done_list: [(6, 1), (2, 2), (1, 1)]
# 6 Must have degree at least 4; adding a new neighbor and updating...
# Checking if N(7) is contained in N(0) and N(13)
# Checking if N(7) is contained in N(11) and N(13)
# N(7) is contained in N(11) and N(13). Attempting coloring...
# Iteration: 1
# There are 14 vertices in the graph.
# Vertex 7 is colored None. Possible neighbors colored 0: [[], [6, 10], [], [], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 1: [[], [5], [], [14], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 2: [[], [5, 6, 10], [], [14], [], [], []]. done_list: []
# Checking if N(7) is contained in N(12) and N(13)
# Checking if 7 is degree 3.
# 7 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 7.
# Iteration: 1
# There are 14 vertices in the graph.
# Vertex 7 is colored None. Possible neighbors colored 0: [[5], [], [], [], [], [], []]. done_list: []
# Vertex 5 is colored 0. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: [(7, 0)]
# 7 Must have degree at least 4; adding a new neighbor and updating...
# Checking if N(8) is contained in N(3) and N(11)
# N(8) is contained in N(3) and N(11). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 8 is colored None. Possible neighbors colored 0: [[], [1, 9], [], [], [], [], []]. done_list: []
# Vertex 8 is colored None. Possible neighbors colored 1: [[], [4], [13], [15], [], [], []]. done_list: []
# Vertex 8 is colored None. Possible neighbors colored 2: [[], [1, 4, 9], [13], [15], [], [], []]. done_list: []
# Checking if N(10) is contained in N(6) and N(8)
# Checking if N(10) is contained in N(6) and N(11)
# Checking if N(10) is contained in N(6) and N(12)
# Checking if N(11) is contained in N(2) and N(12)
# N(11) is contained in N(2) and N(12). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 11 is colored None. Possible neighbors colored 0: [[], [5, 9], [], [], [], [], []]. done_list: []
# Vertex 11 is colored None. Possible neighbors colored 1: [[], [1, 14], [], [], [], [], []]. done_list: []
# Vertex 11 is colored None. Possible neighbors colored 2: [[], [1, 5, 9, 14], [], [], [], [], []]. done_list: []
# Checking if N(11) is contained in N(7) and N(8)
# N(11) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 11 is colored None. Possible neighbors colored 0: [[], [1, 9], [], [], [], [], []]. done_list: []
# Vertex 11 is colored None. Possible neighbors colored 1: [[], [5, 14], [], [], [], [], []]. done_list: []
# Vertex 11 is colored None. Possible neighbors colored 2: [[], [1, 5, 9, 14], [], [], [], [], []]. done_list: []
# Checking if N(12) is contained in N(3) and N(11)
# N(12) is contained in N(3) and N(11). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 12 is colored None. Possible neighbors colored 0: [[], [5, 9], [], [], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 1: [[], [4], [13], [15], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 2: [[], [5, 9, 4], [13], [15], [], [], []]. done_list: []
# Checking if N(13) is contained in N(4) and N(7)
# N(13) is contained in N(4) and N(7). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 13 is colored None. Possible neighbors colored 0: [[], [6, 10], [], [], [], [], []]. done_list: []
# Vertex 13 is colored None. Possible neighbors colored 1: [[], [3], [8, 12], [], [], [], []]. done_list: []
# Vertex 13 is colored None. Possible neighbors colored 2: [[], [6, 10, 3], [8, 12], [15], [], [], []]. done_list: []
# Checking if N(14) is contained in N(1) and N(5)
# Checking if N(14) is contained in N(1) and N(6)
# Checking if N(14) is contained in N(1) and N(10)
# N(14) is contained in N(1) and N(10). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 14 is colored None. Possible neighbors colored 0: [[], [7], [], [15], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 1: [[], [2, 11], [], [], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 2: [[], [7, 2, 11], [], [15], [], [], []]. done_list: []
# Checking if N(14) is contained in N(3) and N(5)
# N(14) is contained in N(3) and N(5). Attempting coloring...
# Iteration: 1
# There are 15 vertices in the graph.
# Vertex 14 is colored None. Possible neighbors colored 0: [[], [7, 11], [], [], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 1: [[], [2], [], [15], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 2: [[], [7, 2, 11], [], [15], [], [], []]. done_list: []
# Checking if N(14) is contained in N(5) and N(6)
# Checking if N(14) is contained in N(6) and N(9)
# Checking if 14 is degree 3.
# 14 is not forced to be degree 3. Attempting coloring to try to force a new neighbor of 14.
# 14 Must have degree at least 4; adding a new neighbor and updating...
# Checking if N(15) is contained in N(4) and N(7)
# N(15) is contained in N(4) and N(7). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 15 is colored None. Possible neighbors colored 0: [[], [14, 10], [], [], [], [], []]. done_list: []
# Vertex 15 is colored None. Possible neighbors colored 1: [[], [3], [8, 12], [], [], [], []]. done_list: []
# Vertex 15 is colored None. Possible neighbors colored 2: [[], [14, 10, 3], [8, 12], [], [], [], []]. done_list: []
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8, 11, 12, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8, 11]
#     Non-edges: [3, 4, 5, 6, 7, 9, 10, 12, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 14]
#     Non-edges: [0, 4, 5, 7, 8, 9, 10, 11, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 13, 15]
#     Non-edges: [0, 1, 5, 6, 7, 8, 9, 10, 11, 12, 14]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8, 12]
#     Non-edges: [1, 2, 5, 6, 7, 9, 10, 11, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 11, 12]
#     Non-edges: [1, 2, 3, 4, 6, 8, 9, 10, 13, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 13]
#     Non-edges: [1, 3, 4, 5, 8, 9, 10, 11, 12, 14, 15]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 10, 14]
#     Non-edges: [0, 1, 2, 3, 4, 8, 9, 11, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [1, 4, 9]
#     Non-edges: [0, 2, 3, 5, 6, 7, 10, 11, 12, 14]
#     Unknown:   [13, 15]
#     Color:   None
# Vertex 9:
#     Edges:     [8, 11, 12]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 7, 13, 14, 15]
#     Unknown:   [10]
#     Color:   None
# Vertex 10:
#     Edges:     [7, 13, 15]
#     Non-edges: [0, 1, 2, 3, 4, 5, 6, 8, 11, 12, 14]
#     Unknown:   [9]
#     Color:   None
# Vertex 11:
#     Edges:     [1, 5, 9, 14]
#     Non-edges: [0, 2, 3, 4, 6, 7, 8, 10, 12, 13, 15]
#     Unknown:   []
#     Color:   None
# Vertex 12:
#     Edges:     [5, 9, 4]
#     Non-edges: [0, 1, 2, 3, 6, 7, 8, 10, 11, 14]
#     Unknown:   [13, 15]
#     Color:   None
# Vertex 13:
#     Edges:     [6, 10, 3]
#     Non-edges: [0, 1, 2, 4, 5, 7, 9, 11, 14, 15]
#     Unknown:   [8, 12]
#     Color:   None
# Vertex 14:
#     Edges:     [7, 2, 11, 15]
#     Non-edges: [5, 6, 10, 1, 0, 3, 4, 8, 9, 12, 13]
#     Unknown:   []
#     Color:   None
# Vertex 15:
#     Edges:     [14, 10, 3]
#     Non-edges: [2, 7, 11, 13, 0, 1, 4, 5, 6, 9]
#     Unknown:   [8, 12]
#     Color:   None
# There are 5 unknown edges in the graph to check
# Checking 8<->13. Completion:     0.00%
# Checking 8<->15. Completion:    20.00%
# Checking 9<->10. Completion:    40.00%
# Checking 12<->13. Completion:    60.00%
# Checking 12<->15. Completion:    80.00%
# Checking if N(0) is contained in N(2) and N(12)
# N(0) is contained in N(2) and N(12). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[], [4, 5], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 1: [[], [1, 6], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 2: [[], [1, 4, 5, 6], [], [], [], [], []]. done_list: []
# Checking if N(0) is contained in N(7) and N(8)
# N(0) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[], [1, 4], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 1: [[], [5, 6], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 2: [[], [1, 4, 5, 6], [], [], [], [], []]. done_list: []
# Checking if N(1) is contained in N(4) and N(14)
# N(1) is contained in N(4) and N(14). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [2, 11], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [0, 8], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0, 8, 11], [], [], [], [], []]. done_list: []
# Checking if N(1) is contained in N(6) and N(9)
# N(1) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [8, 11], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [2, 0], [], [], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[], [2, 0, 8, 11], [], [], [], [], []]. done_list: []
# Checking if N(2) is contained in N(0) and N(15)
# N(2) is contained in N(0) and N(15). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 2 is colored None. Possible neighbors colored 0: [[], [3, 14], [], [], [], [], []]. done_list: []
# Vertex 2 is colored None. Possible neighbors colored 1: [[], [1, 6], [], [], [], [], []]. done_list: []
# Vertex 2 is colored None. Possible neighbors colored 2: [[], [3, 1, 6, 14], [], [], [], [], []]. done_list: []
# Checking if N(2) is contained in N(11) and N(13)
# N(2) is contained in N(11) and N(13). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 2 is colored None. Possible neighbors colored 0: [[], [3, 6], [], [], [], [], []]. done_list: []
# Vertex 2 is colored None. Possible neighbors colored 1: [[], [1, 14], [], [], [], [], []]. done_list: []
# Vertex 2 is colored None. Possible neighbors colored 2: [[], [3, 1, 6, 14], [], [], [], [], []]. done_list: []
# Checking if N(5) is contained in N(4) and N(14)
# N(5) is contained in N(4) and N(14). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [7, 11], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [0, 12], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 2: [[], [0, 7, 11, 12], [], [], [], [], []]. done_list: []
# Checking if N(5) is contained in N(6) and N(9)
# N(5) is contained in N(6) and N(9). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 5 is colored None. Possible neighbors colored 0: [[], [11, 12], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 1: [[], [0, 7], [], [], [], [], []]. done_list: []
# Vertex 5 is colored None. Possible neighbors colored 2: [[], [0, 7, 11, 12], [], [], [], [], []]. done_list: []
# Checking if N(6) is contained in N(1) and N(10)
# N(6) is contained in N(1) and N(10). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[], [7, 13], [], [], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 1: [[], [0, 2], [], [], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 2: [[], [0, 2, 7, 13], [], [], [], [], []]. done_list: []
# Checking if N(6) is contained in N(3) and N(5)
# N(6) is contained in N(3) and N(5). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 6 is colored None. Possible neighbors colored 0: [[], [0, 7], [], [], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 1: [[], [2, 13], [], [], [], [], []]. done_list: []
# Vertex 6 is colored None. Possible neighbors colored 2: [[], [0, 2, 7, 13], [], [], [], [], []]. done_list: []
# Checking if N(7) is contained in N(0) and N(15)
# N(7) is contained in N(0) and N(15). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 7 is colored None. Possible neighbors colored 0: [[], [10, 14], [], [], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 1: [[], [5, 6], [], [], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 2: [[], [5, 6, 10, 14], [], [], [], [], []]. done_list: []
# Checking if N(7) is contained in N(11) and N(13)
# N(7) is contained in N(11) and N(13). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 7 is colored None. Possible neighbors colored 0: [[], [6, 10], [], [], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 1: [[], [5, 14], [], [], [], [], []]. done_list: []
# Vertex 7 is colored None. Possible neighbors colored 2: [[], [5, 6, 10, 14], [], [], [], [], []]. done_list: []
# Checking if N(8) is contained in N(3) and N(11)
# N(8) is contained in N(3) and N(11). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 8 is colored None. Possible neighbors colored 0: [[], [1, 9], [], [], [], [], []]. done_list: []
# Vertex 8 is colored None. Possible neighbors colored 1: [[], [4], [13, 15], [], [], [], []]. done_list: []
# Vertex 8 is colored None. Possible neighbors colored 2: [[], [1, 4, 9], [13, 15], [16], [], [], []]. done_list: []
# Checking if N(11) is contained in N(2) and N(12)
# N(11) is contained in N(2) and N(12). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 11 is colored None. Possible neighbors colored 0: [[], [5, 9], [], [], [], [], []]. done_list: []
# Vertex 11 is colored None. Possible neighbors colored 1: [[], [1, 14], [], [], [], [], []]. done_list: []
# Vertex 11 is colored None. Possible neighbors colored 2: [[], [1, 5, 9, 14], [], [], [], [], []]. done_list: []
# Checking if N(11) is contained in N(7) and N(8)
# N(11) is contained in N(7) and N(8). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 11 is colored None. Possible neighbors colored 0: [[], [1, 9], [], [], [], [], []]. done_list: []
# Vertex 11 is colored None. Possible neighbors colored 1: [[], [5, 14], [], [], [], [], []]. done_list: []
# Vertex 11 is colored None. Possible neighbors colored 2: [[], [1, 5, 9, 14], [], [], [], [], []]. done_list: []
# Checking if N(12) is contained in N(3) and N(11)
# N(12) is contained in N(3) and N(11). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 12 is colored None. Possible neighbors colored 0: [[], [5, 9], [], [], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 1: [[], [4], [13, 15], [], [], [], []]. done_list: []
# Vertex 12 is colored None. Possible neighbors colored 2: [[], [5, 9, 4], [13, 15], [], [], [], []]. done_list: []
# Checking if N(13) is contained in N(4) and N(7)
# N(13) is contained in N(4) and N(7). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 13 is colored None. Possible neighbors colored 0: [[], [6, 10], [], [], [], [], []]. done_list: []
# Vertex 13 is colored None. Possible neighbors colored 1: [[], [3], [8, 12], [], [], [], []]. done_list: []
# Vertex 13 is colored None. Possible neighbors colored 2: [[], [6, 10, 3], [8, 12], [16], [], [], []]. done_list: []
# Checking if N(14) is contained in N(1) and N(10)
# N(14) is contained in N(1) and N(10). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 14 is colored None. Possible neighbors colored 0: [[], [7, 15], [], [], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 1: [[], [2, 11], [], [], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 2: [[], [7, 2, 11, 15], [], [], [], [], []]. done_list: []
# Checking if N(14) is contained in N(3) and N(5)
# N(14) is contained in N(3) and N(5). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 14 is colored None. Possible neighbors colored 0: [[], [7, 11], [], [], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 1: [[], [2, 15], [], [], [], [], []]. done_list: []
# Vertex 14 is colored None. Possible neighbors colored 2: [[], [7, 2, 11, 15], [], [], [], [], []]. done_list: []
# Checking if N(15) is contained in N(4) and N(7)
# N(15) is contained in N(4) and N(7). Attempting coloring...
# Iteration: 1
# There are 16 vertices in the graph.
# Vertex 15 is colored None. Possible neighbors colored 0: [[], [14, 10], [], [], [], [], []]. done_list: []
# Vertex 15 is colored None. Possible neighbors colored 1: [[], [3], [8, 12], [], [], [], []]. done_list: []
# Vertex 15 is colored None. Possible neighbors colored 2: [[], [14, 10, 3], [8, 12], [], [], [], []]. done_list: []
# False
