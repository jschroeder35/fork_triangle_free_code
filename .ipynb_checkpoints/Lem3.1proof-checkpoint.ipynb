# %%
from graph_algs_test_build import *

# %%
###Set up starting graph
v_0 = vert([1, 4, 5, 6], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1, 6], [], 2)
v_3 = vert([4, 2, 5], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 3, 7], [], 5)
v_6 = vert([0, 2, 8], [], 6)
v_7 = vert([5, 8], [0, 1, 2, 3, 4], 7)
v_8 = vert([6, 7], [0, 1, 2, 3, 4], 8)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7, v_8])
test_graph.clean()
print(test_graph.update_graph([fork, triangle]))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 8]
#     Non-edges: [1, 3, 4, 5, 7]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8]
#     Non-edges: [0, 1, 2, 3, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   []
#     Color:   None

# %%
test_graph2=copy.deepcopy(test_graph)
test_graph2.update_graph5([fork, triangle], verbose=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5, 9]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 6, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 8]
#     Non-edges: [1, 3, 4, 5, 7]
#     Unknown:   [9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8]
#     Non-edges: [0, 1, 2, 3, 4, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 8:
#     Edges:     [6, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [9]
#     Color:   None
# Vertex 9:
#     Edges:     []
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 8]
#     Color:   None
# There are 4 unknown edges in the graph to check
# Checking 5<->9. Completion:     0.00%
# Checking 6<->9. Completion:    25.00%
# Checking 7<->9. Completion:    50.00%
# Checking 8<->9. Completion:    75.00%
# Vertex 10 added!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 6, 8]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 8]
#     Non-edges: [1, 3, 4, 5, 7, 10]
#     Unknown:   [9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8]
#     Non-edges: [0, 1, 2, 3, 4, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 8:
#     Edges:     [6, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 9:
#     Edges:     []
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [5, 6, 7, 8, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [1]
#     Non-edges: [6, 0, 2, 3]
#     Unknown:   [4, 5, 7, 8, 9]
#     Color:   None
# There are 9 unknown edges in the graph to check
# Checking 4<->10. Completion:     0.00%
# Checking 5<->9. Completion:    11.11%
# Checking 5<->10. Completion:    22.22%
# Checking 6<->9. Completion:    33.33%
# Checking 7<->9. Completion:    44.44%
# Checking 7<->10. Completion:    55.56%
# Checking 8<->9. Completion:    66.67%
# Checking 8<->10. Completion:    77.78%
# Checking 9<->10. Completion:    88.89%
# Checking if N(0) is contained in N(2) and N(3)
# N(0) is contained in N(2) and N(3). Attempting coloring...
# Iteration: 1
# There are 11 vertices in the graph.
# vertex: 0, done_list: [], colors: None->0, [[], [4, 5], [], [11], [], [], []], num_vertices: 11
# vertex: 0, done_list: [], colors: None->1, [[], [1, 6], [], [11], [], [], []], num_vertices: 11
# vertex: 0, done_list: [], colors: None->2, [[], [1, 4, 5, 6], [], [11], [], [], []], num_vertices: 11
# Checking if N(2) is contained in N(0) and N(4)
# Checking if N(2) is contained in N(0) and N(5)
# Checking if N(3) is contained in N(0) and N(1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/g1/fwv1fw7x3_d5xr_5fk_dfdph0000gn/T/ipykernel_1836/218982538.py in <module>
#       3 test_graph2.vertex_list.append(new_vert)
#       4 test_graph2.clean()
# ----> 5 test_graph2.update_graph5([fork, triangle], verbose=True)
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in update_graph5(self, subgraph_list, add_vertices, quick_update, max_distance, verbose)
#     712                                 continue
#     713                         else:
# --> 714                             if not temp_graph.update_graph3(subgraph_list, start_vert=None, verbose=False, with_colors=False):
#     715                                 continue
#     716
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in update_graph3(self, subgraph_list, start_vert, verbose, with_colors)
#     625
#     626                             ##### Check both cases. If there is a contradiction in either case, return True #####
# --> 627                             bool1 = temp_graph.update_graph2(subgraph_list, 1, start_vert, 0, verbose=False, with_colors=with_colors)
#     628                             bool2 = temp_graph2.update_graph2(subgraph_list, 1, start_vert, 0, verbose=False, with_colors=with_colors)
#     629                             if (bool1 and bool2):
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in update_graph2(self, subgraph_list, max_depth, start_vert, current_depth, verbose, with_colors)
#     531                     temp_graph.vertex_list[edge[0]].edges.append(edge[1])
#     532                     temp_graph.clean()
# --> 533                     if temp_graph.update_graph(subgraph_list, start_vert, with_colors):
#     534                         continue
#     535                     #####Recurse if less than max_depth
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in update_graph(self, subgraph_list, start_vert, with_colors)
#     494                     return True
#     495             else:
# --> 496                 if self.check_for_subgraphs_iter(subgraph_list):
#     497                     return True
#     498             updated =False
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in check_for_subgraphs_iter(self, subgraph_list, depth_cutoff)
#     316             while True:
#     317                 old_graph = copy.deepcopy(self)
# --> 318                 bool1=self.check_for_subgraphs(subgraph_list, i)
#     319                 if bool1:
#     320                     return True
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in check_for_subgraphs(self, subgraph_list, depth_cutoff)
#     297                             ##### Check both cases. If there is a contradiction in either case, return True #####
#     298                             bool1 = temp_graph.check_for_subgraphs(subgraph_list, depth_cutoff)
# --> 299                             bool2 = temp_graph2.check_for_subgraphs(subgraph_list, depth_cutoff)
#     300                             if (bool1 and bool2):
#     301                                 return True
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in check_for_subgraphs(self, subgraph_list, depth_cutoff)
#     275         #####In practice, little is gained by a depth cutoff of more than one#####
#     276         #####Method returns True if a fork/triangle is forced, False otherwise #####
# --> 277         if self.contains_subgraphs(subgraph_list):
#     278             return True
#     279
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in contains_subgraphs(self, subgraph_list)
#     156             temp_edges=[i for i, vert in enumerate(past_vertex_list) if vert in vertex.edges]
#     157             temp_non_edges=[i for i, vert in enumerate(past_vertex_list) if vert in vertex.non_edges]
# --> 158             key=(frozenset(temp_edges), frozenset(temp_non_edges))
#     159             #print(vertex.index, past_vertex_list)
#     160             ###now we can check if the vertex is a valid addition to build out one of our subgraphs.
#
# KeyboardInterrupt:

# %%
###Shows that a1 and b1 must be degree at least 4. 
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].max_degree=3
test_graph2.vertex_list[5].color_start=True
test_graph2.fill_in_colors()
test_graph2.color_argument_iter([fork, triangle], 5, 10)
# Out:
# Iteration: 1
# There are 9 vertices in the graph.
# vertex: 5, done_list: [], colors: None->0, [[0], [], [], [], [], [], []], num_vertices: 9
# vertex: 0, done_list: [(5, 0)], colors: 0->1, [[], [1, 6], [], [9], [], [], []], num_vertices: 9
# vertex: 0, done_list: [(5, 0)], colors: 0->2, [[4], [1, 6], [], [9], [], [], []], num_vertices: 9
# vertex: 5, done_list: [], colors: None->1, [[3], [], [], [], [], [], []], num_vertices: 9
# vertex: 3, done_list: [(5, 1)], colors: 1->0, [[], [2], [], [9], [], [], []], num_vertices: 9
# vertex: 3, done_list: [(5, 1)], colors: 1->2, [[4], [2], [], [], [], [], []], num_vertices: 9
# vertex: 5, done_list: [], colors: None->2, [[7], [], [], [], [], [], []], num_vertices: 9
# vertex: 7, done_list: [(5, 2)], colors: 2->0, [[], [8], [], [9], [], [], []], num_vertices: 9
# vertex: 7, done_list: [(5, 2)], colors: 2->1, [[], [8], [], [9], [], [], []], num_vertices: 9
# False

# %%
###First add a new neighbor to a1
new_vert= vert([5], [], len(test_graph.vertex_list))
test_graph.vertex_list.append(new_vert)
test_graph.clean()
test_graph.update_graph3([fork, triangle], verbose=True, with_colors=False)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   [9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7, 9]
#     Non-edges: [1, 2, 4, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 8]
#     Non-edges: [1, 3, 4, 5, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8]
#     Non-edges: [0, 1, 2, 3, 4, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 7, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [5, 8]
#     Non-edges: [0, 3, 7, 6]
#     Unknown:   [1, 2, 4]
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Checking 2<->9. Completion:    33.33%
# Checking 4<->9. Completion:    66.67%
# False

# %%
###Since the new vertex cannot be adjacent to b1, add another new vertex adjacent to b1
new_vert= vert([6], [], len(test_graph.vertex_list))
test_graph.vertex_list.append(new_vert)
test_graph.clean()
test_graph.update_graph3([fork, triangle], verbose=True, with_colors=False)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5, 10]
#     Unknown:   [9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7, 9]
#     Non-edges: [1, 2, 4, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 8, 10]
#     Non-edges: [1, 3, 4, 5, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8, 10]
#     Non-edges: [0, 1, 2, 3, 4, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 7, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 10]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [5, 8]
#     Non-edges: [0, 3, 7, 6]
#     Unknown:   [1, 2, 4, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [6, 7]
#     Non-edges: [0, 2, 8, 5]
#     Unknown:   [1, 3, 4, 9]
#     Color:   None
# There are 7 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Checking 1<->10. Completion:    14.29%
# Checking 2<->9. Completion:    28.57%
# Checking 3<->10. Completion:    42.86%
# Checking 4<->9. Completion:    57.14%
# Checking 4<->10. Completion:    71.43%
# Checking 9<->10. Completion:    85.71%
# False

# %%
test_graph2=copy.deepcopy(test_graph)
test_graph2.update_graph5([fork, triangle], verbose=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5, 10]
#     Unknown:   [9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7, 9]
#     Non-edges: [1, 2, 4, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 8, 10]
#     Non-edges: [1, 3, 4, 5, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8, 10]
#     Non-edges: [0, 1, 2, 3, 4, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 7, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 10]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [5, 8]
#     Non-edges: [0, 3, 7, 6]
#     Unknown:   [1, 2, 4, 10]
#     Color:   None
# Vertex 10:
#     Edges:     [6, 7]
#     Non-edges: [0, 2, 8, 5]
#     Unknown:   [1, 3, 4, 9]
#     Color:   None
# There are 7 unknown edges in the graph to check
# Checking 1<->9. Completion:     0.00%
# Checking 1<->10. Completion:    14.29%
# Checking 2<->9. Completion:    28.57%
# Checking 3<->10. Completion:    42.86%
# Checking 4<->9. Completion:    57.14%
# Checking 4<->10. Completion:    71.43%
# Checking 9<->10. Completion:    85.71%
# Checking if N(0) is contained in N(2) and N(3)
# N(0) is contained in N(2) and N(3). Attempting coloring...
# Iteration: 1
# There are 11 vertices in the graph.
# vertex: 0, done_list: [], colors: None->0, [[], [4, 5], [], [11], [], [], []], num_vertices: 11
# vertex: 0, done_list: [], colors: None->1, [[], [1, 6], [], [11], [], [], []], num_vertices: 11
# vertex: 0, done_list: [], colors: None->2, [[], [1, 4, 5, 6], [], [11], [], [], []], num_vertices: 11
# Checking if N(1) is contained in N(5) and N(6)
# Checking if N(1) is contained in N(6) and N(8)
# Checking if N(2) is contained in N(0) and N(5)
# Checking if N(3) is contained in N(0) and N(6)
# Checking if N(4) is contained in N(5) and N(6)
# Checking if N(4) is contained in N(5) and N(7)
# Checking if N(5) is contained in N(4) and N(8)
# N(5) is contained in N(4) and N(8). Attempting coloring...
# Iteration: 1
# There are 11 vertices in the graph.
# vertex: 5, done_list: [], colors: None->0, [[], [7, 9], [], [11], [], [], []], num_vertices: 11
# vertex: 5, done_list: [], colors: None->1, [[], [0, 3], [], [], [], [], []], num_vertices: 11
# vertex: 5, done_list: [], colors: None->2, [[], [0, 3, 7, 9], [], [11], [], [], []], num_vertices: 11
# Checking if N(6) is contained in N(1) and N(7)
# N(6) is contained in N(1) and N(7). Attempting coloring...
# Iteration: 1
# There are 11 vertices in the graph.
# vertex: 6, done_list: [], colors: None->0, [[], [8, 10], [], [11], [], [], []], num_vertices: 11
# vertex: 6, done_list: [], colors: None->1, [[], [0, 2], [], [], [], [], []], num_vertices: 11
# vertex: 6, done_list: [], colors: None->2, [[], [0, 2, 8, 10], [], [11], [], [], []], num_vertices: 11
# Checking if N(7) is contained in N(0) and N(6)
# Checking if N(7) is contained in N(3) and N(6)
# Checking if N(7) is contained in N(6) and N(9)
# Checking if N(8) is contained in N(0) and N(5)
# Checking if N(8) is contained in N(2) and N(5)
# Checking if N(8) is contained in N(5) and N(10)
# Checking if N(9) is contained in N(0) and N(6)
# Checking if N(10) is contained in N(0) and N(5)
# False

# %%
###Shows that u1 and u2 must be degree at least 4. 
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[3].max_degree=3
test_graph2.vertex_list[3].color_start=True
test_graph2.fill_in_colors()
test_graph2.color_argument2_iter([fork, triangle], 3, 5)
# Out:
# Iteration: 1
# There are 11 vertices in the graph.
# vertex: 9, done_list: [(3, 0), (4, 1), (0, 0), (1, 1)], colors: 1->0, depth: 4, [[], [8, 10], [], [11], [], [], []], num_vertices: 11
# vertex: 9, done_list: [(3, 0), (4, 1), (0, 0), (1, 1)], colors: 1->2, depth: 4, [[5], [8, 10], [], [11], [], [], []], num_vertices: 11
# vertex: 10, done_list: [(3, 0), (4, 1), (0, 0), (1, 1)], colors: 1->0, depth: 4, [[7], [6], [], [11], [9], [], []], num_vertices: 11
# vertex: 10, done_list: [(3, 0), (4, 1), (0, 0), (1, 1)], colors: 1->2, depth: 4, [[], [6], [], [11], [], [], []], num_vertices: 11
# vertex: 11, done_list: [(3, 0), (4, 1), (0, 0), (1, 1)], colors: 1->0, depth: 4, [[], [], [6, 7, 8, 9, 10], [12], [], [], []], num_vertices: 12
# vertex: 11, done_list: [(3, 0), (4, 1), (0, 0), (1, 1)], colors: 1->2, depth: 4, [[], [], [6, 8, 10], [12], [5], [], []], num_vertices: 12
# vertex: 1, done_list: [(3, 0), (4, 1), (0, 0)], colors: 0->1, depth: 3, [[2], [], [9, 10], [11], [], [], []], num_vertices: 11
# vertex: 10, done_list: [(3, 0), (4, 1), (0, 0), (1, 2)], colors: 2->0, depth: 4, [[6], [7], [9], [11], [], [], []], num_vertices: 11
# vertex: 10, done_list: [(3, 0), (4, 1), (0, 0), (1, 2)], colors: 2->1, depth: 4, [[], [7], [9], [11], [], [], [4]], num_vertices: 11
# vertex: 11, done_list: [(3, 0), (4, 1), (0, 0), (1, 2)], colors: 2->0, depth: 4, [[], [], [6, 7, 8, 9, 10], [12], [], [], []], num_vertices: 12
# vertex: 11, done_list: [(3, 0), (4, 1), (0, 0), (1, 2)], colors: 2->1, depth: 4, [[], [], [7, 8, 9, 10], [12], [], [], [4]], num_vertices: 12
# vertex: 1, done_list: [(3, 0), (4, 1), (0, 0)], colors: 0->2, depth: 3, [[], [], [10], [11], [], [], []], num_vertices: 11
# vertex: 8, done_list: [(3, 0), (4, 1), (0, 0), (6, 1)], colors: 1->0, depth: 4, [[7, 9], [], [], [11], [], [], []], num_vertices: 11
# vertex: 8, done_list: [(3, 0), (4, 1), (0, 0), (6, 1)], colors: 1->2, depth: 4, [[], [], [], [11], [], [], []], num_vertices: 11
# vertex: 10, done_list: [(3, 0), (4, 1), (0, 0), (6, 1)], colors: 1->0, depth: 4, [[7], [], [1], [11], [9], [], []], num_vertices: 11
# vertex: 10, done_list: [(3, 0), (4, 1), (0, 0), (6, 1)], colors: 1->2, depth: 4, [[], [], [1], [11], [], [], []], num_vertices: 11
# vertex: 11, done_list: [(3, 0), (4, 1), (0, 0), (6, 1)], colors: 1->0, depth: 4, [[7], [], [1], [12], [9], [], []], num_vertices: 12
# vertex: 11, done_list: [(3, 0), (4, 1), (0, 0), (6, 1)], colors: 1->2, depth: 4, [[], [], [1], [12], [], [], []], num_vertices: 12
# vertex: 6, done_list: [(3, 0), (4, 1), (0, 0)], colors: 0->1, depth: 3, [[2], [8, 10], [], [11], [], [], []], num_vertices: 11
# vertex: 8, done_list: [(3, 0), (4, 1), (0, 0), (6, 2)], colors: 2->0, depth: 4, [[], [7, 9], [], [11], [], [], []], num_vertices: 11
# vertex: 8, done_list: [(3, 0), (4, 1), (0, 0), (6, 2)], colors: 2->1, depth: 4, [[], [7, 9], [], [11], [], [], []], num_vertices: 11
# vertex: 10, done_list: [(3, 0), (4, 1), (0, 0), (6, 2)], colors: 2->0, depth: 4, [[], [7], [1, 9], [11], [], [], []], num_vertices: 11
# vertex: 10, done_list: [(3, 0), (4, 1), (0, 0), (6, 2)], colors: 2->1, depth: 4, [[], [7], [9], [11], [], [], [4]], num_vertices: 11
# vertex: 11, done_list: [(3, 0), (4, 1), (0, 0), (6, 2)], colors: 2->0, depth: 4, [[], [7], [1, 9], [12], [], [], []], num_vertices: 12
# vertex: 11, done_list: [(3, 0), (4, 1), (0, 0), (6, 2)], colors: 2->1, depth: 4, [[], [7], [9], [12], [], [], [4]], num_vertices: 12
# vertex: 6, done_list: [(3, 0), (4, 1), (0, 0)], colors: 0->2, depth: 3, [[], [8, 10], [], [11], [], [], []], num_vertices: 11
# vertex: 8, done_list: [(3, 0), (4, 1), (0, 0), (11, 1)], colors: 1->0, depth: 4, [[7, 9], [6], [], [12], [], [], []], num_vertices: 12
# vertex: 8, done_list: [(3, 0), (4, 1), (0, 0), (11, 1)], colors: 1->2, depth: 4, [[], [6], [], [12], [], [], []], num_vertices: 12
# vertex: 10, done_list: [(3, 0), (4, 1), (0, 0), (11, 1)], colors: 1->0, depth: 4, [[7], [6], [1], [12], [9], [], []], num_vertices: 12
# vertex: 10, done_list: [(3, 0), (4, 1), (0, 0), (11, 1)], colors: 1->2, depth: 4, [[], [6], [1], [12], [], [], []], num_vertices: 12
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/g1/fwv1fw7x3_d5xr_5fk_dfdph0000gn/T/ipykernel_98871/414251852.py in <module>
#       4 test_graph2.vertex_list[3].color_start=True
#       5 test_graph2.fill_in_colors()
# ----> 6 test_graph2.color_argument2_iter([fork, triangle], 3, 5)
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in color_argument2_iter(self, subgraph_list, start_vert, max_distance, verbose)
#     886             old_graph = copy.deepcopy(self)
#     887             #####With the changes to the code, there is not much meaningful difference between the distance and depth. I can probably remove the second variable in the next update but I wanted to get this update out sooner. #####
# --> 888             if self.color_argument2(subgraph_list, start_vert, [], 0, max_distance, max_distance, verbose):
#     889                 return True
#     890             if self.check_for_subgraphs_iter(subgraph_list, 1):
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in color_argument2(self, subgraph_list, start_vert, done_list, current_distance, max_distance, max_depth, verbose)
#     704                         temp_graph.depth2= self.depth2+1
#     705                         #####Recurse on vertex1
# --> 706                         bool1=temp_graph.color_argument2(subgraph_list, vertex1.index, temp_done_list, current_distance + 1, max_distance, max_depth, verbose)
#     707                         if bool1==False:
#     708                             list0.append(vertex1.index)
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in color_argument2(self, subgraph_list, start_vert, done_list, current_distance, max_distance, max_depth, verbose)
#     704                         temp_graph.depth2= self.depth2+1
#     705                         #####Recurse on vertex1
# --> 706                         bool1=temp_graph.color_argument2(subgraph_list, vertex1.index, temp_done_list, current_distance + 1, max_distance, max_depth, verbose)
#     707                         if bool1==False:
#     708                             list0.append(vertex1.index)
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in color_argument2(self, subgraph_list, start_vert, done_list, current_distance, max_distance, max_depth, verbose)
#     769                     if not temp_graph.update_graph2(subgraph_list, 1):
#     770                         temp_done_list = done_list + [(start_vert, temp_color)]
# --> 771                         bool3=temp_graph.color_argument2(subgraph_list, temp_vert.index, temp_done_list, current_distance + 1, max_distance, max_depth, verbose)
#     772                         if bool3==False:
#     773                             list3.append(temp_vert.index)
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in color_argument2(self, subgraph_list, start_vert, done_list, current_distance, max_distance, max_depth, verbose)
#     767                     temp_graph.clean()
#     768                     #####Assuming no contradiction, recurse on temp_vert #####
# --> 769                     if not temp_graph.update_graph2(subgraph_list, 1):
#     770                         temp_done_list = done_list + [(start_vert, temp_color)]
#     771                         bool3=temp_graph.color_argument2(subgraph_list, temp_vert.index, temp_done_list, current_distance + 1, max_distance, max_depth, verbose)
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in update_graph2(self, subgraph_list, max_depth, start_vert, current_depth, verbose, with_colors)
#     530                     temp_graph.vertex_list[edge[0]].edges.append(edge[1])
#     531                     temp_graph.clean()
# --> 532                     if temp_graph.update_graph(subgraph_list, start_vert, with_colors):
#     533                         continue
#     534                     #####Recurse if less than max_depth
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in update_graph(self, subgraph_list, start_vert, with_colors)
#     490             old_graph = copy.deepcopy(self)
#     491             if with_colors:
# --> 492                 if self.fill_in_colors(start_vert) or self.check_for_subgraphs_iter(subgraph_list):
#     493                     return True
#     494             else:
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in check_for_subgraphs_iter(self, subgraph_list, depth_cutoff)
#     315             while True:
#     316                 old_graph = copy.deepcopy(self)
# --> 317                 bool1=self.check_for_subgraphs(subgraph_list, i)
#     318                 if bool1:
#     319                     return True
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in check_for_subgraphs(self, subgraph_list, depth_cutoff)
#     295
#     296                             ##### Check both cases. If there is a contradiction in either case, return True #####
# --> 297                             bool1 = temp_graph.check_for_subgraphs(subgraph_list, depth_cutoff)
#     298                             bool2 = temp_graph2.check_for_subgraphs(subgraph_list, depth_cutoff)
#     299                             if (bool1 and bool2):
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in check_for_subgraphs(self, subgraph_list, depth_cutoff)
#     274         #####In practice, little is gained by a depth cutoff of more than one#####
#     275         #####Method returns True if a fork/triangle is forced, False otherwise #####
# --> 276         if self.contains_subgraphs(subgraph_list):
#     277             return True
#     278
#
# ~/Documents/GitHub/fork_triangle_free_code/graph_algs_test_build.py in contains_subgraphs(self, subgraph_list)
#     150
#     151         while queue:
# --> 152             vertex, trienode, past_vertex_list = queue.pop()
#     153             tpast_vertex_list=copy.copy(past_vertex_list)
#     154             ###need to convert vertex indices to match the indices of the subgraph, and filter down to only those corresponding to vertices already added to our partial list
#
# KeyboardInterrupt:

# %%
test_graph2.show()
# Out:
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [2, 3, 7, 8, 9]
#     Unknown:   []
#     Color:   1
# Vertex 1:
#     Edges:     [2, 0, 9]
#     Non-edges: [3, 4, 5, 6, 7, 8]
#     Unknown:   []
#     Color:   0
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [0, 4, 5, 7, 8, 9]
#     Unknown:   []
#     Color:   1
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [0, 1, 3, 6, 7, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [1, 2, 5, 6, 7, 8]
#     Unknown:   []
#     Color:   0
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 6, 8, 9]
#     Unknown:   []
#     Color:   2
# Vertex 6:
#     Edges:     [0, 2, 8]
#     Non-edges: [1, 3, 4, 5, 7, 9]
#     Unknown:   []
#     Color:   2
# Vertex 7:
#     Edges:     [5, 8]
#     Non-edges: [0, 1, 2, 3, 4, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 8:
#     Edges:     [6, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   [9]
#     Color:   None
# Vertex 9:
#     Edges:     [4, 1]
#     Non-edges: [0, 2, 3, 5, 6]
#     Unknown:   [7, 8]
#     Color:   2
