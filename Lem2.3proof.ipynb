# %%
from graph_algs import *

# %%
###Set up starting graph
v_0 = vert([1, 4, 5, 6], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1, 6], [], 2)
v_3 = vert([4, 2, 5], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 3, 7], [], 5)
v_6 = vert([0, 2, 8], [], 6)
v_7 = vert([5, 8], [0, 1, 2, 3, 4], 7)
v_8 = vert([6, 7], [0, 1, 2, 3, 4], 8)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7, v_8])
test_graph.clean()
print(test_graph.update_graph([fork, triangle]))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 8]
#     Non-edges: [1, 3, 4, 5, 7]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8]
#     Non-edges: [0, 1, 2, 3, 4, 6]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 7]
#     Non-edges: [0, 1, 2, 3, 4, 5]
#     Unknown:   []
# ...

# %%
###Shows that a1 and b1 must be degree at least 4. 
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].max_degree=3
test_graph2.vertex_list[5].color_start=True
test_graph2.fill_in_colors()
test_graph2.color_argument2_iter([fork, triangle], 5, 3)
# Out:
# Iteration: 1
# There are 9 vertices in the graph.
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [8, 2, 3, 7]
#     Unknown:   []
#     Color:   0
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [0, 1, 6, 7, 8]
#     Unknown:   []
#     Color:   1
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [1, 2, 5, 6, 7, 8]
#     Unknown:   []
#     Color:   2
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [1, 2, 4, 5, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 8]
#     Non-edges: [1, 3, 4, 5, 7]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8]
#     Non-edges: [0, 1, 2, 3, 4, 6]
#     Unknown:   []
#     Color:   2
# Vertex 8:
#     Edges:     [6, 7]
# ...

# %%
###First add a new neighbor to a1
new_vert= vert([5], [], len(test_graph.vertex_list))
test_graph.vertex_list.append(new_vert)
test_graph.clean()
test_graph.update_graph3([fork, triangle], verbose=True, with_colors=False)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   [9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7, 9]
#     Non-edges: [1, 2, 4, 6, 8]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 8]
#     Non-edges: [1, 3, 4, 5, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8]
#     Non-edges: [0, 1, 2, 3, 4, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 7, 9]
# ...

# %%
###Since the new vertex cannot be adjacent to b1, add another new vertex adjacent to b1
new_vert= vert([6], [], len(test_graph.vertex_list))
test_graph.vertex_list.append(new_vert)
test_graph.clean()
test_graph.update_graph3([fork, triangle], verbose=True, with_colors=False)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5, 10]
#     Unknown:   [9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9]
#     Unknown:   [10]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9, 10]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7, 9]
#     Non-edges: [1, 2, 4, 6, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 8, 10]
#     Non-edges: [1, 3, 4, 5, 7, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 8, 10]
#     Non-edges: [0, 1, 2, 3, 4, 6, 9]
#     Unknown:   []
#     Color:   None
# ...

# %%
###Shows that u1 and u2 must be degree at least 4. 
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[7].max_degree=3
test_graph2.vertex_list[7].color_start=True
test_graph2.fill_in_colors()
test_graph2.color_argument2_iter([fork, triangle], 7, 4)
# Out:
# Iteration: 1
# There are 11 vertices in the graph.
# vertex: 1, done_list: [7, 5, 0], colors: 0->1, depth: 3, [[], [2], [], [], []], num_vertices: 11
# vertex: 1, done_list: [7, 5, 0], colors: 0->2, depth: 3, [[10], [], [], [], []], num_vertices: 11
# vertex: 4, done_list: [7, 5, 0], colors: 0->1, depth: 3, [[], [3], [], [], []], num_vertices: 11
# vertex: 4, done_list: [7, 5, 0], colors: 0->2, depth: 3, [[9], [], [], [11], []], num_vertices: 11
# vertex: 6, done_list: [7, 5, 0], colors: 0->1, depth: 3, [[8], [2], [], [], []], num_vertices: 11
# vertex: 6, done_list: [7, 5, 0], colors: 0->2, depth: 3, [[10], [2], [], [], []], num_vertices: 11
# vertex: 11, done_list: [7, 5, 0], colors: 0->1, depth: 3, [[8], [2], [], [], []], num_vertices: 12
# vertex: 11, done_list: [7, 5, 0], colors: 0->2, depth: 3, [[], [2], [], [], [10]], num_vertices: 12
# vertex: 0, done_list: [7, 5], colors: 1->0, depth: 2, [[1, 4, 6], [], [], [11], []], num_vertices: 11
# ...

# %%
###Shows that u1 and u2 must be degree at least 4. 
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[4].color=0
test_graph2.vertex_list[8].color=1
test_graph2.vertex_list[5].color_start=True
test_graph2.fill_in_colors()
test_graph2.color_argument2_iter([fork, triangle], 5, 4)
# Out:
# Iteration: 1
# There are 11 vertices in the graph.
# vertex: 6, done_list: [5, 7, 8], colors: 0->1, depth: 3, [[], [0, 2, 10], [], [11], []], num_vertices: 11
# vertex: 6, done_list: [5, 7, 8], colors: 0->2, depth: 3, [[], [0, 2, 10], [], [11], []], num_vertices: 11
# vertex: 11, done_list: [5, 7, 8], colors: 0->1, depth: 3, [[], [], [0, 1, 2, 10], [12], []], num_vertices: 12
# vertex: 11, done_list: [5, 7, 8], colors: 0->2, depth: 3, [[], [], [0, 1, 2, 10], [12], []], num_vertices: 12
# vertex: 8, done_list: [5, 7], colors: 1->0, depth: 2, [[], [6, 9], [], [11], []], num_vertices: 11
# vertex: 6, done_list: [5, 7, 8], colors: 2->0, depth: 3, [[], [2], [], [], []], num_vertices: 11
# vertex: 6, done_list: [5, 7, 8], colors: 2->1, depth: 3, [[0, 10], [], [], [11], []], num_vertices: 11
# vertex: 11, done_list: [5, 7, 8], colors: 2->0, depth: 3, [[], [], [1, 2], [], [4]], num_vertices: 12
# ...
