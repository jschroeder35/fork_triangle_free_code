# %%
from graph_algs import *

# %%
###Set up starting graph
v_0 = vert([1, 4, 5, 6], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1], [], 2)
v_3 = vert([4, 2], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 7], [], 5)
v_6 = vert([0, 2, 7], [], 6)
v_7 = vert([5, 6], [0, 1, 2, 3, 4], 7)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7])
test_graph.clean()
print(test_graph.update_graph(lem3_4_list))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6]
#     Unknown:   [5]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6]
#     Unknown:   [2, 3]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None

# %%
###Shows contradiction if c_5=c_2
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].edges.append(3)
new_vert=vert([1, 4], [], 8)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph4(lem3_4_list, verbose=True, min_subgraph=C_5)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 8]
#     Non-edges: [7, 1, 2, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 2, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 9]
#     Unknown:   [8]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
# ...

# %%
### Shows a contradiction to conclude Claim 1
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].edges.append(3)
new_vert=vert([1], [4], 8)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], 9)
test_graph2.vertex_list.append(new_vert)
new_vert=vert([4], [0, 1, 2, 3, 5, 6], 10)
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph4(lem3_4_list, verbose=True, min_subgraph=C_5)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 10, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 10, 5, 8]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 0, 1, 6, 9, 10]
#     Unknown:   [8]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 10]
#     Non-edges: [7, 1, 2, 5, 6, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7, 3]
#     Non-edges: [1, 4, 6, 10, 2]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 10]
#     Unknown:   [8, 9]
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [8, 9, 10]
#     Color:   None
# ...

# %%
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].non_edges.append(3)
new_vert=vert([1, 3], [5, 6], len(test_graph2.vertex_list))
test_graph2.vertex_list.append(new_vert)
new_vert=vert([8], [0, 1, 2, 3, 4], len(test_graph2.vertex_list))
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph5(lem3_5_list0, verbose=True, min_subgraph=C_5, update_speed='fast')
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 2, 3, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 9, 8]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 8]
#     Non-edges: [7, 0, 1, 6, 5, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 4, 6, 3, 8, 9]
#     Unknown:   [2]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 8]
#     Unknown:   [9]
#     Color:   None
# Vertex 8:
#     Edges:     [1, 3, 9]
# ...

# %%
test_graph3=copy.deepcopy(test_graph)
test_graph3.vertex_list[5].non_edges.append(3)
test_graph3.clean()
test_graph3.vertex_list[5].color=0
test_graph3.vertex_list[6].color=1
test_graph3.fill_in_colors(1)
test_graph3.color_argument_iter(lem3_5_list0, 1, 10)
# Out:
# Iteration: 1
# There are 8 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [2], [], [8], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [], [], [8], [], [], []]. done_list: []
# Vertex 8 is colored 1. Possible neighbors colored 0: [[], [], [3, 4], [9], [5], [], []]. done_list: [(1, 1)]
# Vertex 8 is colored 1. Possible neighbors colored 2: [[], [], [3], [9], [7], [], []]. done_list: [(1, 1)]
# Vertex 1 is colored None. Possible neighbors colored 2: [[0], [2], [], [9], [], [], []]. done_list: []
# Iteration: 2
# There are 9 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [2], [], [9], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[8], [], [], [9], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 2: [[0], [2], [], [9], [], [], []]. done_list: []
# False

# %%
test_graph3.show()
# Out:
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [8, 2, 3, 7]
#     Unknown:   []
#     Color:   2
# Vertex 1:
#     Edges:     [2, 0, 8]
#     Non-edges: [7, 3, 4, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 0, 4, 8]
#     Unknown:   [5]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2]
#     Non-edges: [7, 0, 1, 6, 5]
#     Unknown:   [8]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 1, 2, 5, 6]
#     Unknown:   [8]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 7]
#     Non-edges: [1, 3, 4, 6]
#     Unknown:   [2, 8]
#     Color:   0
# Vertex 6:
#     Edges:     [0, 2, 7]
#     Non-edges: [1, 3, 4, 5, 8]
#     Unknown:   []
#     Color:   1
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4]
#     Unknown:   [8]
#     Color:   2
# Vertex 8:
#     Edges:     [1]
#     Non-edges: [0, 2, 6]
#     Unknown:   [3, 4, 5, 7]
#     Color:   1
