# %%
from graph_algs import *

# %%
###Set up starting graph
v_0 = vert([1, 4, 5, 6], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1, 6], [], 2)
v_3 = vert([4, 2, 5], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 3, 7], [8], 5)
v_6 = vert([0, 2, 7, 8], [], 6)
v_7 = vert([5, 6], [0, 1, 2, 3, 4], 7)
v_8 = vert([6], [0, 1, 2, 3, 4, 5], 8)
v_9 = vert([8], [7], 9)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7, v_8, v_9])
test_graph.clean()
print(test_graph.update_graph(lem2_3_list))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3]
#     Unknown:   [9]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   [9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [8, 1, 2, 4, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 8]
#     Non-edges: [1, 3, 4, 5, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 7]
# ...

# %%
# %%time
### Update the starting graph as much as we can
test_graph.update_graph4(lem2_3_list, verbose=True, with_colors=False)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 9]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [8, 1, 2, 4, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 8]
#     Non-edges: [1, 3, 4, 5, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
# ...

# %%
###Check structure for any additional neighbor of v2
test_graph2=copy.deepcopy(test_graph)
new_vert= vert([1], [], len(test_graph2.vertex_list))
test_graph2.vertex_list.append(new_vert)
test_graph2.clean()
test_graph2.update_graph3(lem2_3_list, verbose=True, with_colors=False)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10, 12]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 9]
#     Non-edges: [7, 8, 0, 4, 5, 10, 11, 12]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [7, 8, 1, 2, 5, 6, 10, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7, 10]
#     Non-edges: [8, 1, 2, 4, 6, 9, 11]
#     Unknown:   [12]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 8, 12]
#     Non-edges: [1, 3, 4, 5, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11]
# ...

# %%
###Shows that u1 and u2 must be degree at least 4. 
test_graph2=copy.deepcopy(test_graph)
test_graph2.vertex_list[5].color=0
test_graph2.vertex_list[6].color=1
test_graph2.vertex_list[1].color_start=True
test_graph2.fill_in_colors()
test_graph2.color_argument2_iter(lem2_3_list, 1, 2)
# Out:
# Iteration: 1
# There are 12 vertices in the graph.
# vertex: 2, done_list: [1], colors: 0->1, depth: 1, [[6], [3, 9], [], [12], []], num_vertices: 12
# vertex: 2, done_list: [1], colors: 0->2, depth: 1, [[], [3], [], [], []], num_vertices: 12
# vertex: 12, done_list: [1], colors: 0->1, depth: 1, [[6, 11], [], [9], [13], []], num_vertices: 13
# vertex: 12, done_list: [1], colors: 0->2, depth: 1, [[], [], [], [], []], num_vertices: 13
# vertex: 1, done_list: [], colors: None->0, depth: 0, [[], [2], [], [], []], num_vertices: 12
# vertex: 2, done_list: [1], colors: 0->1, depth: 0, [[6], [3, 9], [], [12], []], num_vertices: 12
# vertex: 2, done_list: [1], colors: 0->2, depth: 0, [[], [3], [], [], []], num_vertices: 12
# vertex: 1, done_list: [], colors: None->1, depth: 0, [[], [], [], [], []], num_vertices: 12
# True
