# %%
from graph_algs import *

# %%
###Set up starting graph
v_0 = vert([1, 4, 5, 6], [], 0)
v_1 = vert([2, 0], [], 1)
v_2 = vert([3, 1, 6], [], 2)
v_3 = vert([4, 2, 5], [], 3)
v_4 = vert([0, 3], [], 4)
v_5 = vert([0, 3, 7], [8], 5)
v_6 = vert([0, 2, 7, 8], [], 6)
v_7 = vert([5, 6], [0, 1, 2, 3, 4], 7)
v_8 = vert([6], [0, 1, 2, 3, 4, 5], 8)
v_9 = vert([8], [7], 9)
test_graph = graph([v_0, v_1, v_2, v_3, v_4, v_5, v_6, v_7, v_8, v_9])
test_graph.clean()
print(test_graph.update_graph(lem2_3_list))
test_graph.show()
# Out:
# False
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3]
#     Unknown:   [9]
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   [9]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [8, 1, 2, 4, 6]
#     Unknown:   [9]
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 8]
#     Non-edges: [1, 3, 4, 5, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8]
#     Non-edges: [7, 6]
#     Unknown:   [0, 1, 2, 3, 4, 5]
#     Color:   None

# %%
# %%time
### Update the starting graph as much as we can
test_graph.update_graph5(lem2_3_list, verbose=True)
# Out:
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 9]
#     Non-edges: [7, 8, 0, 4, 5]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [7, 8, 1, 2, 5, 6]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7]
#     Non-edges: [8, 1, 2, 4, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 8]
#     Non-edges: [1, 3, 4, 5, 9]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 9, 8]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 7]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8, 2, 4]
#     Non-edges: [7, 6, 0, 1, 3, 5]
#     Unknown:   []
#     Color:   None
# There are 0 unknown edges in the graph to check
# Vertex 10 added adjacent to 1 that cannot be in N(6)!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 9]
#     Non-edges: [7, 8, 0, 4, 5, 10]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [7, 8, 1, 2, 5, 6, 10]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7, 10]
#     Non-edges: [8, 1, 2, 4, 6, 9]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 8]
#     Non-edges: [1, 3, 4, 5, 9, 10]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6]
#     Non-edges: [0, 1, 2, 3, 4, 9, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 9]
#     Non-edges: [0, 1, 2, 3, 4, 5, 7, 10]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8, 2, 4, 10]
#     Non-edges: [7, 6, 0, 1, 3, 5]
#     Unknown:   []
#     Color:   None
# Vertex 10:
#     Edges:     [1, 5, 9]
#     Non-edges: [6, 0, 2, 3, 4, 7, 8]
#     Unknown:   []
#     Color:   None
# There are 0 unknown edges in the graph to check
# Vertex 11 added adjacent to 7 that cannot be in N(0)!
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 9]
#     Non-edges: [7, 8, 0, 4, 5, 10]
#     Unknown:   [11]
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9, 10]
#     Unknown:   [11]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [7, 8, 1, 2, 5, 6, 10]
#     Unknown:   [11]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7, 10]
#     Non-edges: [8, 1, 2, 4, 6, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 8]
#     Non-edges: [1, 3, 4, 5, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11]
#     Non-edges: [0, 1, 2, 3, 4, 9, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 9, 11]
#     Non-edges: [0, 1, 2, 3, 4, 5, 7, 10]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8, 2, 4, 10]
#     Non-edges: [7, 6, 0, 1, 3, 5, 11]
#     Unknown:   []
#     Color:   None
# Vertex 10:
#     Edges:     [1, 5, 9, 11]
#     Non-edges: [6, 0, 2, 3, 4, 7, 8]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [7, 8, 10]
#     Non-edges: [0, 5, 6, 9, 1]
#     Unknown:   [2, 3, 4]
#     Color:   None
# There are 3 unknown edges in the graph to check
# Checking 2<->11. Completion:     0.00%
# Non-edge added from 2 to 11; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 9]
#     Non-edges: [7, 8, 0, 4, 5, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9, 10]
#     Unknown:   [11]
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [7, 8, 1, 2, 5, 6, 10]
#     Unknown:   [11]
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7, 10]
#     Non-edges: [8, 1, 2, 4, 6, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 8]
#     Non-edges: [1, 3, 4, 5, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11]
#     Non-edges: [0, 1, 2, 3, 4, 9, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 9, 11]
#     Non-edges: [0, 1, 2, 3, 4, 5, 7, 10]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8, 2, 4, 10]
#     Non-edges: [7, 6, 0, 1, 3, 5, 11]
#     Unknown:   []
#     Color:   None
# Vertex 10:
#     Edges:     [1, 5, 9, 11]
#     Non-edges: [6, 0, 2, 3, 4, 7, 8]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [7, 8, 10]
#     Non-edges: [0, 5, 6, 9, 1, 2]
#     Unknown:   [3, 4]
#     Color:   None
# There are 2 unknown edges in the graph to check
# Checking 3<->11. Completion:     0.00%
# Non-edge added from 3 to 11; starting over.
# Setting up and and initial greedy updates...
# Vertex 0:
#     Edges:     [1, 4, 5, 6]
#     Non-edges: [7, 8, 2, 3, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 1:
#     Edges:     [2, 0, 10]
#     Non-edges: [7, 8, 3, 4, 5, 6, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 2:
#     Edges:     [3, 1, 6, 9]
#     Non-edges: [7, 8, 0, 4, 5, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 3:
#     Edges:     [4, 2, 5]
#     Non-edges: [7, 8, 0, 1, 6, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 4:
#     Edges:     [0, 3, 9]
#     Non-edges: [7, 8, 1, 2, 5, 6, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 5:
#     Edges:     [0, 3, 7, 10]
#     Non-edges: [8, 1, 2, 4, 6, 9, 11]
#     Unknown:   []
#     Color:   None
# Vertex 6:
#     Edges:     [0, 2, 7, 8]
#     Non-edges: [1, 3, 4, 5, 9, 10, 11]
#     Unknown:   []
#     Color:   None
# Vertex 7:
#     Edges:     [5, 6, 11]
#     Non-edges: [0, 1, 2, 3, 4, 9, 8, 10]
#     Unknown:   []
#     Color:   None
# Vertex 8:
#     Edges:     [6, 9, 11]
#     Non-edges: [0, 1, 2, 3, 4, 5, 7, 10]
#     Unknown:   []
#     Color:   None
# Vertex 9:
#     Edges:     [8, 2, 4, 10]
#     Non-edges: [7, 6, 0, 1, 3, 5, 11]
#     Unknown:   []
#     Color:   None
# Vertex 10:
#     Edges:     [1, 5, 9, 11]
#     Non-edges: [6, 0, 2, 3, 4, 7, 8]
#     Unknown:   []
#     Color:   None
# Vertex 11:
#     Edges:     [7, 8, 10]
#     Non-edges: [0, 5, 6, 9, 1, 2, 3, 4]
#     Unknown:   []
#     Color:   None
# There are 0 unknown edges in the graph to check
# Checking if N(0) is contained in N(2) and N(3)
# N(0) is contained in N(2) and N(3). Attempting coloring...
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 0 is colored None. Possible neighbors colored 0: [[], [4, 5], [], [], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 1: [[], [1, 6], [], [12], [], [], []]. done_list: []
# Vertex 0 is colored None. Possible neighbors colored 2: [[], [1, 4, 5, 6], [], [12], [], [], []]. done_list: []
# Checking if N(1) is contained in N(3) and N(5)
# Checking if N(1) is contained in N(4) and N(9)
# Checking if N(1) is contained in N(5) and N(6)
# N(1) is contained in N(5) and N(6). Attempting coloring...
# Iteration: 1
# There are 12 vertices in the graph.
# Vertex 1 is colored None. Possible neighbors colored 0: [[], [2], [], [12], [], [], []]. done_list: []
# Vertex 1 is colored None. Possible neighbors colored 1: [[], [], [], [], [], [], []]. done_list: []
# CPU times: user 16.3 s, sys: 306 ms, total: 16.6 s
# Wall time: 17.5 s
# True
